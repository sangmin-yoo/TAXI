# %%
import os
import time
import sys
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.neighbors import NearestCentroid, kneighbors_graph
from sklearn import metrics
from sklearn.metrics import silhouette_score
from scipy.spatial.distance import cdist
from scipy.spatial import KDTree, cKDTree
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from concorde.tsp import TSPSolver
from math import sqrt, ceil, inf, floor

# %%
root_dir = os.getcwd()
tsp_dir = os.path.join(root_dir, "../tsplib")
concorde_dir = os.path.join(root_dir, "../pyconcorde/concorde")

# %%
sys.path.insert(0, root_dir)
sys.path.insert(0, tsp_dir)
#sys.path.insert(0, concorde_dir)

# %%
num_samples = 10000

# %%
def gen_tsp_data():
    ## Load a tsp library and Create a dictionary "tsp_database" of Name-X/Y coordinates.

    tsp_database = {}
    cities = os.listdir(tsp_dir)
    
    for city in cities:
        if city.endswith(".tsp"):
            with open(tsp_dir + '/' + city, 'r') as infile:
                lines = infile.readlines()
                for i in range(0, len(lines)):
                    line = lines[i]
                    if "DIMENSION" in line:
                        Dimension = line.strip().split(':')[1]
                        if not Dimension.isdigit():
                            continue
                    if "EDGE_WEIGHT_TYPE" in line:
                        EdgeWeightType = line.strip().split()[1]
                        if EdgeWeightType != "EUC_2D":
                            continue
                    if "NODE_COORD_SECTION" in line:
                        x_y = None
                        nodelist_x = []
                        nodelist_y = []
        
                        for j in range (1, int(Dimension)):
                            x_y = lines[i+1].strip().split()[1:]
    #                        print(x_y)
    #                        import pdb; pdb.set_trace()
                            x = x_y[0]
                            y = x_y[1]
                            nodelist_x.append(float(x))
                            nodelist_y.append(float(y))
                            i+=1
                        tsp_database.update({city[:-4]:[nodelist_x, nodelist_y]})
    return tsp_database

# %%
tsp_database = gen_tsp_data()
problem_list = tsp_database.keys()
problem_list
# Out:
# dict_keys(['pla7397', 'pr107', 'pla85900', 'usa13509', 'brd14051', 'pla33810', 'pr152', 'pr226', 'pr1002', 'rl11849', 'rat575', 'kroA100', 'eil101'])

# %%
import pyproj as p
#x = "kroA100"
#x = "rat575"
#x = "eil101"
#x = "pr107"
#x = "pr152"
x = "pr1002"
coord_geo = False
if coord_geo == True:
     crs_wgs = p.Proj(init='epsg:4326')
     crs_bng = p.Proj(init = 'epsg:27700')
    
     tsp_database[x][0],tsp_database[x][1]  = p.transform(crs_wgs, crs_bng, tsp_database[x][1], tsp_database[x][0])
# for x in tsp_database:
print("Problem : " + x)
#    print(tsp_database[x])
X_coord = np.array(tsp_database[x][0])
Y_coord = np.array(tsp_database[x][1])
X_Y = np.array(list(zip(X_coord,Y_coord))).reshape(len(X_coord),2)
plt.plot()
plt.title('Cities in ' + x)
plt.scatter(X_coord, Y_coord)
plt.show()
# Out:
# Problem : pr1002

# %% [markdown]
# lt.plot()<br>
# lt.title('Cities in ' + x)<br>
# lt.scatter(X_coord, Y_coord)<br>
# lt.show()

# %%
from numpy import inf

X_Y[X_Y == inf] = 0

# %%
def get_clustered_cities(num_clust, labels_array):
    return np.where(labels_array == num_clust)

# %%
def plot_sys2_cities(sys2_cities):
    for k in K:
        plt.scatter(sys2_cities[k][:,0], sys2_cities[k][:,1])
        plt.show()

# %%
import time   
from k_means_constrained import KMeansConstrained

X_Y=[X_Y]
KM_labels = []
i = 0

cluster_size_min = 3
cluster_size_max = 12

Contrained = False

hierarchies = []

"""if Contrained:
    n_clusters = ceil(len(X_Y[i])/cluster_size_max)
else:
    n_clusters = 2
"""
n_clusters = floor(len(X_Y[i])/cluster_size_max)

CEs = []
clf = NearestCentroid()
while True:
    if Contrained:
        KMC = KMeansConstrained(
            n_clusters = n_clusters,
            size_min = cluster_size_min,
            size_max = cluster_size_max,
            random_state = 0)
        y_KMC = KMC.fit_predict(X_Y[i])
        centers = KMC.cluster_centers_
    else:
        #kmeanModel = KMeans(n_clusters, init='k-means++', n_init=10).fit(X_Y[i])
        #y_KMC = kmeanModel.labels_
        #centers = kmeanModel.cluster_centers_
        knn_graph = kneighbors_graph(X_Y[i], n_clusters, include_self=False)
        #AggloModel = AgglomerativeClustering(n_clusters, metric='euclidean', connectivity= knn_graph, linkage='complete').fit(X_Y[i])
        #AggloModel = AgglomerativeClustering(n_clusters, metric='euclidean', connectivity= knn_graph, linkage='ward').fit(X_Y[i])
        #AggloModel = AgglomerativeClustering(n_clusters, metric='euclidean', linkage='complete').fit(X_Y[i])
        AggloModel = AgglomerativeClustering(n_clusters, metric='euclidean', linkage='ward').fit(X_Y[i])
        y_KMC = AggloModel.labels_
        clf.fit(X_Y[i], y_KMC)
        centers = clf.centroids_
    ICC = 0
    ICS = 0
    n_max = 0
    n_min = inf
    for c in range(len(centers)):
        center = centers[c]
        cities = np.where(y_KMC==c)[0]
        if len(cities) < n_min:
            n_min = len(cities)
        if len(cities) > n_max:
            n_max = len(cities)
        for city in cities:
            ICC += sqrt((X_Y[i][city][0]-center[0])**2+(X_Y[i][city][1]-center[1])**2)
        if len(cities) >1 :
            ICS += ICC/len(cities)
        ICC = 0
        #for center2 in centers:
        #    ICS += sqrt((center[0]-center2[0])**2+(center[1]-center2[1])**2)
    #CE = ICC/ICS
    CE = ICS/len(centers)
    CEs.append(CE)
    #Score = silhouette_score(X_Y[i], y_KMC)
    if len(CEs) > 10:
        MEAN = sum(CEs[-9:])/10
    else:
        MEAN = sum(CEs)/len(CEs)
    print(n_clusters, n_min, n_max, CE, MEAN)
    
    if (n_max < cluster_size_max+1):# and (n_clusters == 2 or MEAN*0.999 < CE):# and (MinScore*1.01 > Score):
        plt.plot(range(len(CEs)), CEs, 'r-')
        plt.show()
        colors = mpl.cm.tab20(range(20))
        c_labels = []
        for yy in y_KMC:
            c_labels.append(colors[yy%20])
        #plt.scatter(X_Y[i][:,0], X_Y[i][:,1], c=y_KMC, s=10, cmap='viridis')
        plt.scatter(X_Y[i][:,0], X_Y[i][:,1], c=c_labels, s=10)
        plt.scatter(centers[:,0], centers[:,1], c='black', s=50, alpha=0.5)
        plt.rcParams.update({'font.size':15})
        plt.show()
        
        KM_labels.append(y_KMC)
        X_Y.append(centers)
        hierarchies.append(len(centers))
        i += 1
        n_clusters = floor(len(X_Y[i])/cluster_size_max)
        if n_clusters < 2:
            n_clusters = 2
        if len(centers) < cluster_size_max+1:
            break
        CEs = []
    else:
        n_clusters += 1

print(hierarchies)
# Out:
# 83 1 22 366.7548572619837 366.7548572619837
# 84 1 22 364.2694645581978 365.51216091009076
# 85 1 22 361.84255168273626 364.2889578343059
# 86 1 22 359.8845776287375 363.18786278291384
# 87 1 22 357.97161447253166 362.1446131208374
# 88 1 22 356.74285828876054 361.2443206488246
# 89 1 22 355.5417146035012 360.4296626423498
# 90 1 22 352.6485233295013 359.4570202282437
# 91 1 22 349.81891867690797 358.3861200558731
# 92 1 22 347.0508271689363 357.2525907671794
# 93 1 22 344.9703046903155 318.6471890541928
# 94 1 22 342.93404864741007 316.75633875066023
# 95 1 22 340.94066115277633 314.8619471030641
# 96 1 22 339.1132540628578 312.9761110620967
# 97 1 22 337.32352546963847 311.03417778018445
# 98 1 18 335.57032194975017 309.03703851480935
# 99 1 18 334.0471166369732 307.1768978455565
# 100 1 18 332.5543754304518 305.4504435209109
# 101 1 18 331.0911934557427 303.85448014959155
# 102 1 18 328.7454331876045 302.2319929993205
# 103 1 18 325.54008925943805 300.4925970605233
# 104 1 18 322.3963865606595 298.63816960131163
# 105 1 18 320.60153512164175 296.78699770719004
# 106 1 18 318.84054880411486 294.9387000406377
# 107 1 18 317.11247811869134 293.09291565753176
# 108 1 18 315.2617234211114 291.2143763359456
# 109 1 18 313.1706881526215 289.27600760816256
# 110 1 18 311.11767170719503 287.2786554333078
# 111 1 17 309.10164654907345 285.31427676945464
# 112 1 17 307.4715898015807 283.50742682366894
# 113 1 17 305.87038361599053 281.8548265292021
# 114 1 17 303.8180162146836 280.17647463850625
# 115 1 17 301.8013421594866 278.4725539740434
# 116 1 17 299.8194383466205 276.7432499968363
# 117 1 17 298.57683774463305 275.07476142918847
# 118 1 17 297.35529816979783 273.4932224309061
# 119 1 17 296.1542886718508 271.9968841273717
# 120 1 17 293.65810706503623 270.452530178968
# 121 1 17 291.81468396836544 268.88683959564645
# 122 1 17 290.0014809224597 267.29994932629336
# 123 1 17 288.2177608529102 265.739923790116
# 124 1 17 286.546458439727 264.21443541814006
# 125 1 17 283.12587880896046 262.54507946437406
# 126 1 17 279.75959409296803 260.6633550992076
# 127 1 17 277.633890601665 258.69121434239435
# 128 1 17 275.54140122741353 256.62992559795055
# 129 1 17 273.4813535488869 254.61225024633563
# 130 1 17 271.7984013671753 252.61062198621661
# 131 1 17 270.14114311190195 250.62458820516082
# 132 1 17 268.50899483019344 248.65371160288913
# 133 1 17 266.10228366729643 246.60929412564616
# 134 1 17 263.7314935665321 244.66985560140324
# 135 1 17 261.39582628207546 242.83347882031404
# 136 1 17 258.5298807432691 240.92307783447444
# 137 1 17 256.77747257016915 239.04668496874996
# 138 1 17 255.05046161696927 237.2035957755582
# 139 1 17 253.34829974223274 235.35858561306395
# 140 1 17 252.32755044627442 233.57722634650122
# 141 1 17 251.321279863734 231.85845484985526
# 142 1 17 250.32918210629987 230.2811446937556
# 143 1 17 249.34607084872127 228.8426024219745
# 144 1 17 248.37661391416466 227.54068118518344
# 145 1 13 247.42052879939504 226.42974599079602
# 146 1 13 247.02881611711445 225.45488034549052
# 147 1 13 246.64243285908262 224.6140774697019
# 148 1 13 246.26127099642954 223.9053745951216
# 149 1 13 245.35005106724722 223.20762465721887
# 150 1 13 244.45098073712066 222.52059474455754
# 151 1 13 243.56381862328715 221.8440583962563
# 152 1 13 242.8569255438429 221.19514386576844
# 153 1 13 242.05470014099828 220.56295248845177
# 154 1 13 241.26289324987889 219.94718893350014
# 155 1 13 240.48130322187077 219.2924376439758
# 156 1 13 238.77554224953172 218.5057485830207
# 157 1 13 237.09151071633073 217.58877255501085
# 158 1 13 235.42879603798033 216.59664705208417
# 159 1 13 234.7286787907847 215.62441685745057
# 160 1 13 234.03731300917903 214.67176629603972
# 161 1 12 233.3545356223759 213.72152730389308
# 13 6 17 1196.6993010203678 1196.6993010203678
# 14 6 17 1146.7352245933942 1171.717262806881
# 15 6 17 1098.3619386705848 1147.2654880947823
# 16 2 17 1055.9057358982666 1124.4255500456534
# 17 2 16 1017.5426292133719 1103.048965879197
# 18 2 16 1001.1588540624663 1086.0672805764086
# 19 2 16 959.8380837902089 1068.03453817838
# 20 2 13 933.3771581404786 1051.2023656736424
# 21 2 11 911.5415124363013 1035.6844930917155
# 2 9 12 3346.5995678294153 3346.5995678294153
# [161, 21, 2]

# %%
## sys2_cities has [hierarchies where the sub-cluster belongs, Center X/Y coordinates of the sub-cluster, Cities X/Y coordinates in the sub-cluster]
## sys2_centers has [hierarchies where the sub-cluster belongs, Center X/Y coordinates of the sub-cluster]
## sys2_clusters has [hierarchies where the sub-cluster belongs, Cities X/Y coordinates in the sub-cluster]
sys2_centers = []
sys2_clusters = []

H = range(0,len(hierarchies))
for h in H:
    K = range(0,hierarchies[h])
    sys2_centers.append([])
    sys2_clusters.append([])
    colors = mpl.cm.tab20(range(20))
    for k in K:
        sys2_centers[h].append(X_Y[h+1][k])
        sys2_clusters[h].append(X_Y[h][get_clustered_cities(k, KM_labels[h])])
    largest_cluster_size = 0
    smallest_cluster_size = 100
    for k in K:
        if len(sys2_clusters[h][k]) > largest_cluster_size:
            largest_cluster_size = len(sys2_clusters[h][k])
        if len(sys2_clusters[h][k]) < smallest_cluster_size:
            smallest_cluster_size = len(sys2_clusters[h][k])
        if (len(sys2_clusters[h][k]) == 1):
            print("dirty cluster")
    print("The largest & smallest cluster size in Hierarchy ",h+1, ": ", largest_cluster_size, " & ", smallest_cluster_size)
## Add the topmost cluster
sys2_centers.append([])
sys2_clusters.append([])
sys2_centers[-1].append([0, 0])
sys2_clusters[-1].append(X_Y[-1])
# Out:
# dirty cluster
# The largest & smallest cluster size in Hierarchy  1 :  12  &  1
# The largest & smallest cluster size in Hierarchy  2 :  11  &  2
# The largest & smallest cluster size in Hierarchy  3 :  12  &  9

# %%
def Fix_first_last_cities(sys2_centers, sys2_clusters, sol_route_prev, sol_route, Lowest_Hier, total_traveling_distance):
    ## Find a pair of the closest cities, each of which is in a distinct cluster which will be sequentially visited.
    ## After finding, place each city of the pair in the end of the preceding cluster and the start of the following cluster.
    ## To avoid the city in the following cluster to be selected once again for the next search, the next search starts from Index 1.
    ## Refer to Page 25
    tree = cKDTree(sys2_centers)
    
    Curr_list = [0, -1]
    
    new_sol_route = []
    
    for k in range(len(sol_route_prev)-1):
        ## Finding a pair of cities from distinct sub-clusters having the shortest distance betweeen sub-clusters.
        clust_idx_curr = tree.query(sol_route_prev[k])[1]
        clust_idx_next = tree.query(sol_route_prev[k+1])[1]
        curr_sol = sol_route[clust_idx_curr]
        next_sol = sol_route[clust_idx_next]
        
        sht_dist = inf
        curr_min = 0
        next_min = 0
        for Curr in Curr_list:
            for Next in [0, -1]:
                dist = sqrt((curr_sol[Curr][0] - next_sol[Next][0])**2 + (curr_sol[Curr][1] - next_sol[Next][1])**2)
                if sht_dist > dist:
                    sht_dist = dist
                    curr_min = Curr
                    next_min = Next
        Curr_list = [0, -1]
        Curr_list.remove(next_min)
        
        if Lowest_Hier:
            print(sht_dist)
            total_traveling_distance += sht_dist
        
        if k == 0:
            if curr_min == 0:
                for nid in range(len(curr_sol)):
                    new_sol_route.append(curr_sol[len(curr_sol)-1-nid])
            else:
                for city in curr_sol:
                    new_sol_route.append(city)
        
        if next_min == 0:
            for city in next_sol:
                new_sol_route.append(city)
        else:
            for nid in range(len(next_sol)):
                new_sol_route.append(next_sol[len(next_sol)-1-nid])
    #if len(sol_route_prev) == 1:
    if len(sol_route) == 1:
        for city in sol_route[0]:
            new_sol_route.append(city)
    
    return new_sol_route, total_traveling_distance

# %%
def skip_ising(Lowest_Hier, total_traveling_distance, sol_route, route_btw_clusters, timet, nMAC_array, nRandFlip_array, curr_clust_size, infile, outfile):
    print("Ising skipped!!")
    timet[-1].append(0)
    nMAC_array[-1].append(0)
    nRandFlip_array[-1].append(0)
    DIST = 0
    sol_route.append([])
    with open(infile,"r") as inF:
        lines = inF.readlines()
        outF = open(outfile,"w")
        
        for i in range(1, curr_clust_size+1):
            line = lines[i]
            outF.write(line)
            
            curr = line.strip().split()
            for j in range(len(curr)):
                curr[j] = float(curr[j])
            sol_route[-1].append(curr)
            #sol_route.append(curr)
            
            if Lowest_Hier:
                if (i == 1):
                    route_btw_clusters.append(curr)
                if (i == curr_clust_size):
                    route_btw_clusters.append(curr)
        if curr_clust_size == 1:
            DIST = 0
        else:
            for i in range(1, curr_clust_size):
                X1 = float(lines[i].strip().split()[0])
                Y1 = float(lines[i].strip().split()[1])
                X2 = float(lines[i+1].strip().split()[0])
                Y2 = float(lines[i+1].strip().split()[1])
                DIST += sqrt((X1-X2)**2+(Y1-Y2)**2)
        outF.write("\n")
        outF.write("dist ")
        outF.write(str(DIST))
        outF.write("\n")
        outF.write("n_MAC 0")
        outF.write("\n")
        outF.write("n_RandFlip 0")
        outF.write("\n")
        
        outF.close()
        inF.close()

        if Lowest_Hier:
            total_traveling_distance += DIST
    
    return total_traveling_distance, sol_route, route_btw_clusters, timet, nMAC_array, nRandFlip_array

# %%
def gen_sys2_sol(MAC_ising, benchmark, sys2_centers, sys2_clusters, SchPar):
    MAC_ising = True
    if MAC_ising:
        cpp_cmd = "./ising_mac"
    else :
        cpp_cmd = "./ising_RNG"
    os.system("rm -rf sys2clusters_" + str(benchmark))
    SYS2_CENTERS = sys2_centers
    SYS2_CLUSTERS = sys2_clusters
    
    timet =[]
    nMAC_array =[]
    nRandFlip_array = []
    sys2_labels = []
    colors = mpl.cm.tab20(range(20))
    sol_route = [0]
    
    for h in range(0, n_hierarchies+1):
        print("Execute Ising Solver for Hierarchy ", n_hierarchies-h)
        sys2_centers = SYS2_CENTERS[n_hierarchies-h]
        sys2_clusters = SYS2_CLUSTERS[n_hierarchies-h]
            
        sol_route_ex = sol_route.copy()
        print("sol_route_ex: ", sol_route_ex)
        sol_route = []
        route_btw_clusters = []
        timet.append([])
        nMAC_array.append([])
        nRandFlip_array.append([])
        sys2_labels.append([])
        for k in range(len(sys2_clusters)):
            curr_clust = sys2_clusters[k]
            curr_clust_size = len(curr_clust)
            for l in range(curr_clust_size):
                sys2_labels[h].append(colors[k%20])
            os.system("mkdir -p sys2clusters_" + str(benchmark))
            curr_filename = str(benchmark) + "_h" + str(n_hierarchies-h)  + "_c" + str(k) +".in"
            curr_logfile = str(benchmark) + "_h" + str(n_hierarchies-h)   + "_c" + str(k) +".out"
            inF = open("sys2clusters_" + str(benchmark) + "/" + curr_filename,"w")
            inF.write(str(curr_clust_size))
            inF.write("\n")
            for i in curr_clust:
                inF.write(str(i[0]) + " " + str(i[1]))
                inF.write("\n")
            inF.close()
            
            if h == 0:
                if curr_clust_size == 2:
                    total_traveling_distance, sol_route, route_btw_clusters, timet, nMAC_array, nRandFlip_array = skip_ising(h == n_hierarchies, 0, sol_route, route_btw_clusters, timet, nMAC_array, nRandFlip_array, curr_clust_size, "sys2clusters_" + str(benchmark) + "/" + curr_filename, "sys2clusters_" + str(benchmark) + "/" + curr_logfile)
                    continue
            else:
                if k == 0 or k == len(sys2_clusters)-1:
                    if curr_clust_size < 3:
                        total_traveling_distance, sol_route, route_btw_clusters, timet, nMAC_array, nRandFlip_array = skip_ising(h == n_hierarchies, total_traveling_distance, sol_route, route_btw_clusters, timet, nMAC_array, nRandFlip_array, curr_clust_size, "sys2clusters_" + str(benchmark) + "/" + curr_filename, "sys2clusters_" + str(benchmark) + "/" + curr_logfile)
                        continue
                else:
                    if curr_clust_size < 4:
                        total_traveling_distance, sol_route, route_btw_clusters, timet, nMAC_array, nRandFlip_array = skip_ising(h == n_hierarchies, total_traveling_distance, sol_route, route_btw_clusters, timet, nMAC_array, nRandFlip_array, curr_clust_size, "sys2clusters_" + str(benchmark) + "/" + curr_filename, "sys2clusters_" + str(benchmark) + "/" + curr_logfile)
                        continue
            tic = time.perf_counter()
            ### when h>0, Problem_size to optimize = N-1 when k is 0 or -1, otherwise N-2
            os.system(cpp_cmd+" -I "+str(SchPar[0])+" -c "+str(SchPar[1])+" -F "+str(SchPar[2])+" -D "+str(SchPar[3])+" -P "+str(SchPar[4])+" k0" + " sys2clusters_" + str(benchmark) + "/" + curr_filename + " >> " + "sys2clusters_" + str(benchmark) + "/" + curr_logfile)
            """
            if h == 0 :
                os.system(cpp_cmd+" -I "+str(SchPar[0])+" -c "+str(SchPar[1])+" -F "+str(SchPar[2])+" -D "+str(SchPar[3])+" -P "+str(SchPar[4])+" k0" + " sys2clusters_" + str(benchmark) + "/" + curr_filename + " >> " + "sys2clusters_" + str(benchmark) + "/" + curr_logfile)
            elif k == len(clust_id_list)-1:
                os.system(cpp_cmd+" -I "+str(SchPar[0])+" -c "+str(SchPar[1])+" -F "+str(SchPar[2])+" -D "+str(SchPar[3])+" -P "+str(SchPar[4])+" k-1" + " sys2clusters_" + str(benchmark) + "/" + curr_filename + " >> " + "sys2clusters_" + str(benchmark) + "/" + curr_logfile)
            else :
                os.system(cpp_cmd+" -I "+str(SchPar[0])+" -c "+str(SchPar[1])+" -F "+str(SchPar[2])+" -D "+str(SchPar[3])+" -P "+str(SchPar[4])+" k" + str(k+1) + " sys2clusters_" + str(benchmark) + "/" + curr_filename + " >> " + "sys2clusters_" + str(benchmark) + "/" + curr_logfile)
            """
            toc = time.perf_counter()
            timet[-1].append(toc-tic)
            
            dist_array =[]
            with open("sys2clusters_" + str(benchmark) + "/" + curr_logfile,"r") as outFile:
                lines = outFile.readlines()
                for i in range(0,len(lines)):
                    line = lines[i]
                    if "dist" in line:
                        dist_array.append(line.strip().split()[1])
                        continue
                    if "n_MAC" in line:
                        nMAC_array[-1].append(int(line.strip().split()[1]))
                        continue
                    if "n_RandFlip" in line:
                        nRandFlip_array[-1].append(int(line.strip().split()[1]))
                        continue
                dist = min(dist_array)
                ####################################
                ####################################
                if h == n_hierarchies:
                    total_traveling_distance += float(dist)
                    print("hierarchy: ", h, " cluster: ", k, " distance within the cluster: ", float(dist), " total distance: ", total_traveling_distance)
                ####################################
                ####################################
                sol_route.append([])
                for i in range(0, curr_clust_size):
                    line = lines[i]
                    curr = line.strip().split()
                    for j in range(len(curr)):
                        curr[j] = float(curr[j])
                    sol_route[-1].append(curr)
                
                    if h == n_hierarchies:
                        if (i == 0) or (i == curr_clust_size-1):
                            route_btw_clusters.append(curr)
                outFile.close()
            print("done with cluster" + str(k))
        #if h != 0:
        sol_route, total_traveling_distance = Fix_first_last_cities(sys2_centers, sys2_clusters, sol_route_ex, sol_route, h == n_hierarchies, total_traveling_distance)
        #else:
        print(f"Ising Max time = {max(timet[-1]):0.4f} seconds", " / ", str(min(timet[-1])))
        if MAC_ising:
            print(f"Max/Min number of Ising Macro MAC Operations = ", max(nMAC_array[-1]), " / ", min(nMAC_array[-1]))
            print(f"Max/Min number of Ising Macro RandomFlip Operations = ", max(nRandFlip_array[-1]), " / ", min(nRandFlip_array[-1]))
    
    print("total_traveling_distance: ", total_traveling_distance)
    return sol_route_ex, sol_route, route_btw_clusters, sys2_labels, total_traveling_distance, nMAC_array, nRandFlip_array

# %%
print(hierarchies)
n_hierarchies = len(hierarchies)
MAC_ising = True
#sol_route, route_btw_clusters, sys2_labels = gen_sys2_sol(MAC_ising, x, sys2_centers, sys2_clusters)
init_Irands = [48]
init_cools = [0.001]
Factors = [0.9]
Thresholds = [0]
Patiences = [10000]
#cools = [0.01, 0.005, 0.002, 0.001]
#Factors = [0.8, 0.9, 0.95, 0.99, 0.995, 0.999]
#Thresholds = [1e6, 1e3, 0, -1e3, -1e6]
#Patiences = [5, 10, 20, 50]
ttds = []
nMACs = []
nRandFlips = []

repeat = 1

for REPEAT in range(repeat):
    for Irand in init_Irands:
        for cool in init_cools:
            for Factor in Factors:
                for Threshold in Thresholds:
                    for Patience in Patiences:
                        scheduler_params = [Irand, cool, Factor, Threshold, Patience]
                        sol_route_ex, sol_route, route_btw_clusters, sys2_labels, ttd, nMAC, nRandFlip = gen_sys2_sol(MAC_ising, x, sys2_centers, sys2_clusters, scheduler_params)
                        ttds.append(ttd)
                        sum_nMACs = 0
                        for MAC in nMAC:
                            sum_nMACs += max(MAC)
                        #nMACs.append(max(nMAC[-1]))
                        nMACs.append(sum_nMACs)
                        sum_nRFlips = 0
                        for RFlip in nRandFlip:
                            sum_nRFlips += max(RFlip)
                        #nRandFlips.append(max(nRandFlip[-1]))
                        nRandFlips.append(sum_nRFlips)
    i = 0
    for Irand in init_Irands:
        for cool in init_cools:
            for Factor in Factors:
                for Threshold in Thresholds:
                    for Patience in Patiences:
                        print("Irand: ", Irand, "Cool: ", cool, "Factor: ", Factor, " Threshold: ", Threshold, " Patience: ", Patience, " ttd: ", ttds[i], " nMAC: ", nMACs[i], " nRandFlip: ", nRandFlips[i])
                        i += 1
# Out:
# [161, 21, 2]
# Execute Ising Solver for Hierarchy  3
# sol_route_ex:  [0]
# Ising skipped!!
# Ising Max time = 0.0000 seconds  /  0
# Max/Min number of Ising Macro MAC Operations =  0  /  0
# Max/Min number of Ising Macro RandomFlip Operations =  0  /  0
# Execute Ising Solver for Hierarchy  2
# sol_route_ex:  [[5213.063636363636, 6742.749986638876], [12802.860251304859, 6326.208678247184]]
# done with cluster0
# done with cluster1
# Ising Max time = 3.1591 seconds  /  1.6916094250045717
# Max/Min number of Ising Macro MAC Operations =  28556  /  20768
# Max/Min number of Ising Macro RandomFlip Operations =  2596  /  2596
# Execute Ising Solver for Hierarchy  1
# sol_route_ex:  [[1160.0, 3095.0], [4541.42, 2559.29], [6485.45, 3992.5], [6773.75, 7060.11], [8669.68, 10310.3], [6450.39, 9865.15], [3919.68, 10310.3], [4204.46, 7876.34], [4712.73, 5615.78], [9291.42, 2559.29], [15725.1, 3482.08], [16119.6, 6430.22], [14041.4, 2559.29], [14212.7, 5615.78], [13100.2, 7641.17], [15950.4, 9865.15], [13398.0, 10290.7], [11200.4, 9865.15], [9795.24, 7786.07], [9637.24, 5730.25], [11162.6, 4089.34]]
# done with cluster0
# done with cluster1
# done with cluster2
# done with cluster3
# done with cluster4
# done with cluster5
# done with cluster6
# done with cluster7
# done with cluster8
# done with cluster9
# done with cluster10
# done with cluster11
# done with cluster12
# done with cluster13
# done with cluster14
# Ising skipped!!
# done with cluster16
# done with cluster17
# done with cluster18
# done with cluster19
# done with cluster20
# Ising Max time = 2.6631 seconds  /  0
# Max/Min number of Ising Macro MAC Operations =  25960  /  0
# Max/Min number of Ising Macro RandomFlip Operations =  2596  /  0
# Execute Ising Solver for Hierarchy  0
# sol_route_ex:  [[1150.0, 4000.0], [1170.0, 2190.0], [5233.33, 2916.67], [4991.67, 3558.33], [4280.0, 3460.0], [4431.25, 2950.0], [3550.0, 2983.33], [4185.71, 1735.71], [3450.0, 1583.33], [4770.0, 2450.0], [4972.22, 1805.56], [5550.0, 2150.0], [7780.0, 4750.0], [7125.0, 3975.0], [6300.0, 2300.0], [6159.09, 3019.18], [6285.71, 3580.43], [5714.29, 3742.86], [5766.67, 4275.0], [6430.0, 4940.0], [6808.33, 5350.0], [6634.17, 5927.33], [5966.67, 6983.33], [5725.0, 7775.0], [7183.33, 7666.67], [8033.33, 7333.33], [7100.0, 6675.0], [8125.0, 9400.0], [8825.0, 9350.0], [9016.67, 10055.6], [9280.0, 11180.0], [8521.43, 11342.9], [8250.0, 10533.3], [6842.86, 9828.57], [7300.0, 9287.5], [6621.43, 8442.86], [6765.3, 9010.5], [6040.0, 8770.0], [5912.5, 9725.0], [5733.33, 10450.0], [5944.44, 11155.6], [6575.0, 11283.3], [6994.44, 10383.3], [6225.0, 10180.0], [4266.67, 10055.6], [4530.0, 11180.0], [3771.43, 11342.9], [3500.0, 10533.3], [3375.0, 9400.0], [4075.0, 9350.0], [4342.86, 7992.86], [4716.67, 8716.67], [4475.0, 7462.5], [3283.33, 7333.33], [5233.33, 5333.33], [5906.62, 5489.12], [5450.0, 5990.91], [5266.67, 6625.0], [4650.0, 6266.67], [4043.75, 6181.25], [4214.18, 5351.55], [3316.67, 4700.0], [4333.33, 4604.17], [8300.0, 2983.33], [8200.0, 1583.33], [8935.71, 1735.71], [9722.22, 1805.56], [10300.0, 2150.0], [9741.67, 3558.33], [9983.33, 2916.67], [9520.0, 2450.0], [9181.25, 2950.0], [9030.0, 3460.0], [15659.1, 3019.18], [15785.7, 3580.43], [15214.3, 3742.86], [15266.7, 4275.0], [16625.0, 3975.0], [15800.0, 2300.0], [15992.9, 5028.57], [16725.0, 5062.5], [16600.0, 6675.0], [16683.3, 7666.67], [15225.0, 7775.0], [15466.7, 6983.33], [16144.4, 5820.5], [14270.0, 2450.0], [14472.2, 1805.56], [15050.0, 2150.0], [14733.3, 2916.67], [14491.7, 3558.33], [13780.0, 3460.0], [13931.2, 2950.0], [13050.0, 2983.33], [12950.0, 1583.33], [13685.7, 1735.71], [13833.3, 4604.17], [12816.7, 4700.0], [13714.2, 5351.55], [13543.8, 6181.25], [14150.0, 6266.67], [14766.7, 6625.0], [14950.0, 5990.91], [15406.6, 5489.12], [14733.3, 5333.33], [14216.7, 8716.67], [13842.9, 7992.86], [13975.0, 7462.5], [12783.3, 7333.33], [11850.0, 6675.0], [11933.3, 7666.67], [15233.3, 10450.0], [15412.5, 9725.0], [15725.0, 10180.0], [15540.0, 8770.0], [16265.3, 9010.5], [16800.0, 9287.5], [16121.4, 8442.86], [16342.9, 9828.57], [16494.4, 10383.3], [16075.0, 11283.3], [15444.4, 11155.6], [13000.0, 10533.3], [13271.4, 11342.9], [13900.0, 11062.5], [13766.7, 10055.6], [13575.0, 9350.0], [12875.0, 9400.0], [10483.3, 10450.0], [10975.0, 10180.0], [10662.5, 9725.0], [11592.9, 9828.57], [11515.3, 9010.5], [11371.4, 8442.86], [10790.0, 8770.0], [12050.0, 9287.5], [11744.4, 10383.3], [11325.0, 11283.3], [10694.4, 11155.6], [10475.0, 7775.0], [9466.67, 8716.67], [9092.86, 7992.86], [9225.0, 7462.5], [10716.7, 6983.33], [9983.33, 5333.33], [10656.6, 5489.12], [10200.0, 5990.91], [10016.7, 6625.0], [9400.0, 6266.67], [8793.75, 6181.25], [8964.18, 5351.55], [9083.33, 4604.17], [11875.0, 3975.0], [11050.0, 2300.0], [10909.1, 3019.18], [11035.7, 3580.43], [10464.3, 3742.86], [10516.7, 4275.0], [11242.9, 5028.57], [11394.4, 5820.5], [11975.0, 5062.5]]
# hierarchy:  3  cluster:  0  distance within the cluster:  2932.06  total distance:  2932.06
# done with cluster0
# hierarchy:  3  cluster:  1  distance within the cluster:  2932.06  total distance:  5864.12
# done with cluster1
# hierarchy:  3  cluster:  2  distance within the cluster:  2932.06  total distance:  8796.18
# done with cluster2
# hierarchy:  3  cluster:  3  distance within the cluster:  1100.44  total distance:  9896.62
# done with cluster3
# hierarchy:  3  cluster:  4  distance within the cluster:  2167.28  total distance:  12063.900000000001
# done with cluster4
# hierarchy:  3  cluster:  5  distance within the cluster:  2058.72  total distance:  14122.62
# done with cluster5
# hierarchy:  3  cluster:  6  distance within the cluster:  1100.44  total distance:  15223.060000000001
# done with cluster6
# hierarchy:  3  cluster:  7  distance within the cluster:  1810.56  total distance:  17033.620000000003
# done with cluster7
# hierarchy:  3  cluster:  8  distance within the cluster:  2233.98  total distance:  19267.600000000002
# done with cluster8
# hierarchy:  3  cluster:  9  distance within the cluster:  2503.73  total distance:  21771.33
# done with cluster9
# hierarchy:  3  cluster:  10  distance within the cluster:  1862.39  total distance:  23633.72
# done with cluster10
# hierarchy:  3  cluster:  11  distance within the cluster:  2058.72  total distance:  25692.440000000002
# done with cluster11
# hierarchy:  3  cluster:  12  distance within the cluster:  1553.73  total distance:  27246.170000000002
# done with cluster12
# hierarchy:  3  cluster:  13  distance within the cluster:  2255.53  total distance:  29501.7
# done with cluster13
# hierarchy:  3  cluster:  14  distance within the cluster:  1810.56  total distance:  31312.260000000002
# done with cluster14
# hierarchy:  3  cluster:  15  distance within the cluster:  1456.16  total distance:  32768.420000000006
# done with cluster15
# hierarchy:  3  cluster:  16  distance within the cluster:  1973.28  total distance:  34741.700000000004
# done with cluster16
# hierarchy:  3  cluster:  17  distance within the cluster:  1973.28  total distance:  36714.98
# done with cluster17
# hierarchy:  3  cluster:  18  distance within the cluster:  1667.49  total distance:  38382.47
# done with cluster18
# hierarchy:  3  cluster:  19  distance within the cluster:  1667.49  total distance:  40049.96
# done with cluster19
# hierarchy:  3  cluster:  20  distance within the cluster:  2503.73  total distance:  42553.69
# done with cluster20
# hierarchy:  3  cluster:  21  distance within the cluster:  1743.73  total distance:  44297.420000000006
# done with cluster21
# hierarchy:  3  cluster:  22  distance within the cluster:  1810.56  total distance:  46107.98
# done with cluster22
# hierarchy:  3  cluster:  23  distance within the cluster:  2058.72  total distance:  48166.700000000004
# done with cluster23
# hierarchy:  3  cluster:  24  distance within the cluster:  1862.39  total distance:  50029.090000000004
# done with cluster24
# hierarchy:  3  cluster:  25  distance within the cluster:  1213.75  total distance:  51242.840000000004
# done with cluster25
# hierarchy:  3  cluster:  26  distance within the cluster:  1380.28  total distance:  52623.12
# done with cluster26
# hierarchy:  3  cluster:  27  distance within the cluster:  1213.75  total distance:  53836.87
# done with cluster27
# hierarchy:  3  cluster:  28  distance within the cluster:  1130.8  total distance:  54967.670000000006
# done with cluster28
# hierarchy:  3  cluster:  29  distance within the cluster:  1213.75  total distance:  56181.420000000006
# done with cluster29
# hierarchy:  3  cluster:  30  distance within the cluster:  1466.27  total distance:  57647.69
# done with cluster30
# Ising skipped!!
# hierarchy:  3  cluster:  32  distance within the cluster:  1309.58  total distance:  59721.27549446403
# done with cluster32
# hierarchy:  3  cluster:  33  distance within the cluster:  1520.55  total distance:  61241.825494464036
# done with cluster33
# hierarchy:  3  cluster:  34  distance within the cluster:  1973.28  total distance:  63215.105494464035
# done with cluster34
# hierarchy:  3  cluster:  35  distance within the cluster:  1466.27  total distance:  64681.37549446403
# done with cluster35
# hierarchy:  3  cluster:  36  distance within the cluster:  1466.27  total distance:  66147.64549446403
# done with cluster36
# hierarchy:  3  cluster:  37  distance within the cluster:  1674.56  total distance:  67822.20549446403
# done with cluster37
# hierarchy:  3  cluster:  38  distance within the cluster:  1553.73  total distance:  69375.93549446402
# done with cluster38
# hierarchy:  3  cluster:  39  distance within the cluster:  1412.32  total distance:  70788.25549446403
# done with cluster39
# hierarchy:  3  cluster:  40  distance within the cluster:  1667.49  total distance:  72455.74549446403
# done with cluster40
# hierarchy:  3  cluster:  41  distance within the cluster:  2503.73  total distance:  74959.47549446403
# done with cluster41
# Ising skipped!!
# hierarchy:  3  cluster:  43  distance within the cluster:  1934.48  total distance:  77852.97248883898
# done with cluster43
# hierarchy:  3  cluster:  44  distance within the cluster:  2233.98  total distance:  80086.95248883897
# done with cluster44
# Ising skipped!!
# hierarchy:  3  cluster:  46  distance within the cluster:  2233.98  total distance:  83228.03927002552
# done with cluster46
# hierarchy:  3  cluster:  47  distance within the cluster:  1862.39  total distance:  85090.42927002552
# done with cluster47
# hierarchy:  3  cluster:  48  distance within the cluster:  1557.28  total distance:  86647.70927002552
# done with cluster48
# hierarchy:  3  cluster:  49  distance within the cluster:  1583.44  total distance:  88231.14927002552
# done with cluster49
# hierarchy:  3  cluster:  50  distance within the cluster:  1553.73  total distance:  89784.87927002551
# done with cluster50
# hierarchy:  3  cluster:  51  distance within the cluster:  1125.94  total distance:  90910.81927002552
# done with cluster51
# hierarchy:  3  cluster:  52  distance within the cluster:  1380.28  total distance:  92291.09927002552
# done with cluster52
# hierarchy:  3  cluster:  53  distance within the cluster:  1380.28  total distance:  93671.37927002551
# done with cluster53
# hierarchy:  3  cluster:  54  distance within the cluster:  1062.25  total distance:  94733.62927002551
# done with cluster54
# hierarchy:  3  cluster:  55  distance within the cluster:  980.116  total distance:  95713.74527002551
# done with cluster55
# Ising skipped!!
# hierarchy:  3  cluster:  57  distance within the cluster:  1130.8  total distance:  97686.31114818335
# done with cluster57
# hierarchy:  3  cluster:  58  distance within the cluster:  1130.8  total distance:  98817.11114818335
# done with cluster58
# hierarchy:  3  cluster:  59  distance within the cluster:  961.972  total distance:  99779.08314818334
# done with cluster59
# hierarchy:  3  cluster:  60  distance within the cluster:  1546.28  total distance:  101325.36314818334
# done with cluster60
# hierarchy:  3  cluster:  61  distance within the cluster:  1377.94  total distance:  102703.30314818335
# done with cluster61
# hierarchy:  3  cluster:  62  distance within the cluster:  1395.56  total distance:  104098.86314818334
# done with cluster62
# hierarchy:  3  cluster:  63  distance within the cluster:  961.972  total distance:  105060.83514818334
# done with cluster63
# Ising skipped!!
# hierarchy:  3  cluster:  65  distance within the cluster:  908.114  total distance:  106521.71840509021
# done with cluster65
# hierarchy:  3  cluster:  66  distance within the cluster:  852.149  total distance:  107373.86740509022
# done with cluster66
# hierarchy:  3  cluster:  67  distance within the cluster:  908.114  total distance:  108281.98140509022
# done with cluster67
# hierarchy:  3  cluster:  68  distance within the cluster:  1309.58  total distance:  109591.56140509022
# done with cluster68
# Ising skipped!!
# hierarchy:  3  cluster:  70  distance within the cluster:  1125.94  total distance:  111481.50689955425
# done with cluster70
# hierarchy:  3  cluster:  71  distance within the cluster:  1674.56  total distance:  113156.06689955425
# done with cluster71
# hierarchy:  3  cluster:  72  distance within the cluster:  1505.33  total distance:  114661.39689955425
# done with cluster72
# hierarchy:  3  cluster:  73  distance within the cluster:  1505.33  total distance:  116166.72689955425
# done with cluster73
# Ising skipped!!
# hierarchy:  3  cluster:  75  distance within the cluster:  1634.76  total distance:  118643.25277771208
# done with cluster75
# hierarchy:  3  cluster:  76  distance within the cluster:  1634.76  total distance:  120278.01277771208
# done with cluster76
# hierarchy:  3  cluster:  77  distance within the cluster:  1634.76  total distance:  121912.77277771207
# done with cluster77
# hierarchy:  3  cluster:  78  distance within the cluster:  1456.16  total distance:  123368.93277771208
# done with cluster78
# hierarchy:  3  cluster:  79  distance within the cluster:  1501.64  total distance:  124870.57277771208
# done with cluster79
# hierarchy:  3  cluster:  80  distance within the cluster:  1501.64  total distance:  126372.21277771208
# done with cluster80
# Ising skipped!!
# hierarchy:  3  cluster:  82  distance within the cluster:  1125.94  total distance:  127498.15277771208
# done with cluster82
# hierarchy:  3  cluster:  83  distance within the cluster:  1663.97  total distance:  129162.12277771208
# done with cluster83
# hierarchy:  3  cluster:  84  distance within the cluster:  1456.16  total distance:  130618.28277771208
# done with cluster84
# hierarchy:  3  cluster:  85  distance within the cluster:  1267.33  total distance:  131885.6127777121
# done with cluster85
# Ising skipped!!
# hierarchy:  3  cluster:  87  distance within the cluster:  1267.33  total distance:  134111.95977208702
# done with cluster87
# hierarchy:  3  cluster:  88  distance within the cluster:  1377.94  total distance:  135489.89977208702
# done with cluster88
# hierarchy:  3  cluster:  89  distance within the cluster:  1305.07  total distance:  136794.96977208703
# done with cluster89
# hierarchy:  3  cluster:  90  distance within the cluster:  1273.21  total distance:  138068.17977208702
# done with cluster90
# hierarchy:  3  cluster:  91  distance within the cluster:  1305.07  total distance:  139373.24977208703
# done with cluster91
# hierarchy:  3  cluster:  92  distance within the cluster:  1377.94  total distance:  140751.18977208703
# done with cluster92
# Ising skipped!!
# Ising skipped!!
# hierarchy:  3  cluster:  95  distance within the cluster:  1600.44  total distance:  144165.8433344601
# done with cluster95
# Ising skipped!!
# Ising skipped!!
# hierarchy:  3  cluster:  98  distance within the cluster:  1546.28  total distance:  147317.89470708196
# done with cluster98
# hierarchy:  3  cluster:  99  distance within the cluster:  1557.28  total distance:  148875.17470708195
# done with cluster99
# hierarchy:  3  cluster:  100  distance within the cluster:  1557.28  total distance:  150432.45470708195
# done with cluster100
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# hierarchy:  3  cluster:  104  distance within the cluster:  1426.75  total distance:  153521.61908662668
# done with cluster104
# hierarchy:  3  cluster:  105  distance within the cluster:  1289.8  total distance:  154811.41908662667
# done with cluster105
# hierarchy:  3  cluster:  106  distance within the cluster:  1289.8  total distance:  156101.21908662666
# done with cluster106
# Ising skipped!!
# hierarchy:  3  cluster:  108  distance within the cluster:  1143.47  total distance:  157797.45834353354
# done with cluster108
# hierarchy:  3  cluster:  109  distance within the cluster:  1143.93  total distance:  158941.38834353353
# done with cluster109
# hierarchy:  3  cluster:  110  distance within the cluster:  1143.47  total distance:  160084.85834353353
# done with cluster110
# hierarchy:  3  cluster:  111  distance within the cluster:  1546.28  total distance:  161631.13834353353
# done with cluster111
# hierarchy:  3  cluster:  112  distance within the cluster:  980.116  total distance:  162611.25434353354
# done with cluster112
# hierarchy:  3  cluster:  113  distance within the cluster:  1641.58  total distance:  164252.83434353353
# done with cluster113
# hierarchy:  3  cluster:  114  distance within the cluster:  1641.58  total distance:  165894.4143435335
# done with cluster114
# hierarchy:  3  cluster:  115  distance within the cluster:  1641.58  total distance:  167535.9943435335
# done with cluster115
# hierarchy:  3  cluster:  116  distance within the cluster:  1663.97  total distance:  169199.9643435335
# done with cluster116
# hierarchy:  3  cluster:  117  distance within the cluster:  961.972  total distance:  170161.9363435335
# done with cluster117
# hierarchy:  3  cluster:  118  distance within the cluster:  1663.97  total distance:  171825.9063435335
# done with cluster118
# Ising skipped!!
# hierarchy:  3  cluster:  120  distance within the cluster:  1062.95  total distance:  173441.6256004404
# done with cluster120
# hierarchy:  3  cluster:  121  distance within the cluster:  1414.18  total distance:  174855.8056004404
# done with cluster121
# hierarchy:  3  cluster:  122  distance within the cluster:  1414.18  total distance:  176269.98560044038
# done with cluster122
# hierarchy:  3  cluster:  123  distance within the cluster:  1033.1  total distance:  177303.0856004404
# done with cluster123
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# hierarchy:  3  cluster:  129  distance within the cluster:  1070.42  total distance:  180022.1130128302
# done with cluster129
# hierarchy:  3  cluster:  130  distance within the cluster:  1070.42  total distance:  181092.53301283022
# done with cluster130
# hierarchy:  3  cluster:  131  distance within the cluster:  1070.42  total distance:  182162.95301283023
# done with cluster131
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# hierarchy:  3  cluster:  139  distance within the cluster:  1150.0  total distance:  185522.25154799246
# done with cluster139
# hierarchy:  3  cluster:  140  distance within the cluster:  1000.0  total distance:  186522.25154799246
# done with cluster140
# hierarchy:  3  cluster:  141  distance within the cluster:  650.0  total distance:  187172.25154799246
# done with cluster141
# hierarchy:  3  cluster:  142  distance within the cluster:  808.921  total distance:  187981.17254799246
# done with cluster142
# hierarchy:  3  cluster:  143  distance within the cluster:  731.721  total distance:  188712.89354799245
# done with cluster143
# hierarchy:  3  cluster:  144  distance within the cluster:  731.721  total distance:  189444.61454799245
# done with cluster144
# hierarchy:  3  cluster:  145  distance within the cluster:  1267.33  total distance:  190711.94454799243
# done with cluster145
# hierarchy:  3  cluster:  146  distance within the cluster:  1505.33  total distance:  192217.27454799242
# done with cluster146
# hierarchy:  3  cluster:  147  distance within the cluster:  1583.44  total distance:  193800.71454799242
# done with cluster147
# hierarchy:  3  cluster:  148  distance within the cluster:  922.866  total distance:  194723.58054799243
# done with cluster148
# hierarchy:  3  cluster:  149  distance within the cluster:  1022.87  total distance:  195746.45054799243
# done with cluster149
# hierarchy:  3  cluster:  150  distance within the cluster:  922.866  total distance:  196669.31654799244
# done with cluster150
# hierarchy:  3  cluster:  151  distance within the cluster:  1284.43  total distance:  197953.74654799243
# done with cluster151
# hierarchy:  3  cluster:  152  distance within the cluster:  874.414  total distance:  198828.16054799242
# done with cluster152
# hierarchy:  3  cluster:  153  distance within the cluster:  900.807  total distance:  199728.96754799242
# done with cluster153
# hierarchy:  3  cluster:  154  distance within the cluster:  697.214  total distance:  200426.18154799243
# done with cluster154
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# hierarchy:  3  cluster:  160  distance within the cluster:  604.138  total distance:  203093.10668504133
# done with cluster160
# 1662.0770138594662
# 4100.304866714181
# 710.6335201775947
# 657.6473218982952
# 250.0
# 1012.4228365658294
# 851.46931829632
# 701.78344238091
# 1442.2205101855957
# 657.6473218982952
# 851.46931829632
# 3405.87727318528
# 1484.9242404917497
# 1795.1323071016243
# 522.0153254455275
# 587.2307893835268
# 269.2582403567252
# 782.6237921249264
# 743.3034373659252
# 250.0
# 806.2257748298549
# 1000.0
# 509.9019513592785
# 1557.2411502397438
# 1059.4810050208546
# 1241.974234837422
# 2909.467305195231
# 304.138126514911
# 424.26406871192853
# 1200.0
# 1323.8202294873727
# 996.2429422585637
# 1786.7568385205639
# 618.4658438426491
# 939.4147114027968
# 820.0609733428363
# 873.212459828649
# 790.5694150420949
# 500.0
# 300.0
# 600.0
# 751.6648189186454
# 961.7692030835673
# 1533.7861650177967
# 1188.4864324004714
# 1323.8202294873727
# 996.2429422585637
# 1092.0164833920778
# 474.3416490252569
# 1216.552506059644
# 500.0
# 1303.8404810405298
# 982.344135219425
# 2420.7436873820407
# 538.5164807134504
# 789.4327077085164
# 640.3124237432849
# 790.5694150420949
# 626.4982043070834
# 1274.7548783981963
# 1105.4193774310272
# 901.3878188659974
# 4390.899680020029
# 1118.033988749895
# 701.78344238091
# 626.4982043070834
# 851.46931829632
# 1746.424919657298
# 667.0832032063167
# 565.685424949238
# 680.0735254367721
# 158.11388300841898
# 6304.958366238432
# 666.6363326432186
# 355.58402663786796
# 782.6237921249264
# 1503.3296378372909
# 1916.37678967368
# 2647.6404589747453
# 851.46931829632
# 1718.2840277439582
# 608.276253029822
# 1209.3386622447824
# 838.1527307120105
# 811.4542500967013
# 3891.336531321854
# 657.6473218982952
# 851.46931829632
# 1029.5630140987
# 430.11626335213134
# 657.6473218982952
# 250.0
# 1012.4228365658294
# 1001.2492197250393
# 701.78344238091
# 2600.4807247891686
# 1140.175425099138
# 1421.2853337736233
# 1054.7511554864493
# 291.547594742265
# 1029.5630140987
# 500.0
# 1030.7764064044152
# 780.8354500149184
# 2951.694428629088
# 583.09518948453
# 651.9202405202649
# 1154.3396380615195
# 934.0770846134702
# 756.6372975210778
# 3871.046370169182
# 801.5609770940698
# 500.0
# 1051.189802081432
# 1350.9256086106295
# 300.0
# 1012.4228365658294
# 1480.7092894960847
# 514.78150704935
# 961.7692030835673
# 640.3124237432849
# 2227.6669409945466
# 874.642784226795
# 832.1658488546619
# 1188.4864324004714
# 424.26406871192853
# 304.138126514911
# 2610.0766272276373
# 424.26406871192853
# 657.6473218982952
# 1101.135777277262
# 955.24865872714
# 680.0735254367721
# 886.0022573334675
# 1795.1323071016243
# 790.5694150420949
# 651.9202405202649
# 921.9544457292888
# 2976.995129320839
# 943.3981132056604
# 522.0153254455275
# 509.9019513592785
# 1453.4441853748633
# 1390.1438774457845
# 538.5164807134504
# 789.4327077085164
# 471.6990566028302
# 1054.7511554864493
# 626.4982043070834
# 1274.7548783981963
# 356.02247120090607
# 2837.6927247325425
# 1916.37678967368
# 522.0153254455275
# 498.8025661521801
# 355.58402663786796
# 782.6237921249264
# 1360.1470508735442
# 1110.1801655587258
# 746.4971533770239
# Ising Max time = 3.3384 seconds  /  0
# Max/Min number of Ising Macro MAC Operations =  28556  /  0
# Max/Min number of Ising Macro RandomFlip Operations =  2596  /  0
# total_traveling_distance:  379737.0891154894
# Irand:  48 Cool:  0.001 Factor:  0.9  Threshold:  0  Patience:  10000  ttd:  379737.0891154894  nMAC:  83072  nRandFlip:  7788

# %%
route = np.array(route_btw_clusters)
sol_route = np.array(sol_route)
for n in range(int(len(route_btw_clusters)/2)-1):
    plt.plot(route[2*n+1:2*(n+1)+1,0], route[2*n+1:2*(n+1)+1,1], '-')
plt.scatter(sol_route[:,0], sol_route[:,1], c=sys2_labels[n_hierarchies][:], s=20)

colors = 'rbk'
sol_route_ex = sol_route_ex[1:]
for H in range(len(sol_route_ex)):
    for n in range(len(sol_route_ex[H])):
        plt.text(sol_route_ex[H][n][0],sol_route_ex[H][n][1], str(n+1), fontsize = 10*(len(sol_route_ex)-H), color = colors[H])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 11
#       9 for H in range(len(sol_route_ex)):
#      10     for n in range(len(sol_route_ex[H])):
# ---> 11         plt.text(sol_route_ex[H][n][0],sol_route_ex[H][n][1], str(n+1), fontsize = 10*(len(sol_route_ex)-H), color = colors[H])
#      12 plt.show()
#
# TypeError: 'float' object is not subscriptable

# %%
from math import sin, cos, sqrt, atan2, radians
def compute_geo(p1,p2):
    R = 6373.0
    
    lat1 = radians(float(p1[0]))
    lon1 = radians(float(p1[1]))
    lat2 = radians(float(p2[0]))
    lon2 = radians(float(p2[1]))
    
    dlon = lon2 - lon1
    dlat = lat2 -lat1

    a = sin(dlat/2)**2 + cos(lat1)*cos(lat2)*sin(dlon/2)**2
    c = 2*atan2(sqrt(a),sqrt(1-a))
    dist = R*c
    return dist

# %%
coord_geo == False
if coord_geo == True:
#     test = np.load("sys2clusters_" + str(x) + "/sol_table.npy", allow_pickle=True)
    for i in range(len(test)):
        print(i)
        for j in range(len(test[i])):
            geo_dist = 0
            li = test[i][j][1]
            for idx,elem in enumerate(li):
                thiscity = elem
                nextcity = li[(idx+1)%len(li)]
                geo_dist += compute_geo(thiscity, nextcity)
            test[i][j][2] = geo_dist 
            print(geo_dist)
        np.save("sys2clusters_" + str(x) + "/sol_table" ,test)

# %% [markdown]
# mport pdb; pdb.set_trace()

# %%
## Sangmin edited

print(X_coord.shape)
print(Y_coord.shape)
print(x)
with open("tsp" + x + "_pyconcorde.txt", "w") as f:
    solver = TSPSolver.from_data(X_coord, Y_coord, norm="EUC_2D")  
    solution = solver.solve()
    f.write( str(" ") + str('output') + str(" ") )
    f.write( str("solution found? ") + str(solution.found_tour) + str(" ") )
    f.write( str("Optimal value? ") + str(solution.optimal_value) + str(" ") )
    f.write( str(" ").join( str(node_idx+1) for node_idx in solution.tour) )
    f.write( str(" ") + str(solution.tour[0]+1) + str(" ") )
# Out:
# (1001,)
# (1001,)
# pr1002
# Problem Name: 3318e975dace46aaa9034d0a9d81d32b
# Problem Type: TSP
# Number of Nodes: 1001
# Rounded Euclidean Norm (CC_EUCLIDEAN)
# CCtsp_solve_dat ...
# Finding a good tour for compression ...
# linkern ...
# Starting Cycle: 304860
#    0 Steps   Best: 263521   0.01 seconds
#    2 Steps   Best: 263455   0.01 seconds
#    3 Steps   Best: 263423   0.01 seconds
#    6 Steps   Best: 262935   0.01 seconds
#    7 Steps   Best: 262928   0.01 seconds
#   10 Steps   Best: 262839   0.01 seconds
#   11 Steps   Best: 262622   0.01 seconds
#   13 Steps   Best: 262548   0.01 seconds
#   14 Steps   Best: 262418   0.01 seconds
#   15 Steps   Best: 262373   0.01 seconds
#   17 Steps   Best: 261715   0.02 seconds
#   19 Steps   Best: 261708   0.02 seconds
#   20 Steps   Best: 261685   0.02 seconds
#   24 Steps   Best: 261106   0.02 seconds
#   29 Steps   Best: 260695   0.02 seconds
#   34 Steps   Best: 260651   0.02 seconds
#   39 Steps   Best: 260642   0.03 seconds
#   43 Steps   Best: 260437   0.03 seconds
#   46 Steps   Best: 260411   0.03 seconds
#   53 Steps   Best: 260396   0.03 seconds
#   54 Steps   Best: 260298   0.03 seconds
#   57 Steps   Best: 260257   0.03 seconds
#   64 Steps   Best: 260075   0.04 seconds
#   68 Steps   Best: 259862   0.04 seconds
#   74 Steps   Best: 259829   0.04 seconds
#   77 Steps   Best: 259780   0.04 seconds
#  102 Steps   Best: 259771   0.05 seconds
#  108 Steps   Best: 259729   0.05 seconds
#  118 Steps   Best: 259697   0.06 seconds
#  140 Steps   Best: 259690   0.06 seconds
#  226 Steps   Best: 259495   0.09 seconds
#  241 Steps   Best: 259481   0.10 seconds
#  246 Steps   Best: 259401   0.11 seconds
#  249 Steps   Best: 259393   0.11 seconds
#  255 Steps   Best: 259244   0.11 seconds
#  261 Steps   Best: 259197   0.11 seconds
#  298 Steps   Best: 259188   0.12 seconds
#  311 Steps   Best: 259180   0.13 seconds
#  354 Steps   Best: 259101   0.15 seconds
#  358 Steps   Best: 259045   0.15 seconds
#  433 Steps   Best: 259038   0.18 seconds
#  447 Steps   Best: 259005   0.18 seconds
#  500 Total Steps.
# Best cycle length: 259005
# Lin-Kernighan Running Time: 0.20
# LK Initial Run: 259005.0
# LK Run 0: 259008.0
# LK Run from best tour: 258665.0
# Time to find compression tour: 0.68 (seconds)
# Set initial upperbound to 258665 (from tour)
# Fractional Matching: 248501.5
# Initial Running Time: 0.00 (seconds)
# Basis Running Time: 0.00 (seconds)
# Total fractional matching time: 0.00 (seconds)
# Total Time for first_lp: 0.00 (seconds)
# Setting upperbound to the initial bound: 258665.00
# Loading lp...done in 0.00 seconds
# LP has:  1001 rows  1672 columns  3344 nonzeros
# Dual opt returned after 0.00 seconds
# Initial LP value: 248501.500000
# Setting tolerances: next cuts 101.6350 next round 10.1635
# CCtsp_init_edgegenerator (50)
# . 29049 edges
# LP has:  1001 rows  1672 columns  3344 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  1001 rows  1672 columns  3344 nonzeros
# Found 65 connect cuts in 0.00 seconds
#   Add 65 cuts (Total 43), LP: 254521.500000 (0.00 seconds)
# Found 11 segment cuts in 0.00 seconds
#   Add 11 cuts (Total 50), LP: 254712.250000 (0.00 seconds)
# Found 20 Fast Blossoms in 0.00 seconds
#   Add 20 cuts (Total 68), LP: 255125.250000 (0.00 seconds)
# Found 19 Groetschel-Holland Blossoms in 0.00 seconds
#   Add 19 cuts (Total 85), LP: 255407.550000 (0.00 seconds)
# Block Combs
#   Type 0: 13 cuts  2.0000 max violation  0.00 seconds
#   Type 1: 6 cuts  2.5000 max violation  0.00 seconds
#   Type 2: 6 cuts  3.0000 max violation  0.00 seconds
#   Type 3: 2 cuts  2.0000 max violation  0.00 seconds
#   Type 4: 0 cuts  0.0000 max violation  0.00 seconds
#   Type 5: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 1: 8 cuts  2.5000 max violation  0.00 seconds
#   Olaf 2: 9 cuts  2.0000 max violation  0.00 seconds
#   Olaf 3: 5 cuts  1.3000 max violation  0.00 seconds
#   Olaf 4: 5 cuts  1.3000 max violation  0.00 seconds
#   Total Time in block_combs: 0.01
# Found 54 block_combs in 0.01 seconds
#   Add 54 cuts (Total 92), LP: 255452.166667 (0.00 seconds)
# Found 22 exact subtours in 0.00 seconds
#   Add 22 cuts (Total 110), LP: 256320.283333 (0.00 seconds)
# Found 44 tighten_lp cuts (viol 2.0000) in 0.00 seconds
#   Add 44 cuts (Total 127), LP: 256527.750000 (0.00 seconds)
# Found 23 CLOSE tighten_lp cuts (viol 0.5000) in 0.00 seconds
#   Add 23 cuts (Total 137), LP: 256914.333333 (0.00 seconds)
# Found 21 double deckers (viol 2.3333) in 0.01 seconds
#   Add 21 cuts (Total 143), LP: 256939.916667 (0.00 seconds)
# Found  7 CLOSE double deckers (viol 0.7500) in 0.00 seconds
#   Add  7 cuts (Total 144), LP: 256947.166667 (0.00 seconds)
# Found 15 Handling Inequalities (viol 1.0833) in 0.01 seconds
#   Add 15 cuts (Total 151), LP: 256977.697619 (0.00 seconds)
# Found  6 teethed combs (viol 1.0000) in 0.00 seconds
#   Add  6 cuts (Total 156), LP: 257009.733333 (0.00 seconds)
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.01 seconds (0.01 total in 1 calls)
# Time for Add edges optimize: 0.01 seconds (0.01 total in 2 calls)
# Time for Add edges optimize: 0.00 seconds (0.02 total in 3 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.00 seconds (0.02 total in 4 calls)
# Time for Add edges optimize: 0.00 seconds (0.02 total in 5 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.00 seconds (0.02 total in 6 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.00 seconds (0.02 total in 7 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges: 0.02 seconds (0.02 total in 1 calls)
# (SPARSE) 424 edges added, penalty 0.000000, val 248088.937500
# Time for Sparse edge check: 0.02 seconds (0.02 total in 1 calls)
# Write Pool: 69 cuts
# Time for Cutting inside loop: 0.09 seconds (0.09 total in 1 calls)
# LP has:  1157 rows  2096 columns  9308 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  1157 rows  2096 columns  5770 nonzeros
# Found 57 connect cuts in 0.00 seconds
#   Add 57 cuts (Total 192), LP: 252928.333333 (0.00 seconds)
# Found 25 segment cuts in 0.00 seconds
#   Add 25 cuts (Total 209), LP: 253686.116667 (0.00 seconds)
# Found 26 Fast Blossoms in 0.00 seconds
#   Add 26 cuts (Total 230), LP: 254079.876389 (0.00 seconds)
# Found 22 Groetschel-Holland Blossoms in 0.00 seconds
#   Add 22 cuts (Total 242), LP: 254219.379630 (0.00 seconds)
# Block Combs
#   Type 0: 41 cuts  1.4167 max violation  0.00 seconds
#   Type 1: 40 cuts  1.4167 max violation  0.00 seconds
#   Type 2: 34 cuts  2.2500 max violation  0.00 seconds
#   Type 3: 23 cuts  2.2500 max violation  0.00 seconds
#   Type 4: 23 cuts  3.2500 max violation  0.00 seconds
#   Type 5: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 1: 27 cuts  1.0000 max violation  0.00 seconds
#   Olaf 2: 31 cuts  2.0000 max violation  0.00 seconds
#   Olaf 3: 10 cuts  3.0000 max violation  0.00 seconds
#   Olaf 4: 18 cuts  3.0000 max violation  0.00 seconds
#   Total Time in block_combs: 0.02
# Found 247 block_combs in 0.02 seconds
#   Add 247 cuts (Total 272), LP: 254372.501302 (0.01 seconds)
# Found 15 exact subtours in 0.00 seconds
#   Add 15 cuts (Total 281), LP: 256054.722222 (0.01 seconds)
# Found 79 tighten_lp cuts (viol 1.1111) in 0.01 seconds
#   Add 79 cuts (Total 304), LP: 256235.895833 (0.01 seconds)
# Found 41 CLOSE tighten_lp cuts (viol 0.5000) in 0.00 seconds
#   Add 41 cuts (Total 315), LP: 256410.375000 (0.01 seconds)
# Found 63 double deckers (viol 8.0000) in 0.02 seconds
#   Add 63 cuts (Total 324), LP: 256461.871970 (0.01 seconds)
# Found 15 CLOSE double deckers (viol 1.0556) in 0.01 seconds
#   Add 15 cuts (Total 306), LP: 256519.211364 (0.00 seconds)
# Found 15 Handling Inequalities (viol 3.3750) in 0.01 seconds
#   Add 15 cuts (Total 313), LP: 256546.863570 (0.00 seconds)
# Found 25 teethed combs (viol 1.7500) in 0.00 seconds
#   Add 25 cuts (Total 323), LP: 256602.692980 (0.00 seconds)
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.02 seconds (0.04 total in 8 calls)
# Time for Add edges optimize: 0.00 seconds (0.04 total in 9 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.00 seconds (0.04 total in 10 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges: 0.02 seconds (0.05 total in 2 calls)
# (SPARSE) 119 edges added, penalty 0.000000, val 256013.725694
# Time for Sparse edge check: 0.02 seconds (0.05 total in 2 calls)
# Write Pool: 201 cuts
# Time for Cutting inside loop: 0.16 seconds (0.25 total in 2 calls)
# LP has:  1324 rows  2215 columns  17759 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  1324 rows  2215 columns  7883 nonzeros
# Found  2 pool cuts (viol 1.0000) in 0.00 seconds
#   Add  2 cuts (Total 325), LP: 256033.225694 (0.01 seconds)
# Found 14 connect cuts in 0.00 seconds
#   Add 14 cuts (Total 327), LP: 256141.475694 (0.00 seconds)
# Found 36 segment cuts in 0.00 seconds
#   Add 36 cuts (Total 337), LP: 256377.812500 (0.01 seconds)
# Found 22 Fast Blossoms in 0.00 seconds
#   Add 22 cuts (Total 347), LP: 256563.375000 (0.01 seconds)
# Found 25 Groetschel-Holland Blossoms in 0.00 seconds
#   Add 23 cuts (Total 354), LP: 256708.766667 (0.01 seconds)
# Block Combs
#   Type 0: 30 cuts  2.0000 max violation  0.00 seconds
#   Type 1: 17 cuts  2.0000 max violation  0.00 seconds
#   Type 2: 12 cuts  2.0000 max violation  0.00 seconds
#   Type 4: 10 cuts  2.0000 max violation  0.00 seconds
#   Type 5: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 1: 20 cuts  2.0000 max violation  0.00 seconds
#   Olaf 2: 18 cuts  2.0000 max violation  0.00 seconds
#   Olaf 3: 8 cuts  1.4333 max violation  0.00 seconds
#   Olaf 4: 6 cuts  0.8333 max violation  0.00 seconds
#   Total Time in block_combs: 0.03
# Found 121 block_combs in 0.03 seconds
#   Add 121 cuts (Total 368), LP: 256832.207939 (0.02 seconds)
# Found  2 exact subtours in 0.00 seconds
#   Add  2 cuts (Total 366), LP: 256881.025728 (0.00 seconds)
# Found 87 tighten_lp cuts (viol 1.0270) in 0.01 seconds
#   Add 87 cuts (Total 394), LP: 257056.600000 (0.01 seconds)
# Found 46 CLOSE tighten_lp cuts (viol 0.2500) in 0.01 seconds
#   Add 46 cuts (Total 408), LP: 257141.750000 (0.01 seconds)
# Found 38 double deckers (viol 3.0000) in 0.07 seconds
#   Add 38 cuts (Total 397), LP: 257185.842857 (0.01 seconds)
# Found 23 CLOSE double deckers (viol 1.0000) in 0.01 seconds
#   Add 23 cuts (Total 404), LP: 257269.222222 (0.01 seconds)
# Found 21 Handling Inequalities (viol 1.3333) in 0.02 seconds
#   Add 21 cuts (Total 399), LP: 257271.077778 (0.00 seconds)
# Found 15 teethed combs (viol 1.1000) in 0.01 seconds
#   Add 15 cuts (Total 399), LP: 257356.931176 (0.01 seconds)
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.01 seconds (0.06 total in 11 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.00 seconds (0.06 total in 12 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges: 0.02 seconds (0.06 total in 3 calls)
# (SPARSE) 106 edges added, penalty -0.000000, val 257021.250000
# Time for Sparse edge check: 0.02 seconds (0.06 total in 3 calls)
# Write Pool: 326 cuts
# Time for Cutting inside loop: 0.29 seconds (0.54 total in 3 calls)
# LP has:  1400 rows  2321 columns  16746 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  1400 rows  2321 columns  8942 nonzeros
# Found  2 pool cuts (viol 1.0000) in 0.00 seconds
#   Add  2 cuts (Total 401), LP: 257021.250000 (0.01 seconds)
# Found  3 connect cuts in 0.00 seconds
#   Add  3 cuts (Total 390), LP: 257118.666667 (0.00 seconds)
# Found  8 segment cuts in 0.00 seconds
#   Add  8 cuts (Total 393), LP: 257143.710938 (0.01 seconds)
# Found 12 Fast Blossoms in 0.00 seconds
#   Add 12 cuts (Total 401), LP: 257230.774306 (0.01 seconds)
# Found 10 Groetschel-Holland Blossoms in 0.00 seconds
#   Add 10 cuts (Total 402), LP: 257290.185190 (0.01 seconds)
# Block Combs
#   Type 0: 43 cuts  1.9130 max violation  0.00 seconds
#   Type 1: 25 cuts  0.9565 max violation  0.00 seconds
#   Type 2: 19 cuts  0.8021 max violation  0.00 seconds
#   Type 4: 15 cuts  0.5217 max violation  0.00 seconds
#   Type 5: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 1: 17 cuts  1.9130 max violation  0.00 seconds
#   Olaf 2: 14 cuts  1.0435 max violation  0.00 seconds
#   Olaf 3: 1 cuts  0.8696 max violation  0.00 seconds
#   Olaf 4: 1 cuts  0.8696 max violation  0.00 seconds
#   Total Time in block_combs: 0.03
# Found 135 block_combs in 0.03 seconds
#   Add 135 cuts (Total 421), LP: 257339.164651 (0.01 seconds)
# Found  2 exact subtours in 0.00 seconds
#   Add  2 cuts (Total 417), LP: 257357.664651 (0.00 seconds)
# Found 86 tighten_lp cuts (viol 0.9655) in 0.01 seconds
#   Add 86 cuts (Total 433), LP: 257446.445238 (0.01 seconds)
# Found 48 CLOSE tighten_lp cuts (viol 0.5000) in 0.01 seconds
#   Add 48 cuts (Total 450), LP: 257513.514867 (0.02 seconds)
# Found 79 double deckers (viol 2.0000) in 0.02 seconds
#   Add 79 cuts (Total 458), LP: 257591.732719 (0.01 seconds)
# Found 36 CLOSE double deckers (viol 1.0000) in 0.02 seconds
#   Add 36 cuts (Total 456), LP: 257620.597057 (0.01 seconds)
# Found  5 Handling Inequalities (viol 0.6986) in 0.02 seconds
#   Add  5 cuts (Total 455), LP: 257623.719380 (0.00 seconds)
# Found 29 teethed combs (viol 0.6667) in 0.01 seconds
#   Add 29 cuts (Total 460), LP: 257662.447452 (0.01 seconds)
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.03 seconds (0.08 total in 13 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.00 seconds (0.09 total in 14 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges: 0.03 seconds (0.09 total in 4 calls)
# (SPARSE) 40 edges added, penalty -0.000000, val 257591.141278
# Time for Sparse edge check: 0.03 seconds (0.09 total in 4 calls)
# Write Pool: 449 cuts
# Time for Cutting inside loop: 0.27 seconds (0.81 total in 4 calls)
# LP has:  1461 rows  2361 columns  18017 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  1461 rows  2361 columns  10195 nonzeros
# Found  7 pool cuts (viol 0.5500) in 0.00 seconds
#   Add  7 cuts (Total 455), LP: 257596.678442 (0.02 seconds)
# Found  0 connect cuts in 0.00 seconds
# Found 43 segment cuts in 0.00 seconds
#   Add 43 cuts (Total 456), LP: 257641.318438 (0.01 seconds)
# Found  4 Fast Blossoms in 0.00 seconds
#   Add  4 cuts (Total 458), LP: 257666.720908 (0.01 seconds)
# Found 10 Groetschel-Holland Blossoms in 0.00 seconds
#   Add 10 cuts (Total 454), LP: 257701.665598 (0.01 seconds)
# Block Combs
#   Type 0: 41 cuts  1.3333 max violation  0.00 seconds
#   Type 1: 25 cuts  0.9583 max violation  0.00 seconds
#   Type 2: 18 cuts  0.6667 max violation  0.00 seconds
#   Type 4: 10 cuts  0.6667 max violation  0.00 seconds
#   Type 5: 0 cuts  0.0000 max violation  0.01 seconds
#   Olaf 1: 9 cuts  0.5256 max violation  0.01 seconds
#   Olaf 2: 8 cuts  1.0000 max violation  0.01 seconds
#   Olaf 3: 4 cuts  1.4744 max violation  0.00 seconds
#   Olaf 4: 4 cuts  1.4744 max violation  0.00 seconds
#   Total Time in block_combs: 0.04
# Found 119 block_combs in 0.04 seconds
#   Add 119 cuts (Total 462), LP: 257785.319377 (0.04 seconds)
# Found 40 exact subtours in 0.00 seconds
#   Add 40 cuts (Total 462), LP: 257822.819509 (0.02 seconds)
# Found 54 tighten_lp cuts (viol 1.0000) in 0.02 seconds
#   Add 54 cuts (Total 468), LP: 257844.905159 (0.02 seconds)
# Found 33 CLOSE tighten_lp cuts (viol 0.5000) in 0.01 seconds
#   Add 33 cuts (Total 476), LP: 257874.549683 (0.01 seconds)
# Found 42 double deckers (viol 1.4545) in 0.03 seconds
#   Add 42 cuts (Total 476), LP: 257887.017766 (0.01 seconds)
# Found 16 CLOSE double deckers (viol 0.6000) in 0.04 seconds
#   Add 16 cuts (Total 473), LP: 257900.862831 (0.02 seconds)
# Found 20 Handling Inequalities (viol 0.0781) in 0.03 seconds
#   Add 20 cuts (Total 464), LP: 257900.884315 (0.00 seconds)
# Found 22 teethed combs (viol 1.0156) in 0.01 seconds
#   Add 22 cuts (Total 467), LP: 257929.032540 (0.04 seconds)
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.03 seconds (0.12 total in 15 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.00 seconds (0.12 total in 16 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges: 0.04 seconds (0.13 total in 5 calls)
# (SPARSE) 29 edges added, penalty -0.000000, val 257831.644907
# Time for Sparse edge check: 0.04 seconds (0.13 total in 5 calls)
# Write Pool: 518 cuts
# Time for Cutting inside loop: 0.43 seconds (1.25 total in 5 calls)
# LP has:  1468 rows  2390 columns  19512 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  1468 rows  2390 columns  10943 nonzeros
# Found  3 pool cuts (viol 0.1736) in 0.00 seconds
#   Add  3 cuts (Total 466), LP: 257832.677083 (0.02 seconds)
# Found  0 connect cuts in 0.00 seconds
# Found  6 segment cuts in 0.00 seconds
#   Add  6 cuts (Total 451), LP: 257851.833333 (0.01 seconds)
# Found  2 Fast Blossoms in 0.00 seconds
#   Add  2 cuts (Total 441), LP: 257852.604167 (0.01 seconds)
# Found  3 Groetschel-Holland Blossoms in 0.00 seconds
#   Add  3 cuts (Total 439), LP: 257853.585367 (0.00 seconds)
# Block Combs
#   Type 0: 11 cuts  1.0000 max violation  0.00 seconds
#   Type 1: 13 cuts  1.0000 max violation  0.00 seconds
#   Type 2: 16 cuts  1.0000 max violation  0.00 seconds
#   Type 4: 6 cuts  1.0000 max violation  0.00 seconds
#   Type 5: 1 cuts  0.7297 max violation  0.00 seconds
#   Olaf 1: 8 cuts  1.0000 max violation  0.00 seconds
#   Olaf 2: 6 cuts  1.0000 max violation  0.01 seconds
#   Olaf 3: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 4: 0 cuts  0.0000 max violation  0.00 seconds
#   Total Time in block_combs: 0.03
# Found 61 block_combs in 0.03 seconds
#   Add 61 cuts (Total 438), LP: 257906.782143 (0.03 seconds)
# Found 16 exact subtours in 0.00 seconds
#   Add 16 cuts (Total 437), LP: 257914.686639 (0.01 seconds)
# Found 55 tighten_lp cuts (viol 0.5620) in 0.01 seconds
#   Add 55 cuts (Total 445), LP: 257947.095573 (0.04 seconds)
# Found 60 CLOSE tighten_lp cuts (viol 0.1607) in 0.01 seconds
#   Add 60 cuts (Total 448), LP: 257951.875000 (0.01 seconds)
# Found 12 double deckers (viol 3.0000) in 0.05 seconds
#   Add 12 cuts (Total 439), LP: 257958.747153 (0.03 seconds)
# Found 63 CLOSE double deckers (viol 0.3426) in 0.02 seconds
#   Add 63 cuts (Total 440), LP: 257963.500000 (0.01 seconds)
# Found  2 Handling Inequalities (viol 0.1373) in 0.05 seconds
#   Add  2 cuts (Total 439), LP: 257964.221698 (0.00 seconds)
# Found  6 teethed combs (viol 0.3019) in 0.01 seconds
#   Add  6 cuts (Total 440), LP: 257965.333095 (0.01 seconds)
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.03 seconds (0.15 total in 17 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges: 0.03 seconds (0.16 total in 6 calls)
# (SPARSE) 10 edges added, penalty 0.000000, val 257955.511959
# Time for Sparse edge check: 0.03 seconds (0.16 total in 6 calls)
# Write Pool: 569 cuts
# Time for Cutting inside loop: 0.40 seconds (1.64 total in 6 calls)
# LP has:  1441 rows  2400 columns  18833 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  1441 rows  2400 columns  10827 nonzeros
# Found  3 pool cuts (viol 0.0585) in 0.00 seconds
#   Add  2 cuts (Total 440), LP: 257955.542253 (0.02 seconds)
# Found  0 connect cuts in 0.00 seconds
# Found  8 segment cuts in 0.00 seconds
#   Add  8 cuts (Total 438), LP: 257963.455456 (0.01 seconds)
# Found  0 Fast Blossoms in 0.00 seconds
# Found  2 Groetschel-Holland Blossoms in 0.00 seconds
#   Add  2 cuts (Total 436), LP: 257964.908042 (0.01 seconds)
# Block Combs
#   Type 0: 15 cuts  0.5356 max violation  0.00 seconds
#   Type 1: 9 cuts  0.6661 max violation  0.00 seconds
#   Type 2: 6 cuts  0.4155 max violation  0.00 seconds
#   Type 4: 6 cuts  0.4339 max violation  0.00 seconds
#   Type 5: 0 cuts  0.0000 max violation  0.01 seconds
#   Olaf 1: 5 cuts  0.2298 max violation  0.01 seconds
#   Olaf 2: 8 cuts  0.4587 max violation  0.01 seconds
#   Olaf 3: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 4: 0 cuts  0.0000 max violation  0.00 seconds
#   Total Time in block_combs: 0.04
# Found 49 block_combs in 0.04 seconds
#   Add 49 cuts (Total 431), LP: 257971.823314 (0.02 seconds)
# Found 17 exact subtours in 0.00 seconds
#   Add 15 cuts (Total 434), LP: 257973.666353 (0.01 seconds)
# Found 48 tighten_lp cuts (viol 0.3456) in 0.01 seconds
#   Add 48 cuts (Total 437), LP: 257979.798397 (0.03 seconds)
# Found 29 CLOSE tighten_lp cuts (viol 0.0688) in 0.01 seconds
#   Add 29 cuts (Total 442), LP: 257980.974432 (0.01 seconds)
# Found  2 double deckers (viol 0.7500) in 0.03 seconds
#   Add  2 cuts (Total 440), LP: 257981.618182 (0.00 seconds)
# Found  1 CLOSE double deckers (viol 0.2000) in 0.04 seconds
#   Add  1 cuts (Total 441), LP: 257981.618182 (0.00 seconds)
# Found  0 Handling Inequalities (viol -0.0000) in 0.03 seconds
# Found  2 teethed combs (viol 0.4000) in 0.01 seconds
#   Add  2 cuts (Total 438), LP: 257981.646753 (0.00 seconds)
# Found 28 consecutiveones cuts in 0.02 seconds
#   Add 28 cuts (Total 447), LP: 258047.290200 (0.03 seconds)
# localcuts classes(8d)... 273 nodes 433 edges
# localcuts done in 0.00 seconds
# Found  2 LocalCuts in 0.00 seconds
#   Add  2 cuts (Total 443), LP: 258048.064394 (0.00 seconds)
# localcuts classes(9d)... 264 nodes 417 edges
# localcuts done in 0.00 seconds
# Found  1 LocalCuts in 0.00 seconds
#   Add  1 cuts (Total 443), LP: 258048.164394 (0.00 seconds)
# localcuts classes(10d)... 280 nodes 444 edges
# localcuts done in 0.01 seconds
# Found  3 LocalCuts in 0.01 seconds
#   Add  3 cuts (Total 439), LP: 258050.587963 (0.00 seconds)
# localcuts classes(11d)... 195 nodes 311 edges
# localcuts done in 0.00 seconds
# Found  3 LocalCuts in 0.00 seconds
#   Add  3 cuts (Total 434), LP: 258052.763889 (0.01 seconds)
# localcuts classes(12d)... 183 nodes 289 edges
# localcuts done in 0.00 seconds
# Found  5 LocalCuts in 0.00 seconds
#   Add  5 cuts (Total 427), LP: 258055.500000 (0.01 seconds)
# localcuts classes(13d)... 161 nodes 251 edges
# localcuts done in 0.00 seconds
# Found  2 LocalCuts in 0.00 seconds
#   Add  2 cuts (Total 426), LP: 258058.722115 (0.01 seconds)
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.02 seconds (0.17 total in 18 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges: 0.02 seconds (0.18 total in 7 calls)
# (SPARSE) 13 edges added, penalty 0.000000, val 258054.028133
# Time for Sparse edge check: 0.02 seconds (0.18 total in 7 calls)
# Write Pool: 627 cuts
# Time for Cutting inside loop: 0.44 seconds (2.08 total in 7 calls)
# LP has:  1427 rows  2413 columns  15080 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  1427 rows  2413 columns  10430 nonzeros
# Found 24 pool cuts (viol 2.0000) in 0.00 seconds
#   Add 24 cuts (Total 433), LP: 258085.430800 (0.05 seconds)
# Found  0 connect cuts in 0.00 seconds
# Found 19 segment cuts in 0.00 seconds
#   Add 19 cuts (Total 436), LP: 258090.700549 (0.01 seconds)
# Found  0 Fast Blossoms in 0.00 seconds
# Found  2 Groetschel-Holland Blossoms in 0.00 seconds
#   Add  2 cuts (Total 424), LP: 258090.781746 (0.00 seconds)
# Block Combs
#   Type 0: 11 cuts  0.3333 max violation  0.00 seconds
#   Type 1: 4 cuts  0.2857 max violation  0.00 seconds
#   Type 2: 6 cuts  0.6429 max violation  0.00 seconds
#   Type 4: 3 cuts  0.1111 max violation  0.00 seconds
#   Type 5: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 1: 3 cuts  0.2857 max violation  0.00 seconds
#   Olaf 2: 5 cuts  0.2857 max violation  0.00 seconds
#   Olaf 3: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 4: 0 cuts  0.0000 max violation  0.00 seconds
#   Total Time in block_combs: 0.02
# Found 32 block_combs in 0.02 seconds
#   Add 32 cuts (Total 431), LP: 258094.331959 (0.02 seconds)
# Found 17 exact subtours in 0.00 seconds
#   Add 14 cuts (Total 439), LP: 258097.725182 (0.02 seconds)
# Found 38 tighten_lp cuts (viol 0.5000) in 0.01 seconds
#   Add 38 cuts (Total 450), LP: 258109.703152 (0.04 seconds)
# Found 56 CLOSE tighten_lp cuts (viol 0.3559) in 0.01 seconds
#   Add 56 cuts (Total 455), LP: 258126.378261 (0.02 seconds)
# Found 49 double deckers (viol 0.6667) in 0.03 seconds
#   Add 49 cuts (Total 456), LP: 258128.008816 (0.01 seconds)
# Found 34 CLOSE double deckers (viol 0.3333) in 0.03 seconds
#   Add 34 cuts (Total 463), LP: 258129.753097 (0.02 seconds)
# Found 13 Handling Inequalities (viol 0.0599) in 0.05 seconds
#   Add 13 cuts (Total 461), LP: 258129.981407 (0.01 seconds)
# Found 38 teethed combs (viol 0.2726) in 0.01 seconds
#   Add 38 cuts (Total 475), LP: 258133.371656 (0.03 seconds)
# Found 35 consecutiveones cuts in 0.03 seconds
#   Add 29 cuts (Total 484), LP: 258167.954776 (0.03 seconds)
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.10 seconds (0.27 total in 19 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.00 seconds (0.27 total in 20 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges: 0.11 seconds (0.29 total in 8 calls)
# (SPARSE) 18 edges added, penalty -0.000000, val 258165.257587
# Time for Sparse edge check: 0.11 seconds (0.29 total in 8 calls)
# Write Pool: 700 cuts
# Time for Cutting inside loop: 0.58 seconds (2.66 total in 8 calls)
# LP has:  1485 rows  2431 columns  20058 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  1485 rows  2431 columns  12219 nonzeros
# Found  9 pool cuts (viol 0.3436) in 0.00 seconds
#   Add  9 cuts (Total 490), LP: 258168.279486 (0.05 seconds)
# Found  0 connect cuts in 0.00 seconds
# Found 14 segment cuts in 0.00 seconds
#   Add 12 cuts (Total 493), LP: 258169.020588 (0.01 seconds)
# Found  0 Fast Blossoms in 0.00 seconds
# Found  1 Groetschel-Holland Blossoms in 0.00 seconds
#   Add  1 cuts (Total 484), LP: 258169.510204 (0.01 seconds)
# Block Combs
#   Type 0: 3 cuts  0.2857 max violation  0.00 seconds
#   Type 1: 3 cuts  0.2857 max violation  0.00 seconds
#   Type 2: 1 cuts  0.1088 max violation  0.00 seconds
#   Type 5: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 1: 1 cuts  0.2857 max violation  0.00 seconds
#   Olaf 2: 1 cuts  0.2449 max violation  0.00 seconds
#   Olaf 3: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 4: 0 cuts  0.0000 max violation  0.00 seconds
#   Total Time in block_combs: 0.02
# Found  9 block_combs in 0.02 seconds
#   Add  9 cuts (Total 479), LP: 258171.128675 (0.01 seconds)
# Found  6 exact subtours in 0.00 seconds
#   Add  6 cuts (Total 479), LP: 258173.018692 (0.01 seconds)
# Found 23 tighten_lp cuts (viol 0.6168) in 0.06 seconds
#   Add 23 cuts (Total 482), LP: 258175.908778 (0.04 seconds)
# Found 39 CLOSE tighten_lp cuts (viol 0.2607) in 0.02 seconds
#   Add 39 cuts (Total 492), LP: 258188.005465 (0.06 seconds)
# Found 87 double deckers (viol 0.4446) in 0.03 seconds
#   Add 87 cuts (Total 495), LP: 258189.903005 (0.03 seconds)
# Found 23 CLOSE double deckers (viol 0.1052) in 0.06 seconds
#   Add 23 cuts (Total 487), LP: 258190.454545 (0.01 seconds)
# Found  4 Handling Inequalities (viol 0.0455) in 0.02 seconds
#   Add  4 cuts (Total 479), LP: 258190.552857 (0.01 seconds)
# Found 10 teethed combs (viol 0.3636) in 0.02 seconds
#   Add 10 cuts (Total 481), LP: 258191.694173 (0.02 seconds)
# Found 21 consecutiveones cuts in 0.03 seconds
#   Add 21 cuts (Total 487), LP: 258200.400000 (0.04 seconds)
# localcuts classes(8d)... 159 nodes 255 edges
# localcuts done in 0.01 seconds
# Found  2 LocalCuts in 0.01 seconds
#   Add  2 cuts (Total 488), LP: 258200.642946 (0.01 seconds)
# localcuts classes(9d)... 270 nodes 436 edges
# localcuts done in 0.00 seconds
# Found  2 LocalCuts in 0.00 seconds
#   Add  2 cuts (Total 487), LP: 258201.877967 (0.01 seconds)
# localcuts classes(10d)... 271 nodes 439 edges
# localcuts done in 0.00 seconds
# Found  2 LocalCuts in 0.00 seconds
#   Add  2 cuts (Total 478), LP: 258202.065737 (0.02 seconds)
# localcuts classes(11d)... 295 nodes 483 edges
# localcuts done in 0.00 seconds
# Found  1 LocalCuts in 0.00 seconds
#   Add  1 cuts (Total 463), LP: 258202.291286 (0.03 seconds)
# localcuts classes(12d)... 323 nodes 545 edges
# localcuts done in 0.00 seconds
# Found  2 LocalCuts in 0.00 seconds
#   Add  2 cuts (Total 456), LP: 258202.345481 (0.01 seconds)
# localcuts classes(13d)... 329 nodes 555 edges
# localcuts done in 0.00 seconds
# Found  1 LocalCuts in 0.00 seconds
#   Add  1 cuts (Total 452), LP: 258202.354430 (0.00 seconds)
# localcuts classes(14d)... 310 nodes 523 edges
# localcuts done in 0.00 seconds
# Found  1 LocalCuts in 0.00 seconds
#   Add  1 cuts (Total 451), LP: 258202.364930 (0.00 seconds)
# localcuts classes(15d)... 301 nodes 506 edges
# localcuts done in 0.00 seconds
# Found  0 LocalCuts in 0.00 seconds
# localcuts classes(16d)... 301 nodes 506 edges
# localcuts done in 0.01 seconds
# Found  1 LocalCuts in 0.01 seconds
#   Add  1 cuts (Total 446), LP: 258204.767759 (0.01 seconds)
# localcuts spheres(6d/8d)... 262 nodes 423 edges
# localcuts done in 0.03 seconds
# Found  5 LocalCuts in 0.03 seconds
#   Add  5 cuts (Total 434), LP: 258206.115727 (0.00 seconds)
# localcuts spheres(7d/9d)... 261 nodes 421 edges
# localcuts done in 0.03 seconds
# Found  9 LocalCuts in 0.03 seconds
#   Add  9 cuts (Total 436), LP: 258219.662921 (0.02 seconds)
# localcuts spheres(8d/10d)... 161 nodes 263 edges
# localcuts done in 0.02 seconds
# Found  3 LocalCuts in 0.02 seconds
#   Add  3 cuts (Total 434), LP: 258220.564647 (0.03 seconds)
# localcuts spheres(9d/11d)... 310 nodes 509 edges
# localcuts done in 0.03 seconds
# Found  4 LocalCuts in 0.03 seconds
#   Add  4 cuts (Total 434), LP: 258221.010929 (0.01 seconds)
# localcuts spheres(10d/12d)... 259 nodes 421 edges
# localcuts done in 0.03 seconds
# Found  3 LocalCuts in 0.03 seconds
#   Add  3 cuts (Total 426), LP: 258221.147506 (0.01 seconds)
# localcuts spheres(11d/13d)... 255 nodes 415 edges
# localcuts done in 0.05 seconds
# Found  5 LocalCuts in 0.05 seconds
#   Add  5 cuts (Total 428), LP: 258226.132119 (0.02 seconds)
# localcuts spheres(12d/14d)... 349 nodes 585 edges
# localcuts done in 0.11 seconds
# Found 36 LocalCuts in 0.11 seconds
#   Add 36 cuts (Total 434), LP: 258230.169355 (0.02 seconds)
# localcuts spheres(13d/15d)... 107 nodes 178 edges
# localcuts done in 0.04 seconds
# Found 18 LocalCuts in 0.04 seconds
#   Add 18 cuts (Total 436), LP: 258231.114659 (0.01 seconds)
# localcuts spheres(14d/16d)... 136 nodes 225 edges
# localcuts done in 0.04 seconds
# Found 26 LocalCuts in 0.04 seconds
#   Add 26 cuts (Total 439), LP: 258232.309535 (0.02 seconds)
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.06 seconds (0.33 total in 21 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges: 0.06 seconds (0.35 total in 9 calls)
# (SPARSE) 14 edges added, penalty 0.000000, val 258224.074267
# Time for Sparse edge check: 0.06 seconds (0.35 total in 9 calls)
# Write Pool: 793 cuts
# Time for Cutting inside loop: 1.24 seconds (3.90 total in 9 calls)
# LP has:  1440 rows  2445 columns  22048 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  1440 rows  2445 columns  11541 nonzeros
# Found  5 pool cuts (viol 0.2959) in 0.00 seconds
#   Add  5 cuts (Total 443), LP: 258225.712380 (0.06 seconds)
# Found  0 connect cuts in 0.00 seconds
# Found 38 segment cuts in 0.00 seconds
#   Add 33 cuts (Total 445), LP: 258228.070892 (0.03 seconds)
# Found  0 Fast Blossoms in 0.00 seconds
# Found  3 Groetschel-Holland Blossoms in 0.00 seconds
#   Add  2 cuts (Total 444), LP: 258228.746660 (0.01 seconds)
# Block Combs
#   Type 0: 21 cuts  0.0648 max violation  0.01 seconds
#   Type 1: 16 cuts  0.0648 max violation  0.01 seconds
#   Type 2: 13 cuts  0.0648 max violation  0.01 seconds
#   Type 5: 0 cuts  0.0000 max violation  0.01 seconds
#   Olaf 1: 10 cuts  0.0355 max violation  0.01 seconds
#   Olaf 2: 11 cuts  0.0232 max violation  0.01 seconds
#   Olaf 3: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 4: 0 cuts  0.0001 max violation  0.00 seconds
#   Total Time in block_combs: 0.05
# Found 71 block_combs in 0.05 seconds
#   Add 71 cuts (Total 452), LP: 258229.139036 (0.01 seconds)
# Found  5 exact subtours in 0.00 seconds
#   Add  5 cuts (Total 455), LP: 258229.338525 (0.01 seconds)
# Found 20 tighten_lp cuts (viol 0.1641) in 0.02 seconds
#   Add 20 cuts (Total 455), LP: 258231.000000 (0.01 seconds)
# Integral Solution of Value 258231.00
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.00 seconds (0.34 total in 22 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges: 0.01 seconds (0.36 total in 10 calls)
# (SPARSE) 1 edges added, penalty -0.000000, val 258231.000000
# Time for Sparse edge check: 0.01 seconds (0.36 total in 10 calls)
# Write Pool: 806 cuts
# Time for Cutting inside loop: 0.22 seconds (4.12 total in 10 calls)
# CCtsp_init_edgegenerator (-1)
# xprice_build
# xprice_reset (0)
# CCtsp_generate_edges (23003)
# Time for Add edges: 0.00 seconds (0.36 total in 11 calls)
# 0 edges added, penalty -0.000000
# New lower bound: 258231.000000
# Time for Full edge check: 0.00 seconds (0.00 total in 1 calls)
# Setting tolerances: next cuts 4.3400 next round 0.4340
# LP has:  1456 rows  2446 columns  13458 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  1456 rows  2446 columns  11621 nonzeros
# Integral Solution of Value 258231.00
# CCtsp_generate_edges (23003)
# Time for Add edges: 0.00 seconds (0.36 total in 12 calls)
# (SPARSE) 0 edges added, penalty -0.000000, val 258231.000000
# Time for Sparse edge check: 0.00 seconds (0.36 total in 11 calls)
# recomputing rownorms ...
# Write Pool: 806 cuts
# Time for Cutting inside loop: 0.03 seconds (4.15 total in 11 calls)
# CCtsp_init_edgegenerator (-1)
# xprice_build
# xprice_reset (0)
# CCtsp_generate_edges (23003)
# Time for Add edges: 0.00 seconds (0.36 total in 13 calls)
# 0 edges added, penalty -0.000000
# Time for Full edge check: 0.00 seconds (0.01 total in 2 calls)
# Time for Cutting Loop: 4.17 seconds (4.17 total in 1 calls)
# Number of outside rounds: 2
# CCtsp_x_greedy_tour ...
# 1000 edges in x-tour
# tour length: 258231.00 (0.00 seconds)
# Built CCkdtree: 0.00 (seconds)
# . 4306 edges
# Quad Nearest added 4306 edges (0.00 seconds)
# Edgegen total edges: 4306 (0.00 seconds)
# x-heuristic lk  gives: 258231.00
# Upperbound from x-heuristic: 258231.00
# Exact Price Time: 0.04 seconds
# Exact lower bound: 258231.000000
# DIFF: 0.000000
# Established Bound: 258231
# Optimal tour: 258231
# Total Time to solve TSP: 5.16

# %%
GO = False
if GO:
    num_samples = 10000
    set_nodes_coord = np.random.random([num_samples, n_clusters, 2])
    with open("tsp" + str(n_clusters) + "_pr1002.txt", "w") as f:
        solver = TSPSolver.from_data(centers[:,0], centers[:,1], norm="EUC_2D")  
        solution = solver.solve()
        f.write( " ".join( str(x)+str(" ")+str(y) for x,y in centers) )
        f.write( str(" ") + str('output') + str(" ") )
        f.write( str(" ").join( str(node_idx+1) for node_idx in solution.tour) )
        f.write( str(" ") + str(solution.tour[0]+1) + str(" ") )
