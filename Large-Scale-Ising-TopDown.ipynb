# %%
import os
import time
import sys
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.neighbors import NearestCentroid, kneighbors_graph
from sklearn import metrics
from sklearn.metrics import silhouette_score
from scipy.spatial.distance import cdist
from scipy.spatial import KDTree, cKDTree
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from concorde.tsp import TSPSolver
from math import sqrt, ceil, inf, floor

# %%
root_dir = os.getcwd()
tsp_dir = os.path.join(root_dir, "../tsplib")
concorde_dir = os.path.join(root_dir, "../pyconcorde/concorde")

# %%
sys.path.insert(0, root_dir)
sys.path.insert(0, tsp_dir)
#sys.path.insert(0, concorde_dir)

# %%
num_samples = 10000

# %%
def gen_tsp_data():
    ## Load a tsp library and Create a dictionary "tsp_database" of Name-X/Y coordinates.

    tsp_database = {}
    cities = os.listdir(tsp_dir)
    
    for city in cities:
        if city.endswith(".tsp"):
            with open(tsp_dir + '/' + city, 'r') as infile:
                lines = infile.readlines()
                for i in range(0, len(lines)):
                    line = lines[i]
                    if "DIMENSION" in line:
                        Dimension = line.strip().split(':')[1]
                        if not Dimension.isdigit():
                            continue
                    if "EDGE_WEIGHT_TYPE" in line:
                        EdgeWeightType = line.strip().split()[1]
                        if EdgeWeightType != "EUC_2D":
                            continue
                    if "NODE_COORD_SECTION" in line:
                        x_y = None
                        nodelist_x = []
                        nodelist_y = []
        
                        for j in range (1, int(Dimension)):
                            x_y = lines[i+1].strip().split()[1:]
    #                        print(x_y)
    #                        import pdb; pdb.set_trace()
                            x = x_y[0]
                            y = x_y[1]
                            nodelist_x.append(float(x))
                            nodelist_y.append(float(y))
                            i+=1
                        tsp_database.update({city[:-4]:[nodelist_x, nodelist_y]})
    return tsp_database

# %%
tsp_database = gen_tsp_data()
problem_list = tsp_database.keys()
problem_list
# Out:
# dict_keys(['pcb442', 'd15112', 'pla7397', 'd18512', 'd2103', 'fl1400', 'pr107', 'berlin52', 'fl3795', 'pcb3038', 'gr666', 'fnl4461', 'gil262', 'kroB200', 'kroE100', 'pr2392', 'lin318', 'pla85900', 'usa13509', 'brd14051', 'pla33810', 'pr152', 'pr226', 'pr1002', 'u2152', 'eil76', 'rl5934', 'bier127', 'rl5915', 'u2319', 'rat783', 'rl11849', 'rat575', 'kroA100', 'eil101'])

# %%
cluster_dict = {
    "berlin52": [9],
    "eil76": [9],
    "eil101": [21,3],
    "kroE100": [14,2],
    "kroB200": [33,5],
    "gil262": [41,4],
    "lin318": [56,6],
    "pcb442": [79,10],
    "rat575": [73,9],
    "gr666": [335,52,7],
    "rat783": [113,14,2],
    "pr1002": [161,21,2],
    "d2103": [288,42,6],
    "u2152": [365,50,6],
    "pr2392": [416,55,6],
    "pcb3038": [487,75,8],
    "fnl4461": [773,125,16,2],
    "rl5915": [980,139,17,2],
    "rl5934": [1237,196,29,4],
    "rl11849": [2341,375,61,7],
    "pla33810": [6446,1257,192,28,3]
    }

# %%
import pyproj as p

x = "pla33810"
n_clusters = cluster_dict[x]
#n_clusters = [416,55,6]
#x = "pla33810"
## Connectivty and Complete linkage
#n_clusters = [6600,1417,233,39,8,1]
#x = "pla85900"
coord_geo = False
if coord_geo == True:
     crs_wgs = p.Proj(init='epsg:4326')
     crs_bng = p.Proj(init = 'epsg:27700')
    
     tsp_database[x][0],tsp_database[x][1]  = p.transform(crs_wgs, crs_bng, tsp_database[x][1], tsp_database[x][0])
# for x in tsp_database:
print("Problem : " + x)
#    print(tsp_database[x])
X_coord = np.array(tsp_database[x][0])
Y_coord = np.array(tsp_database[x][1])
X_Y = np.array(list(zip(X_coord,Y_coord))).reshape(len(X_coord),2)
plt.plot()
plt.title('Cities in ' + x)
plt.scatter(X_coord, Y_coord)
plt.show()
# Out:
# Problem : pla33810

# %% [markdown]
# lt.plot()<br>
# lt.title('Cities in ' + x)<br>
# lt.scatter(X_coord, Y_coord)<br>
# lt.show()

# %%
from numpy import inf

X_Y[X_Y == inf] = 0

# %%
def get_clustered_cities(num_clust, labels_array):
    return np.where(labels_array == num_clust)

# %%
def plot_sys2_cities(sys2_cities):
    for k in K:
        plt.scatter(sys2_cities[k][:,0], sys2_cities[k][:,1])
        plt.show()

# %%
import time   
from k_means_constrained import KMeansConstrained

X_Y = [X_Y]
Centroids = []
KM_labels = []
i = 0

cluster_size_min = 3
cluster_size_max = 12

Contrained = False

hierarchies = []

CEs = []
clf = NearestCentroid()
SEARCH = False
if SEARCH:
    while True:
        #if len(X_Y) > cluster_size_max:
        #    n_clusters = cluster_size_max
        #else:
        #    n_clusters = len(X_Y)
        centroid = []
        LABEL = []
        offset = 0
        for problem in X_Y:
            AggloModel = AgglomerativeClustering(n_clusters, metric='euclidean', linkage='ward').fit(problem)
            y_KMC = AggloModel.labels_
            clf.fit(problem, y_KMC)
            centers = clf.centroids_
            centroid.append(centers)
            LABEL.append(y_KMC+offset)
            offset = len(problem)
            
            for c in range(len(centers)):
                cities = problem[np.where(y_KMC==c)[0]]
                
            np.where(y_KMC)
            
        Centroids.insert(0, centroid)
        
        n_max = 0
        for c in range(len(centers)):
            center = centers[c]
            cities = np.where(y_KMC==c)[0]
            if len(cities) > n_max:
                n_max = len(cities)
        
        if (n_max < cluster_size_max+1):# and (n_clusters == 2 or MEAN*0.999 < CE):# and (MinScore*1.01 > Score):
            plt.plot(range(len(CEs)), CEs, 'r-')
            plt.show()
            colors = mpl.cm.tab20(range(20))
            c_labels = []
            for yy in y_KMC:
                c_labels.append(colors[yy%20])
            #plt.scatter(X_Y[i][:,0], X_Y[i][:,1], c=y_KMC, s=10, cmap='viridis')
            plt.scatter(X_Y[i][:,0], X_Y[i][:,1], c=c_labels, s=10)
            plt.scatter(centers[:,0], centers[:,1], c='black', s=50, alpha=0.5)
            plt.rcParams.update({'font.size':15})
            plt.show()
            
            KM_labels.append(y_KMC)
            X_Y.append(centers)
            hierarchies.append(len(centers))
            i += 1
            n_clusters = floor(len(X_Y[i])/cluster_size_max)
            if n_clusters < 2:
                n_clusters = 2
            if len(centers) < cluster_size_max+1:
                break
            CEs = []
        else:
            n_clusters += 1
else:
    Cluster_distribution = []
    for N_C in n_clusters:
        #knn_graph = kneighbors_graph(X_Y[i], n_clusters, include_self=False)
        #AggloModel = AgglomerativeClustering(n_clusters, metric='euclidean', connectivity= knn_graph, linkage='complete').fit(X_Y[i])
        #AggloModel = AgglomerativeClustering(n_clusters, metric='euclidean', connectivity= knn_graph, linkage='ward').fit(X_Y[i])
        #AggloModel = AgglomerativeClustering(n_clusters, metric='euclidean', linkage='complete').fit(X_Y[i])
        AggloModel = AgglomerativeClustering(N_C, metric='euclidean', linkage='ward').fit(X_Y[-1])
        y_KMC = AggloModel.labels_
        clf.fit(X_Y[-1], y_KMC)
        centers = clf.centroids_
        
        #####
        unique, counts = np.unique(y_KMC, return_counts=True)
        unique, counts = np.unique(counts, return_counts=True)
        Cluster_distribution.append(dict(zip(unique, counts)))
        #####
        
        KM_labels.append(y_KMC)
        X_Y.append(centers)
        hierarchies.append(len(centers))
        
Cluster_distribution.append(dict(zip([hierarchies[-1]], [1])))
print(hierarchies)
print(Cluster_distribution)
# Out:
# [6446, 1257, 192, 28, 3]
# [{1: 168, 2: 102, 3: 199, 4: 2602, 5: 641, 6: 1269, 7: 595, 8: 564, 9: 162, 10: 112, 11: 26, 12: 6}, {1: 1, 2: 130, 3: 141, 4: 274, 5: 193, 6: 227, 7: 118, 8: 90, 9: 53, 10: 18, 11: 8, 12: 4}, {2: 1, 3: 2, 4: 23, 5: 32, 6: 46, 7: 27, 8: 30, 9: 18, 10: 13}, {3: 2, 4: 1, 5: 8, 6: 1, 7: 5, 8: 4, 9: 2, 10: 4, 11: 1}, {7: 1, 9: 1, 12: 1}, {3: 1}]

# %%
## sys2_cities has [hierarchies where the sub-cluster belongs, Center X/Y coordinates of the sub-cluster, Cities X/Y coordinates in the sub-cluster]
## sys2_centers has [hierarchies where the sub-cluster belongs, Center X/Y coordinates of the sub-cluster]
## sys2_clusters has [hierarchies where the sub-cluster belongs, Cities X/Y coordinates in the sub-cluster]
sys2_centers = []
sys2_clusters = []

H = range(0,len(hierarchies))
for h in H:
    K = range(0,hierarchies[h])
    sys2_centers.append([])
    sys2_clusters.append([])
    colors = mpl.cm.tab20(range(20))
    for k in K:
        sys2_centers[h].append(X_Y[h+1][k])
        sys2_clusters[h].append(X_Y[h][get_clustered_cities(k, KM_labels[h])])
    largest_cluster_size = 0
    smallest_cluster_size = 100
    for k in K:
        if len(sys2_clusters[h][k]) > largest_cluster_size:
            largest_cluster_size = len(sys2_clusters[h][k])
        if len(sys2_clusters[h][k]) < smallest_cluster_size:
            smallest_cluster_size = len(sys2_clusters[h][k])
        if (len(sys2_clusters[h][k]) == 1):
            print("dirty cluster")
    print("The largest & smallest cluster size in Hierarchy ",h+1, ": ", largest_cluster_size, " & ", smallest_cluster_size)
## Add the topmost cluster
sys2_centers.append([])
sys2_clusters.append([])
sys2_centers[-1].append([0, 0])
sys2_clusters[-1].append(X_Y[-1])
# Out:
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# dirty cluster
# The largest & smallest cluster size in Hierarchy  1 :  12  &  1
# dirty cluster
# The largest & smallest cluster size in Hierarchy  2 :  12  &  1
# The largest & smallest cluster size in Hierarchy  3 :  10  &  2
# The largest & smallest cluster size in Hierarchy  4 :  11  &  3
# The largest & smallest cluster size in Hierarchy  5 :  12  &  7

# %%
def Fix_first_last_cities(sys2_centers, sys2_clusters, sol_route, Lowest_Hier):
    ## Find a pair of the closest cities, each of which is in a distinct cluster which will be sequentially visited.
    ## After finding, place each city of the pair in the end of the preceding cluster and the start of the following cluster.
    ## To avoid the city in the following cluster to be selected once again for the next search, the next search starts from Index 1.
    ## Refer to Page 25
    tree = cKDTree(sys2_centers)
    clust_id_list = []
    total_traveling_distance = 0
    
    for k in range(len(sol_route)-1):
        ## Finding a pair of cities from distinct sub-clusters having the shortest distance betweeen sub-clusters.
        clust_idx_curr = tree.query(sol_route[k])[1]
        clust_idx_next = tree.query(sol_route[k+1])[1]
        if k ==0:
            clust_id_list.append(clust_idx_curr)
        clust_id_list.append(clust_idx_next)
        
        curr_clust = sys2_clusters[clust_idx_curr]
        next_clust = sys2_clusters[clust_idx_next]
        tree_clust = cKDTree(next_clust)
        ## For the first cluster in a hierarchy, all cities in the cluster is included in the search.
        ## For clusters that include only one city, the city that has been chosen for the first city from the previous search 
        ## will be used for the search and chosen for the last city. The first and last city at the same time. 
        if k ==0 or len(curr_clust) == 1:
            search_init = 0
        ## Otherwise, the first city is excluded from the search, because it's already chosen for the first city.
        else:
            search_init = 1
        sht_dist = inf
        for inc in range(search_init, len(curr_clust)):
            val_sd, idx_sd = tree_clust.query(curr_clust[inc])
            if val_sd < sht_dist:
                sht_dist = val_sd
                sht_idx_curr = inc
                sht_idx_next = idx_sd
                
        ## Fix the first and the last cities according to the information found above, unless the clust has one city.
        if len(curr_clust) > 1:
            curr_clust[[-1, sht_idx_curr]] = curr_clust[[sht_idx_curr,-1]]
            sys2_clusters[clust_idx_curr] = curr_clust
        if len(next_clust) > 1:
            next_clust[[0, sht_idx_next]] = next_clust[[sht_idx_next,0]]
            sys2_clusters[clust_idx_next] = next_clust
        if Lowest_Hier:
            total_traveling_distance += sht_dist
            #print("Inter-cluster distance (clusters ", k, "-", k+1, "): ", sht_dist, " total distance: ", total_traveling_distance)
            
    return sys2_clusters, clust_id_list, total_traveling_distance

# %%
def skip_ising(Lowest_Hier, total_traveling_distance, sol_route, route_btw_clusters, timet, nMAC_array, nRandFlip_array, curr_clust_size, infile, outfile):
    print("Ising skipped!!")
    timet[-1].append(0)
    nMAC_array[-1].append(0)
    nRandFlip_array[-1].append(0)
    DIST = 0
    with open(infile,"r") as inF:
        lines = inF.readlines()
        outF = open(outfile,"w")
        
        for i in range(1, curr_clust_size+1):
            line = lines[i]
            outF.write(line)
            
            curr = line.strip().split()
            for j in range(len(curr)):
                curr[j] = float(curr[j])
            sol_route.append(curr)
            
            if Lowest_Hier:
                if (i == 1):
                    route_btw_clusters.append(curr)
                if (i == curr_clust_size):
                    route_btw_clusters.append(curr)
        if curr_clust_size == 1:
            DIST = 0
        else:
            for i in range(1, curr_clust_size):
                X1 = float(lines[i].strip().split()[0])
                Y1 = float(lines[i].strip().split()[1])
                X2 = float(lines[i+1].strip().split()[0])
                Y2 = float(lines[i+1].strip().split()[1])
                DIST += sqrt((X1-X2)**2+(Y1-Y2)**2)
        outF.write("\n")
        outF.write("dist ")
        outF.write(str(DIST))
        outF.write("\n")
        outF.write("n_MAC 0")
        outF.write("\n")
        outF.write("n_RandFlip 0")
        outF.write("\n")
        
        outF.close()
        inF.close()

        if Lowest_Hier:
            total_traveling_distance += DIST
    
    return total_traveling_distance, sol_route, route_btw_clusters, timet, nMAC_array, nRandFlip_array

# %%
def gen_sys2_sol(MAC_ising, benchmark, sys2_centers, sys2_clusters, SchPar):
    MAC_ising = True
    if MAC_ising:
        cpp_cmd = "./ising_mac"
    else :
        cpp_cmd = "./ising_RNG"
    os.system("rm -rf sys2clusters_" + str(benchmark))
    SYS2_CENTERS = sys2_centers
    SYS2_CLUSTERS = sys2_clusters
    
    timet =[]
    nMAC_array =[]
    nRandFlip_array = []
    sys2_labels = []
    colors = mpl.cm.tab20(range(20))
    sol_route = 0
    sol_route_ex = []
    
    ideal_latency = 0
    nMAC_hierarchies = []
    
    for h in range(0, n_hierarchies+1):
        print("Execute Ising Solver for Hierarchy ", n_hierarchies-h)
        sys2_centers = SYS2_CENTERS[n_hierarchies-h]
        sys2_clusters = SYS2_CLUSTERS[n_hierarchies-h]

        if h != 0:
            sys2_clusters, clust_id_list, total_traveling_distance = Fix_first_last_cities(sys2_centers, sys2_clusters, sol_route, h == n_hierarchies)
        else:
            clust_id_list = range(0, len(sys2_centers))
            
        sol_route_ex.append(sol_route)
        sol_route = []
        route_btw_clusters = []
        timet.append([])
        nMAC_array.append([])
        nRandFlip_array.append([])
        sys2_labels.append([])
        for k in range(len(clust_id_list)):
            curr_clust = sys2_clusters[clust_id_list[k]]
            curr_clust_size = len(curr_clust)
            for l in range(curr_clust_size):
                sys2_labels[h].append(colors[k%20])
            os.system("mkdir -p sys2clusters_" + str(benchmark))
            curr_filename = str(benchmark) + "_h" + str(n_hierarchies-h)  + "_c" + str(k) +".in"
            curr_logfile = str(benchmark) + "_h" + str(n_hierarchies-h)   + "_c" + str(k) +".out"
            inF = open("sys2clusters_" + str(benchmark) + "/" + curr_filename,"w")
            inF.write(str(curr_clust_size))
            inF.write("\n")
            for i in curr_clust:
                inF.write(str(i[0]) + " " + str(i[1]))
                inF.write("\n")
            inF.close()
            
            if h == 0:
                if curr_clust_size == 2:
                    Cluster_distribution[n_hierarchies-h][curr_clust_size] -= 1
                    total_traveling_distance, sol_route, route_btw_clusters, timet, nMAC_array, nRandFlip_array = skip_ising(h == n_hierarchies, 0, sol_route, route_btw_clusters, timet, nMAC_array, nRandFlip_array, curr_clust_size, "sys2clusters_" + str(benchmark) + "/" + curr_filename, "sys2clusters_" + str(benchmark) + "/" + curr_logfile)
                    continue
            else:
                if k == 0 or k == len(clust_id_list)-1:
                    if curr_clust_size < 3:
                        Cluster_distribution[n_hierarchies-h][curr_clust_size] -= 1
                        total_traveling_distance, sol_route, route_btw_clusters, timet, nMAC_array, nRandFlip_array = skip_ising(h == n_hierarchies, total_traveling_distance, sol_route, route_btw_clusters, timet, nMAC_array, nRandFlip_array, curr_clust_size, "sys2clusters_" + str(benchmark) + "/" + curr_filename, "sys2clusters_" + str(benchmark) + "/" + curr_logfile)
                        continue
                else:
                    if curr_clust_size < 4:
                        Cluster_distribution[n_hierarchies-h][curr_clust_size] -= 1
                        total_traveling_distance, sol_route, route_btw_clusters, timet, nMAC_array, nRandFlip_array = skip_ising(h == n_hierarchies, total_traveling_distance, sol_route, route_btw_clusters, timet, nMAC_array, nRandFlip_array, curr_clust_size, "sys2clusters_" + str(benchmark) + "/" + curr_filename, "sys2clusters_" + str(benchmark) + "/" + curr_logfile)
                        continue
            tic = time.perf_counter()
            ### when h>0, Problem_size to optimize = N-1 when k is 0 or -1, otherwise N-2
            if h == 0 :
                os.system(cpp_cmd+" -I "+str(SchPar[0])+" -c "+str(SchPar[1])+" -F "+str(SchPar[2])+" -D "+str(SchPar[3])+" -P "+str(SchPar[4])+" k0" + " sys2clusters_" + str(benchmark) + "/" + curr_filename + " >> " + "sys2clusters_" + str(benchmark) + "/" + curr_logfile)
            elif k == len(clust_id_list)-1:
                os.system(cpp_cmd+" -I "+str(SchPar[0])+" -c "+str(SchPar[1])+" -F "+str(SchPar[2])+" -D "+str(SchPar[3])+" -P "+str(SchPar[4])+" k-1" + " sys2clusters_" + str(benchmark) + "/" + curr_filename + " >> " + "sys2clusters_" + str(benchmark) + "/" + curr_logfile)
            else :
                os.system(cpp_cmd+" -I "+str(SchPar[0])+" -c "+str(SchPar[1])+" -F "+str(SchPar[2])+" -D "+str(SchPar[3])+" -P "+str(SchPar[4])+" k" + str(k+1) + " sys2clusters_" + str(benchmark) + "/" + curr_filename + " >> " + "sys2clusters_" + str(benchmark) + "/" + curr_logfile)
            toc = time.perf_counter()
            timet[-1].append(toc-tic)
            
            dist_array =[]
            with open("sys2clusters_" + str(benchmark) + "/" + curr_logfile,"r") as outFile:
                lines = outFile.readlines()
                for i in range(0,len(lines)):
                    line = lines[i]
                    if "dist" in line:
                        dist_array.append(line.strip().split()[1])
                        continue
                    if "n_MAC" in line:
                        nMAC_array[-1].append(int(line.strip().split()[1]))
                        continue
                    if "n_RandFlip" in line:
                        nRandFlip_array[-1].append(int(line.strip().split()[1]))
                        continue
                dist = min(dist_array)
                ####################################
                ####################################
                if h == n_hierarchies:
                    total_traveling_distance += float(dist)
                    print("hierarchy: ", h, " cluster: ", k, " distance within the cluster: ", float(dist), " total distance: ", total_traveling_distance)
                ####################################
                ####################################
                for i in range(0, curr_clust_size):
                    line = lines[i]
                    curr = line.strip().split()
                    for j in range(len(curr)):
                        curr[j] = float(curr[j])
                    sol_route.append(curr)
                
                    if h == n_hierarchies:
                        if (i == 0) or (i == curr_clust_size-1):
                            route_btw_clusters.append(curr)
                
                outFile.close()
            print("done with cluster" + str(k))
        #print(f"Ising Max time = {max(timet[-1]):0.4f} seconds", " / ", str(min(timet[-1])))
        ideal_latency += max(timet[-1])
        #nMAC_hierarchies.append(max(nMAC_array[-1]))
        nMAC_hierarchies.insert(0, max(nMAC_array[-1]))
        if MAC_ising:
            print(f"Max/Min number of Ising Macro MAC Operations = ", max(nMAC_array[-1]), " / ", min(nMAC_array[-1]))
            #print(f"Max/Min number of Ising Macro RandomFlip Operations = ", max(nRandFlip_array[-1]), " / ", min(nRandFlip_array[-1]))
    
    print("total wall-clock latency: ", ideal_latency)
    print("Max nMAC per hierarchy: ", nMAC_hierarchies)
    print("total traveling distance: ", total_traveling_distance)
    return sol_route_ex, sol_route, route_btw_clusters, sys2_labels, total_traveling_distance, nMAC_array, nRandFlip_array

# %%
print(hierarchies)
print(Cluster_distribution)
n_hierarchies = len(hierarchies)
MAC_ising = True
#sol_route, route_btw_clusters, sys2_labels = gen_sys2_sol(MAC_ising, x, sys2_centers, sys2_clusters)
init_Irands = [48]
init_cools = [0.001]
Factors = [1.1]
Thresholds = [0]
Patiences = [30]
#Patiences = [100]

init_Irands = [48]
init_cools = [0.002]
Factors = [0.9]
Thresholds = [0]
Patiences = [30]
#Patiences = [100]


#cools = [0.01, 0.005, 0.002, 0.001]
#Factors = [0.8, 0.9, 0.95, 0.99, 0.995, 0.999]
#Thresholds = [1e6, 1e3, 0, -1e3, -1e6]
#Patiences = [5, 10, 20, 50]
ttds = []
nMACs = []
nRandFlips = []

repeat = 1

for REPEAT in range(repeat):
    for Irand in init_Irands:
        for cool in init_cools:
            for Factor in Factors:
                for Threshold in Thresholds:
                    for Patience in Patiences:
                        scheduler_params = [Irand, cool, Factor, Threshold, Patience]
                        sol_route_ex, sol_route, route_btw_clusters, sys2_labels, ttd, nMAC, nRandFlip = gen_sys2_sol(MAC_ising, x, sys2_centers, sys2_clusters, scheduler_params)
                        ttds.append(ttd)
                        sum_nMACs = 0
                        for MAC in nMAC:
                            sum_nMACs += max(MAC)
                        #nMACs.append(max(nMAC[-1]))
                        nMACs.append(sum_nMACs)
                        sum_nRFlips = 0
                        for RFlip in nRandFlip:
                            sum_nRFlips += max(RFlip)
                        #nRandFlips.append(max(nRandFlip[-1]))
                        nRandFlips.append(sum_nRFlips)
    i = 0
    for Irand in init_Irands:
        for cool in init_cools:
            for Factor in Factors:
                for Threshold in Thresholds:
                    for Patience in Patiences:
                        #print("Irand: ", Irand, "Cool: ", cool, "Factor: ", Factor, " Threshold: ", Threshold, " Patience: ", Patience, " ttd: ", ttds[i], " nMAC: ", nMACs[i], " nRandFlip: ", nRandFlips[i])
                        i += 1
#print(hierarchies)
#print(Cluster_distribution)
hierarchies_new = []
for XX in range(len(Cluster_distribution)):
    hierarchies_new.append(sum(Cluster_distribution[XX].values()))
    kick_out = []
    for key, value in Cluster_distribution[XX].items():
        if value == 0:
            kick_out.append(key)
    for key in kick_out:
        del Cluster_distribution[XX][key]
print(hierarchies_new)
print(Cluster_distribution)
# Out:
# [6446, 1257, 192, 28, 3]
# [{1: 168, 2: 102, 3: 199, 4: 2602, 5: 641, 6: 1269, 7: 595, 8: 564, 9: 162, 10: 112, 11: 26, 12: 6}, {1: 1, 2: 130, 3: 141, 4: 274, 5: 193, 6: 227, 7: 118, 8: 90, 9: 53, 10: 18, 11: 8, 12: 4}, {2: 1, 3: 2, 4: 23, 5: 32, 6: 46, 7: 27, 8: 30, 9: 18, 10: 13}, {3: 2, 4: 1, 5: 8, 6: 1, 7: 5, 8: 4, 9: 2, 10: 4, 11: 1}, {7: 1, 9: 1, 12: 1}, {3: 1}]
# Execute Ising Solver for Hierarchy  5
# done with cluster0
# Max/Min number of Ising Macro MAC Operations =  2596  /  2596
# Execute Ising Solver for Hierarchy  4
# done with cluster0
# done with cluster1
# done with cluster2
# Max/Min number of Ising Macro MAC Operations =  12980  /  6490
# Execute Ising Solver for Hierarchy  3
# done with cluster0
# done with cluster1
# done with cluster2
# done with cluster3
# done with cluster4
# done with cluster5
# done with cluster6
# Ising skipped!!
# Ising skipped!!
# done with cluster9
# done with cluster10
# done with cluster11
# done with cluster12
# done with cluster13
# done with cluster14
# done with cluster15
# done with cluster16
# done with cluster17
# done with cluster18
# done with cluster19
# done with cluster20
# done with cluster21
# done with cluster22
# done with cluster23
# done with cluster24
# done with cluster25
# done with cluster26
# done with cluster27
# Max/Min number of Ising Macro MAC Operations =  11682  /  0
# Execute Ising Solver for Hierarchy  2
# done with cluster0
# done with cluster1
# done with cluster2
# done with cluster3
# done with cluster4
# done with cluster5
# done with cluster6
# done with cluster7
# done with cluster8
# done with cluster9
# done with cluster10
# done with cluster11
# done with cluster12
# done with cluster13
# done with cluster14
# done with cluster15
# done with cluster16
# done with cluster17
# done with cluster18
# done with cluster19
# done with cluster20
# done with cluster21
# done with cluster22
# done with cluster23
# done with cluster24
# done with cluster25
# done with cluster26
# done with cluster27
# done with cluster28
# done with cluster29
# done with cluster30
# done with cluster31
# done with cluster32
# done with cluster33
# done with cluster34
# done with cluster35
# done with cluster36
# done with cluster37
# done with cluster38
# Ising skipped!!
# done with cluster40
# done with cluster41
# Ising skipped!!
# done with cluster43
# done with cluster44
# done with cluster45
# done with cluster46
# done with cluster47
# done with cluster48
# done with cluster49
# done with cluster50
# done with cluster51
# done with cluster52
# done with cluster53
# done with cluster54
# done with cluster55
# done with cluster56
# done with cluster57
# done with cluster58
# done with cluster59
# done with cluster60
# done with cluster61
# done with cluster62
# done with cluster63
# done with cluster64
# done with cluster65
# done with cluster66
# done with cluster67
# done with cluster68
# done with cluster69
# done with cluster70
# done with cluster71
# done with cluster72
# done with cluster73
# done with cluster74
# done with cluster75
# done with cluster76
# done with cluster77
# done with cluster78
# done with cluster79
# done with cluster80
# done with cluster81
# done with cluster82
# done with cluster83
# done with cluster84
# done with cluster85
# done with cluster86
# done with cluster87
# done with cluster88
# done with cluster89
# done with cluster90
# done with cluster91
# done with cluster92
# done with cluster93
# done with cluster94
# done with cluster95
# done with cluster96
# done with cluster97
# done with cluster98
# done with cluster99
# done with cluster100
# done with cluster101
# done with cluster102
# done with cluster103
# done with cluster104
# done with cluster105
# done with cluster106
# done with cluster107
# done with cluster108
# done with cluster109
# done with cluster110
# done with cluster111
# done with cluster112
# done with cluster113
# done with cluster114
# done with cluster115
# done with cluster116
# done with cluster117
# done with cluster118
# done with cluster119
# done with cluster120
# done with cluster121
# done with cluster122
# done with cluster123
# done with cluster124
# done with cluster125
# done with cluster126
# done with cluster127
# done with cluster128
# done with cluster129
# done with cluster130
# done with cluster131
# done with cluster132
# done with cluster133
# done with cluster134
# done with cluster135
# done with cluster136
# done with cluster137
# done with cluster138
# done with cluster139
# done with cluster140
# done with cluster141
# done with cluster142
# done with cluster143
# done with cluster144
# done with cluster145
# done with cluster146
# Ising skipped!!
# done with cluster148
# done with cluster149
# done with cluster150
# done with cluster151
# done with cluster152
# done with cluster153
# done with cluster154
# done with cluster155
# done with cluster156
# done with cluster157
# done with cluster158
# done with cluster159
# done with cluster160
# done with cluster161
# done with cluster162
# done with cluster163
# done with cluster164
# done with cluster165
# done with cluster166
# done with cluster167
# done with cluster168
# done with cluster169
# done with cluster170
# done with cluster171
# done with cluster172
# done with cluster173
# done with cluster174
# done with cluster175
# done with cluster176
# done with cluster177
# done with cluster178
# done with cluster179
# done with cluster180
# done with cluster181
# done with cluster182
# done with cluster183
# done with cluster184
# done with cluster185
# done with cluster186
# done with cluster187
# done with cluster188
# done with cluster189
# done with cluster190
# done with cluster191
# Max/Min number of Ising Macro MAC Operations =  9086  /  0
# Execute Ising Solver for Hierarchy  1
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# done with cluster4
# done with cluster5
# done with cluster6
# done with cluster7
# done with cluster8
# Ising skipped!!
# Ising skipped!!
# done with cluster11
# Ising skipped!!
# done with cluster13
# done with cluster14
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# done with cluster18
# done with cluster19
# done with cluster20
# Ising skipped!!
# Ising skipped!!
# done with cluster23
# done with cluster24
# done with cluster25
# Ising skipped!!
# done with cluster27
# done with cluster28
# done with cluster29
# done with cluster30
# done with cluster31
# done with cluster32
# done with cluster33
# done with cluster34
# done with cluster35
# done with cluster36
# done with cluster37
# done with cluster38
# done with cluster39
# done with cluster40
# done with cluster41
# done with cluster42
# done with cluster43
# done with cluster44
# done with cluster45
# done with cluster46
# done with cluster47
# done with cluster48
# done with cluster49
# Ising skipped!!
# done with cluster51
# done with cluster52
# done with cluster53
# done with cluster54
# Ising skipped!!
# done with cluster56
# Ising skipped!!
# done with cluster58
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# done with cluster63
# done with cluster64
# done with cluster65
# done with cluster66
# done with cluster67
# done with cluster68
# Ising skipped!!
# done with cluster70
# done with cluster71
# done with cluster72
# Ising skipped!!
# Ising skipped!!
# done with cluster75
# done with cluster76
# Ising skipped!!
# done with cluster78
# done with cluster79
# Ising skipped!!
# Ising skipped!!
# done with cluster82
# Ising skipped!!
# done with cluster84
# done with cluster85
# done with cluster86
# done with cluster87
# done with cluster88
# done with cluster89
# done with cluster90
# done with cluster91
# done with cluster92
# done with cluster93
# done with cluster94
# done with cluster95
# done with cluster96
# done with cluster97
# done with cluster98
# done with cluster99
# done with cluster100
# done with cluster101
# done with cluster102
# done with cluster103
# done with cluster104
# done with cluster105
# done with cluster106
# done with cluster107
# done with cluster108
# done with cluster109
# done with cluster110
# done with cluster111
# done with cluster112
# done with cluster113
# done with cluster114
# Ising skipped!!
# done with cluster116
# done with cluster117
# done with cluster118
# done with cluster119
# done with cluster120
# done with cluster121
# done with cluster122
# done with cluster123
# done with cluster124
# done with cluster125
# done with cluster126
# done with cluster127
# done with cluster128
# done with cluster129
# Ising skipped!!
# done with cluster131
# Ising skipped!!
# done with cluster133
# done with cluster134
# Ising skipped!!
# Ising skipped!!
# done with cluster137
# done with cluster138
# Ising skipped!!
# Ising skipped!!
# done with cluster141
# done with cluster142
# done with cluster143
# done with cluster144
# done with cluster145
# Ising skipped!!
# done with cluster147
# done with cluster148
# done with cluster149
# done with cluster150
# done with cluster151
# done with cluster152
# done with cluster153
# done with cluster154
# done with cluster155
# done with cluster156
# done with cluster157
# done with cluster158
# done with cluster159
# done with cluster160
# done with cluster161
# done with cluster162
# done with cluster163
# done with cluster164
# done with cluster165
# done with cluster166
# done with cluster167
# done with cluster168
# done with cluster169
# done with cluster170
# done with cluster171
# done with cluster172
# done with cluster173
# done with cluster174
# done with cluster175
# done with cluster176
# done with cluster177
# done with cluster178
# done with cluster179
# done with cluster180
# done with cluster181
# done with cluster182
# done with cluster183
# done with cluster184
# done with cluster185
# Ising skipped!!
# done with cluster187
# done with cluster188
# done with cluster189
# done with cluster190
# done with cluster191
# done with cluster192
# done with cluster193
# done with cluster194
# done with cluster195
# Ising skipped!!
# done with cluster197
# done with cluster198
# Ising skipped!!
# done with cluster200
# done with cluster201
# done with cluster202
# done with cluster203
# done with cluster204
# Ising skipped!!
# done with cluster206
# Ising skipped!!
# done with cluster208
# done with cluster209
# done with cluster210
# done with cluster211
# done with cluster212
# done with cluster213
# done with cluster214
# done with cluster215
# done with cluster216
# done with cluster217
# done with cluster218
# done with cluster219
# done with cluster220
# done with cluster221
# done with cluster222
# done with cluster223
# done with cluster224
# done with cluster225
# done with cluster226
# done with cluster227
# done with cluster228
# Ising skipped!!
# Ising skipped!!
# done with cluster231
# done with cluster232
# done with cluster233
# done with cluster234
# done with cluster235
# done with cluster236
# done with cluster237
# done with cluster238
# done with cluster239
# done with cluster240
# done with cluster241
# done with cluster242
# done with cluster243
# done with cluster244
# Ising skipped!!
# done with cluster246
# done with cluster247
# done with cluster248
# done with cluster249
# done with cluster250
# done with cluster251
# done with cluster252
# done with cluster253
# done with cluster254
# done with cluster255
# done with cluster256
# done with cluster257
# done with cluster258
# Ising skipped!!
# done with cluster260
# Ising skipped!!
# done with cluster262
# done with cluster263
# Ising skipped!!
# done with cluster265
# Ising skipped!!
# Ising skipped!!
# done with cluster268
# done with cluster269
# done with cluster270
# Ising skipped!!
# Ising skipped!!
# done with cluster273
# done with cluster274
# Ising skipped!!
# done with cluster276
# done with cluster277
# Ising skipped!!
# Ising skipped!!
# done with cluster280
# done with cluster281
# done with cluster282
# done with cluster283
# done with cluster284
# done with cluster285
# done with cluster286
# Ising skipped!!
# Ising skipped!!
# done with cluster289
# done with cluster290
# done with cluster291
# done with cluster292
# done with cluster293
# Ising skipped!!
# done with cluster295
# done with cluster296
# done with cluster297
# done with cluster298
# done with cluster299
# Ising skipped!!
# done with cluster301
# done with cluster302
# done with cluster303
# Ising skipped!!
# done with cluster305
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# done with cluster311
# done with cluster312
# done with cluster313
# done with cluster314
# done with cluster315
# done with cluster316
# done with cluster317
# done with cluster318
# done with cluster319
# Ising skipped!!
# done with cluster321
# done with cluster322
# done with cluster323
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# done with cluster342
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# done with cluster359
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# done with cluster365
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# done with cluster371
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# done with cluster375
# Ising skipped!!
# Ising skipped!!
# done with cluster378
# Ising skipped!!
# Ising skipped!!
# done with cluster381
# done with cluster382
# done with cluster383
# Ising skipped!!
# done with cluster385
# done with cluster386
# done with cluster387
# done with cluster388
# done with cluster389
# Ising skipped!!
# done with cluster391
# done with cluster392
# done with cluster393
# done with cluster394
# done with cluster395
# done with cluster396
# done with cluster397
# done with cluster398
# done with cluster399
# done with cluster400
# Ising skipped!!
# done with cluster402
# Ising skipped!!
# done with cluster404
# done with cluster405
# done with cluster406
# done with cluster407
# done with cluster408
# Ising skipped!!
# done with cluster410
# done with cluster411
# Ising skipped!!
# Ising skipped!!
# done with cluster414
# done with cluster415
# done with cluster416
# done with cluster417
# done with cluster418
# done with cluster419
# done with cluster420
# done with cluster421
# done with cluster422
# done with cluster423
# done with cluster424
# Ising skipped!!
# done with cluster426
# done with cluster427
# done with cluster428
# done with cluster429
# done with cluster430
# done with cluster431
# done with cluster432
# done with cluster433
# done with cluster434
# done with cluster435
# done with cluster436
# done with cluster437
# done with cluster438
# done with cluster439
# done with cluster440
# done with cluster441
# done with cluster442
# done with cluster443
# done with cluster444
# done with cluster445
# done with cluster446
# done with cluster447
# done with cluster448
# done with cluster449
# done with cluster450
# done with cluster451
# done with cluster452
# done with cluster453
# done with cluster454
# Ising skipped!!
# done with cluster456
# Ising skipped!!
# done with cluster458
# done with cluster459
# done with cluster460
# done with cluster461
# done with cluster462
# Ising skipped!!
# done with cluster464
# done with cluster465
# done with cluster466
# done with cluster467
# done with cluster468
# done with cluster469
# done with cluster470
# done with cluster471
# done with cluster472
# done with cluster473
# Ising skipped!!
# done with cluster475
# done with cluster476
# done with cluster477
# done with cluster478
# done with cluster479
# done with cluster480
# done with cluster481
# done with cluster482
# done with cluster483
# done with cluster484
# done with cluster485
# done with cluster486
# Ising skipped!!
# done with cluster488
# done with cluster489
# done with cluster490
# done with cluster491
# done with cluster492
# done with cluster493
# done with cluster494
# done with cluster495
# done with cluster496
# done with cluster497
# Ising skipped!!
# done with cluster499
# done with cluster500
# done with cluster501
# done with cluster502
# done with cluster503
# done with cluster504
# done with cluster505
# done with cluster506
# done with cluster507
# done with cluster508
# done with cluster509
# done with cluster510
# done with cluster511
# done with cluster512
# done with cluster513
# done with cluster514
# done with cluster515
# done with cluster516
# done with cluster517
# done with cluster518
# done with cluster519
# done with cluster520
# done with cluster521
# done with cluster522
# done with cluster523
# done with cluster524
# done with cluster525
# done with cluster526
# done with cluster527
# done with cluster528
# done with cluster529
# done with cluster530
# done with cluster531
# Ising skipped!!
# done with cluster533
# done with cluster534
# Ising skipped!!
# done with cluster536
# done with cluster537
# done with cluster538
# done with cluster539
# done with cluster540
# Ising skipped!!
# done with cluster542
# done with cluster543
# done with cluster544
# done with cluster545
# done with cluster546
# done with cluster547
# done with cluster548
# done with cluster549
# Ising skipped!!
# done with cluster551
# done with cluster552
# done with cluster553
# done with cluster554
# Ising skipped!!
# done with cluster556
# done with cluster557
# done with cluster558
# done with cluster559
# done with cluster560
# done with cluster561
# done with cluster562
# done with cluster563
# done with cluster564
# done with cluster565
# done with cluster566
# done with cluster567
# done with cluster568
# done with cluster569
# done with cluster570
# done with cluster571
# done with cluster572
# done with cluster573
# done with cluster574
# done with cluster575
# done with cluster576
# done with cluster577
# done with cluster578
# done with cluster579
# done with cluster580
# done with cluster581
# done with cluster582
# done with cluster583
# done with cluster584
# done with cluster585
# Ising skipped!!
# done with cluster587
# done with cluster588
# done with cluster589
# done with cluster590
# done with cluster591
# done with cluster592
# done with cluster593
# done with cluster594
# done with cluster595
# done with cluster596
# done with cluster597
# done with cluster598
# done with cluster599
# done with cluster600
# done with cluster601
# done with cluster602
# done with cluster603
# done with cluster604
# done with cluster605
# done with cluster606
# done with cluster607
# done with cluster608
# done with cluster609
# done with cluster610
# done with cluster611
# done with cluster612
# done with cluster613
# done with cluster614
# done with cluster615
# done with cluster616
# Ising skipped!!
# done with cluster618
# done with cluster619
# done with cluster620
# done with cluster621
# done with cluster622
# done with cluster623
# done with cluster624
# done with cluster625
# done with cluster626
# done with cluster627
# done with cluster628
# done with cluster629
# done with cluster630
# done with cluster631
# done with cluster632
# done with cluster633
# done with cluster634
# done with cluster635
# done with cluster636
# done with cluster637
# done with cluster638
# done with cluster639
# Ising skipped!!
# Ising skipped!!
# done with cluster642
# Ising skipped!!
# Ising skipped!!
# done with cluster645
# done with cluster646
# Ising skipped!!
# done with cluster648
# Ising skipped!!
# done with cluster650
# done with cluster651
# done with cluster652
# done with cluster653
# done with cluster654
# done with cluster655
# done with cluster656
# done with cluster657
# done with cluster658
# Ising skipped!!
# done with cluster660
# done with cluster661
# Ising skipped!!
# done with cluster663
# done with cluster664
# Ising skipped!!
# Ising skipped!!
# done with cluster667
# done with cluster668
# done with cluster669
# done with cluster670
# done with cluster671
# done with cluster672
# done with cluster673
# done with cluster674
# done with cluster675
# done with cluster676
# done with cluster677
# done with cluster678
# done with cluster679
# done with cluster680
# done with cluster681
# done with cluster682
# done with cluster683
# done with cluster684
# done with cluster685
# done with cluster686
# done with cluster687
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# done with cluster691
# Ising skipped!!
# done with cluster693
# done with cluster694
# done with cluster695
# done with cluster696
# done with cluster697
# done with cluster698
# done with cluster699
# Ising skipped!!
# done with cluster701
# done with cluster702
# done with cluster703
# done with cluster704
# done with cluster705
# done with cluster706
# done with cluster707
# done with cluster708
# done with cluster709
# done with cluster710
# done with cluster711
# done with cluster712
# done with cluster713
# done with cluster714
# done with cluster715
# done with cluster716
# done with cluster717
# done with cluster718
# done with cluster719
# done with cluster720
# done with cluster721
# done with cluster722
# Ising skipped!!
# done with cluster724
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# done with cluster729
# done with cluster730
# done with cluster731
# done with cluster732
# done with cluster733
# done with cluster734
# done with cluster735
# done with cluster736
# done with cluster737
# done with cluster738
# done with cluster739
# done with cluster740
# done with cluster741
# done with cluster742
# done with cluster743
# done with cluster744
# done with cluster745
# done with cluster746
# done with cluster747
# done with cluster748
# done with cluster749
# done with cluster750
# done with cluster751
# done with cluster752
# done with cluster753
# done with cluster754
# done with cluster755
# done with cluster756
# done with cluster757
# done with cluster758
# done with cluster759
# done with cluster760
# done with cluster761
# done with cluster762
# done with cluster763
# done with cluster764
# done with cluster765
# Ising skipped!!
# Ising skipped!!
# done with cluster768
# done with cluster769
# Ising skipped!!
# Ising skipped!!
# done with cluster772
# Ising skipped!!
# done with cluster774
# done with cluster775
# done with cluster776
# done with cluster777
# Ising skipped!!
# done with cluster779
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# done with cluster785
# done with cluster786
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# done with cluster797
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# done with cluster801
# Ising skipped!!
# done with cluster803
# done with cluster804
# done with cluster805
# done with cluster806
# done with cluster807
# done with cluster808
# done with cluster809
# done with cluster810
# done with cluster811
# done with cluster812
# done with cluster813
# done with cluster814
# done with cluster815
# done with cluster816
# done with cluster817
# done with cluster818
# done with cluster819
# done with cluster820
# done with cluster821
# Ising skipped!!
# done with cluster823
# done with cluster824
# done with cluster825
# done with cluster826
# done with cluster827
# done with cluster828
# done with cluster829
# done with cluster830
# done with cluster831
# done with cluster832
# done with cluster833
# done with cluster834
# done with cluster835
# done with cluster836
# done with cluster837
# done with cluster838
# Ising skipped!!
# Ising skipped!!
# done with cluster841
# done with cluster842
# Ising skipped!!
# done with cluster844
# done with cluster845
# Ising skipped!!
# done with cluster847
# done with cluster848
# done with cluster849
# done with cluster850
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# done with cluster860
# done with cluster861
# done with cluster862
# done with cluster863
# done with cluster864
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# done with cluster869
# done with cluster870
# done with cluster871
# done with cluster872
# Ising skipped!!
# done with cluster874
# done with cluster875
# done with cluster876
# done with cluster877
# done with cluster878
# done with cluster879
# done with cluster880
# done with cluster881
# done with cluster882
# done with cluster883
# done with cluster884
# done with cluster885
# done with cluster886
# done with cluster887
# done with cluster888
# done with cluster889
# done with cluster890
# done with cluster891
# done with cluster892
# done with cluster893
# done with cluster894
# done with cluster895
# done with cluster896
# done with cluster897
# done with cluster898
# done with cluster899
# done with cluster900
# done with cluster901
# done with cluster902
# done with cluster903
# done with cluster904
# done with cluster905
# done with cluster906
# done with cluster907
# done with cluster908
# done with cluster909
# done with cluster910
# done with cluster911
# done with cluster912
# Ising skipped!!
# done with cluster914
# Ising skipped!!
# Ising skipped!!
# done with cluster917
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# done with cluster922
# Ising skipped!!
# Ising skipped!!
# done with cluster925
# done with cluster926
# Ising skipped!!
# done with cluster928
# done with cluster929
# done with cluster930
# done with cluster931
# done with cluster932
# done with cluster933
# done with cluster934
# done with cluster935
# done with cluster936
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# done with cluster942
# done with cluster943
# Ising skipped!!
# Ising skipped!!
# done with cluster946
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# done with cluster952
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# done with cluster956
# done with cluster957
# done with cluster958
# done with cluster959
# done with cluster960
# done with cluster961
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# done with cluster965
# done with cluster966
# Ising skipped!!
# done with cluster968
# done with cluster969
# done with cluster970
# Ising skipped!!
# Ising skipped!!
# done with cluster973
# done with cluster974
# done with cluster975
# done with cluster976
# done with cluster977
# done with cluster978
# done with cluster979
# done with cluster980
# done with cluster981
# done with cluster982
# done with cluster983
# done with cluster984
# done with cluster985
# done with cluster986
# done with cluster987
# done with cluster988
# done with cluster989
# done with cluster990
# done with cluster991
# done with cluster992
# done with cluster993
# done with cluster994
# done with cluster995
# done with cluster996
# done with cluster997
# done with cluster998
# done with cluster999
# done with cluster1000
# done with cluster1001
# done with cluster1002
# Ising skipped!!
# done with cluster1004
# done with cluster1005
# done with cluster1006
# done with cluster1007
# done with cluster1008
# done with cluster1009
# Ising skipped!!
# done with cluster1011
# done with cluster1012
# done with cluster1013
# done with cluster1014
# done with cluster1015
# Ising skipped!!
# Ising skipped!!
# done with cluster1018
# done with cluster1019
# done with cluster1020
# done with cluster1021
# Ising skipped!!
# done with cluster1023
# done with cluster1024
# done with cluster1025
# done with cluster1026
# done with cluster1027
# done with cluster1028
# done with cluster1029
# done with cluster1030
# done with cluster1031
# done with cluster1032
# done with cluster1033
# done with cluster1034
# done with cluster1035
# done with cluster1036
# done with cluster1037
# done with cluster1038
# done with cluster1039
# done with cluster1040
# done with cluster1041
# done with cluster1042
# Ising skipped!!
# done with cluster1044
# done with cluster1045
# Ising skipped!!
# done with cluster1047
# done with cluster1048
# done with cluster1049
# done with cluster1050
# done with cluster1051
# done with cluster1052
# done with cluster1053
# done with cluster1054
# done with cluster1055
# Ising skipped!!
# done with cluster1057
# done with cluster1058
# done with cluster1059
# done with cluster1060
# done with cluster1061
# done with cluster1062
# done with cluster1063
# done with cluster1064
# done with cluster1065
# done with cluster1066
# done with cluster1067
# done with cluster1068
# done with cluster1069
# done with cluster1070
# done with cluster1071
# done with cluster1072
# Ising skipped!!
# done with cluster1074
# done with cluster1075
# done with cluster1076
# done with cluster1077
# done with cluster1078
# Ising skipped!!
# done with cluster1080
# done with cluster1081
# done with cluster1082
# done with cluster1083
# done with cluster1084
# done with cluster1085
# done with cluster1086
# done with cluster1087
# done with cluster1088
# done with cluster1089
# done with cluster1090
# done with cluster1091
# done with cluster1092
# done with cluster1093
# done with cluster1094
# done with cluster1095
# done with cluster1096
# done with cluster1097
# done with cluster1098
# done with cluster1099
# done with cluster1100
# done with cluster1101
# done with cluster1102
# done with cluster1103
# done with cluster1104
# done with cluster1105
# done with cluster1106
# done with cluster1107
# done with cluster1108
# done with cluster1109
# Ising skipped!!
# done with cluster1111
# done with cluster1112
# done with cluster1113
# done with cluster1114
# Ising skipped!!
# done with cluster1116
# done with cluster1117
# done with cluster1118
# done with cluster1119
# done with cluster1120
# done with cluster1121
# done with cluster1122
# done with cluster1123
# done with cluster1124
# done with cluster1125
# done with cluster1126
# done with cluster1127
# done with cluster1128
# done with cluster1129
# done with cluster1130
# done with cluster1131
# done with cluster1132
# done with cluster1133
# done with cluster1134
# done with cluster1135
# done with cluster1136
# done with cluster1137
# done with cluster1138
# Ising skipped!!
# done with cluster1140
# done with cluster1141
# done with cluster1142
# done with cluster1143
# done with cluster1144
# done with cluster1145
# done with cluster1146
# done with cluster1147
# Ising skipped!!
# done with cluster1149
# Ising skipped!!
# done with cluster1151
# Ising skipped!!
# done with cluster1153
# done with cluster1154
# done with cluster1155
# done with cluster1156
# done with cluster1157
# done with cluster1158
# done with cluster1159
# done with cluster1160
# done with cluster1161
# done with cluster1162
# done with cluster1163
# done with cluster1164
# done with cluster1165
# done with cluster1166
# done with cluster1167
# done with cluster1168
# done with cluster1169
# done with cluster1170
# done with cluster1171
# done with cluster1172
# Ising skipped!!
# done with cluster1174
# Ising skipped!!
# done with cluster1176
# done with cluster1177
# done with cluster1178
# done with cluster1179
# done with cluster1180
# done with cluster1181
# Ising skipped!!
# done with cluster1183
# done with cluster1184
# Ising skipped!!
# Ising skipped!!
# done with cluster1187
# done with cluster1188
# done with cluster1189
# done with cluster1190
# done with cluster1191
# done with cluster1192
# done with cluster1193
# done with cluster1194
# done with cluster1195
# Ising skipped!!
# done with cluster1197
# done with cluster1198
# done with cluster1199
# done with cluster1200
# Ising skipped!!
# done with cluster1202
# done with cluster1203
# done with cluster1204
# done with cluster1205
# done with cluster1206
# done with cluster1207
# done with cluster1208
# done with cluster1209
# done with cluster1210
# Ising skipped!!
# done with cluster1212
# Ising skipped!!
# done with cluster1214
# done with cluster1215
# done with cluster1216
# done with cluster1217
# done with cluster1218
# done with cluster1219
# done with cluster1220
# done with cluster1221
# done with cluster1222
# done with cluster1223
# Ising skipped!!
# Ising skipped!!
# done with cluster1226
# done with cluster1227
# done with cluster1228
# done with cluster1229
# done with cluster1230
# done with cluster1231
# done with cluster1232
# done with cluster1233
# done with cluster1234
# done with cluster1235
# done with cluster1236
# Ising skipped!!
# Ising skipped!!
# done with cluster1239
# done with cluster1240
# done with cluster1241
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# done with cluster1252
# Ising skipped!!
# done with cluster1254
# Ising skipped!!
# done with cluster1256
# Max/Min number of Ising Macro MAC Operations =  11682  /  0
# Execute Ising Solver for Hierarchy  0
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# hierarchy:  5  cluster:  4  distance within the cluster:  8000.0  total distance:  24770783.34490434
# done with cluster4
# hierarchy:  5  cluster:  5  distance within the cluster:  6000.0  total distance:  24776783.34490434
# done with cluster5
# hierarchy:  5  cluster:  6  distance within the cluster:  6000.0  total distance:  24782783.34490434
# done with cluster6
# hierarchy:  5  cluster:  7  distance within the cluster:  6000.0  total distance:  24788783.34490434
# done with cluster7
# hierarchy:  5  cluster:  8  distance within the cluster:  6000.0  total distance:  24794783.34490434
# done with cluster8
# Ising skipped!!
# hierarchy:  5  cluster:  10  distance within the cluster:  13412.6  total distance:  24810195.944904342
# done with cluster10
# hierarchy:  5  cluster:  11  distance within the cluster:  6000.0  total distance:  24816195.944904342
# done with cluster11
# hierarchy:  5  cluster:  12  distance within the cluster:  6183.03  total distance:  24822378.974904343
# done with cluster12
# hierarchy:  5  cluster:  13  distance within the cluster:  10000.0  total distance:  24832378.974904343
# done with cluster13
# Ising skipped!!
# hierarchy:  5  cluster:  15  distance within the cluster:  6183.03  total distance:  24843390.43202909
# done with cluster15
# hierarchy:  5  cluster:  16  distance within the cluster:  6183.03  total distance:  24849573.462029092
# done with cluster16
# hierarchy:  5  cluster:  17  distance within the cluster:  6226.41  total distance:  24855799.872029092
# done with cluster17
# hierarchy:  5  cluster:  18  distance within the cluster:  11054.8  total distance:  24866854.672029093
# done with cluster18
# hierarchy:  5  cluster:  19  distance within the cluster:  8296.23  total distance:  24875150.902029093
# done with cluster19
# hierarchy:  5  cluster:  20  distance within the cluster:  9075.99  total distance:  24884226.89202909
# done with cluster20
# hierarchy:  5  cluster:  21  distance within the cluster:  6000.0  total distance:  24890226.89202909
# done with cluster21
# hierarchy:  5  cluster:  22  distance within the cluster:  2940.42  total distance:  24893167.312029094
# done with cluster22
# hierarchy:  5  cluster:  23  distance within the cluster:  2940.42  total distance:  24896107.732029095
# done with cluster23
# hierarchy:  5  cluster:  24  distance within the cluster:  2940.42  total distance:  24899048.152029097
# done with cluster24
# hierarchy:  5  cluster:  25  distance within the cluster:  2940.42  total distance:  24901988.5720291
# done with cluster25
# hierarchy:  5  cluster:  26  distance within the cluster:  4950.45  total distance:  24906939.022029098
# done with cluster26
# hierarchy:  5  cluster:  27  distance within the cluster:  9168.98  total distance:  24916108.0020291
# done with cluster27
# hierarchy:  5  cluster:  28  distance within the cluster:  2940.42  total distance:  24919048.4220291
# done with cluster28
# hierarchy:  5  cluster:  29  distance within the cluster:  2940.42  total distance:  24921988.842029102
# done with cluster29
# hierarchy:  5  cluster:  30  distance within the cluster:  2940.42  total distance:  24924929.262029104
# done with cluster30
# hierarchy:  5  cluster:  31  distance within the cluster:  3860.78  total distance:  24928790.042029105
# done with cluster31
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# hierarchy:  5  cluster:  36  distance within the cluster:  6000.0  total distance:  24934790.042029105
# done with cluster36
# hierarchy:  5  cluster:  37  distance within the cluster:  8000.0  total distance:  24942790.042029105
# done with cluster37
# hierarchy:  5  cluster:  38  distance within the cluster:  12113.2  total distance:  24954903.242029104
# done with cluster38
# hierarchy:  5  cluster:  39  distance within the cluster:  6113.2  total distance:  24961016.442029104
# done with cluster39
# hierarchy:  5  cluster:  40  distance within the cluster:  6000.0  total distance:  24967016.442029104
# done with cluster40
# hierarchy:  5  cluster:  41  distance within the cluster:  6000.0  total distance:  24973016.442029104
# done with cluster41
# hierarchy:  5  cluster:  42  distance within the cluster:  6000.0  total distance:  24979016.442029104
# done with cluster42
# hierarchy:  5  cluster:  43  distance within the cluster:  6000.0  total distance:  24985016.442029104
# done with cluster43
# hierarchy:  5  cluster:  44  distance within the cluster:  5262.67  total distance:  24990279.112029105
# done with cluster44
# Ising skipped!!
# hierarchy:  5  cluster:  46  distance within the cluster:  8000.0  total distance:  25009075.80330444
# done with cluster46
# hierarchy:  5  cluster:  47  distance within the cluster:  6000.0  total distance:  25015075.80330444
# done with cluster47
# hierarchy:  5  cluster:  48  distance within the cluster:  4930.39  total distance:  25020006.193304442
# done with cluster48
# hierarchy:  5  cluster:  49  distance within the cluster:  4950.45  total distance:  25024956.64330444
# done with cluster49
# hierarchy:  5  cluster:  50  distance within the cluster:  9168.98  total distance:  25034125.62330444
# done with cluster50
# hierarchy:  5  cluster:  51  distance within the cluster:  2940.42  total distance:  25037066.043304443
# done with cluster51
# hierarchy:  5  cluster:  52  distance within the cluster:  2940.42  total distance:  25040006.463304445
# done with cluster52
# hierarchy:  5  cluster:  53  distance within the cluster:  2940.42  total distance:  25042946.883304447
# done with cluster53
# hierarchy:  5  cluster:  54  distance within the cluster:  8000.0  total distance:  25050946.883304447
# done with cluster54
# hierarchy:  5  cluster:  55  distance within the cluster:  6000.0  total distance:  25056946.883304447
# done with cluster55
# Ising skipped!!
# hierarchy:  5  cluster:  57  distance within the cluster:  6000.0  total distance:  25067775.310429193
# done with cluster57
# Ising skipped!!
# hierarchy:  5  cluster:  59  distance within the cluster:  8000.0  total distance:  25080603.73755394
# done with cluster59
# hierarchy:  5  cluster:  60  distance within the cluster:  14000.0  total distance:  25094603.73755394
# done with cluster60
# Ising skipped!!
# Ising skipped!!
# hierarchy:  5  cluster:  63  distance within the cluster:  6940.42  total distance:  25107544.15755394
# done with cluster63
# hierarchy:  5  cluster:  64  distance within the cluster:  8155.47  total distance:  25115699.62755394
# done with cluster64
# hierarchy:  5  cluster:  65  distance within the cluster:  7225.08  total distance:  25122924.707553938
# done with cluster65
# hierarchy:  5  cluster:  66  distance within the cluster:  8848.49  total distance:  25131773.197553936
# done with cluster66
# hierarchy:  5  cluster:  67  distance within the cluster:  18944.3  total distance:  25150717.497553937
# done with cluster67
# hierarchy:  5  cluster:  68  distance within the cluster:  11656.9  total distance:  25162374.397553936
# done with cluster68
# hierarchy:  5  cluster:  69  distance within the cluster:  12828.4  total distance:  25175202.797553934
# done with cluster69
# hierarchy:  5  cluster:  70  distance within the cluster:  8000.0  total distance:  25183202.797553934
# done with cluster70
# hierarchy:  5  cluster:  71  distance within the cluster:  8183.03  total distance:  25191385.827553935
# done with cluster71
# hierarchy:  5  cluster:  72  distance within the cluster:  6828.43  total distance:  25198214.257553935
# done with cluster72
# hierarchy:  5  cluster:  73  distance within the cluster:  14828.4  total distance:  25213042.657553934
# done with cluster73
# hierarchy:  5  cluster:  74  distance within the cluster:  10000.0  total distance:  25223042.657553934
# done with cluster74
# hierarchy:  5  cluster:  75  distance within the cluster:  15306.0  total distance:  25238348.657553934
# done with cluster75
# hierarchy:  5  cluster:  76  distance within the cluster:  2940.42  total distance:  25241289.077553935
# done with cluster76
# hierarchy:  5  cluster:  77  distance within the cluster:  8930.39  total distance:  25250219.467553936
# done with cluster77
# hierarchy:  5  cluster:  78  distance within the cluster:  13124.4  total distance:  25263343.867553934
# done with cluster78
# hierarchy:  5  cluster:  79  distance within the cluster:  4950.45  total distance:  25268294.317553934
# done with cluster79
# hierarchy:  5  cluster:  80  distance within the cluster:  2940.42  total distance:  25271234.737553935
# done with cluster80
# hierarchy:  5  cluster:  81  distance within the cluster:  2940.42  total distance:  25274175.157553937
# done with cluster81
# hierarchy:  5  cluster:  82  distance within the cluster:  2940.42  total distance:  25277115.57755394
# done with cluster82
# hierarchy:  5  cluster:  83  distance within the cluster:  2940.42  total distance:  25280055.99755394
# done with cluster83
# hierarchy:  5  cluster:  84  distance within the cluster:  4930.39  total distance:  25284986.38755394
# done with cluster84
# hierarchy:  5  cluster:  85  distance within the cluster:  4930.39  total distance:  25289916.777553942
# done with cluster85
# Ising skipped!!
# hierarchy:  5  cluster:  87  distance within the cluster:  18000.0  total distance:  25312029.980099842
# done with cluster87
# hierarchy:  5  cluster:  88  distance within the cluster:  10000.0  total distance:  25322029.980099842
# done with cluster88
# hierarchy:  5  cluster:  89  distance within the cluster:  6000.0  total distance:  25328029.980099842
# done with cluster89
# hierarchy:  5  cluster:  90  distance within the cluster:  15815.5  total distance:  25343845.480099842
# done with cluster90
# hierarchy:  5  cluster:  91  distance within the cluster:  6000.0  total distance:  25349845.480099842
# done with cluster91
# hierarchy:  5  cluster:  92  distance within the cluster:  16158.6  total distance:  25366004.080099843
# done with cluster92
# hierarchy:  5  cluster:  93  distance within the cluster:  6000.0  total distance:  25372004.080099843
# done with cluster93
# hierarchy:  5  cluster:  94  distance within the cluster:  10000.0  total distance:  25382004.080099843
# done with cluster94
# hierarchy:  5  cluster:  95  distance within the cluster:  6828.43  total distance:  25388832.510099843
# done with cluster95
# hierarchy:  5  cluster:  96  distance within the cluster:  15656.9  total distance:  25404489.41009984
# done with cluster96
# hierarchy:  5  cluster:  97  distance within the cluster:  8838.46  total distance:  25413327.870099843
# done with cluster97
# hierarchy:  5  cluster:  98  distance within the cluster:  7656.85  total distance:  25420984.720099844
# done with cluster98
# hierarchy:  5  cluster:  99  distance within the cluster:  8472.14  total distance:  25429456.860099845
# done with cluster99
# hierarchy:  5  cluster:  100  distance within the cluster:  14000.0  total distance:  25443456.860099845
# done with cluster100
# hierarchy:  5  cluster:  101  distance within the cluster:  14828.4  total distance:  25458285.260099843
# done with cluster101
# hierarchy:  5  cluster:  102  distance within the cluster:  9666.89  total distance:  25467952.150099844
# done with cluster102
# hierarchy:  5  cluster:  103  distance within the cluster:  11666.9  total distance:  25479619.050099842
# done with cluster103
# hierarchy:  5  cluster:  104  distance within the cluster:  6828.43  total distance:  25486447.480099842
# done with cluster104
# hierarchy:  5  cluster:  105  distance within the cluster:  6828.43  total distance:  25493275.91009984
# done with cluster105
# hierarchy:  5  cluster:  106  distance within the cluster:  14828.4  total distance:  25508104.31009984
# done with cluster106
# hierarchy:  5  cluster:  107  distance within the cluster:  15656.9  total distance:  25523761.21009984
# done with cluster107
# hierarchy:  5  cluster:  108  distance within the cluster:  10010.0  total distance:  25533771.21009984
# done with cluster108
# hierarchy:  5  cluster:  109  distance within the cluster:  11300.6  total distance:  25545071.81009984
# done with cluster109
# hierarchy:  5  cluster:  110  distance within the cluster:  10828.4  total distance:  25555900.21009984
# done with cluster110
# hierarchy:  5  cluster:  111  distance within the cluster:  6828.43  total distance:  25562728.64009984
# done with cluster111
# hierarchy:  5  cluster:  112  distance within the cluster:  6828.43  total distance:  25569557.070099838
# done with cluster112
# hierarchy:  5  cluster:  113  distance within the cluster:  6000.0  total distance:  25575557.070099838
# done with cluster113
# hierarchy:  5  cluster:  114  distance within the cluster:  6828.43  total distance:  25582385.500099838
# done with cluster114
# hierarchy:  5  cluster:  115  distance within the cluster:  6010.03  total distance:  25588395.53009984
# done with cluster115
# hierarchy:  5  cluster:  116  distance within the cluster:  8155.47  total distance:  25596551.000099838
# done with cluster116
# hierarchy:  5  cluster:  117  distance within the cluster:  8155.47  total distance:  25604706.470099837
# done with cluster117
# hierarchy:  5  cluster:  118  distance within the cluster:  10587.2  total distance:  25615293.670099836
# done with cluster118
# Ising skipped!!
# hierarchy:  5  cluster:  120  distance within the cluster:  14828.4  total distance:  25635048.77900234
# done with cluster120
# hierarchy:  5  cluster:  121  distance within the cluster:  14828.4  total distance:  25649877.179002337
# done with cluster121
# hierarchy:  5  cluster:  122  distance within the cluster:  6113.2  total distance:  25655990.379002336
# done with cluster122
# hierarchy:  5  cluster:  123  distance within the cluster:  12366.1  total distance:  25668356.479002338
# done with cluster123
# hierarchy:  5  cluster:  124  distance within the cluster:  10828.4  total distance:  25679184.879002336
# done with cluster124
# hierarchy:  5  cluster:  125  distance within the cluster:  10407.9  total distance:  25689592.779002335
# done with cluster125
# hierarchy:  5  cluster:  126  distance within the cluster:  16495.3  total distance:  25706088.079002336
# done with cluster126
# hierarchy:  5  cluster:  127  distance within the cluster:  10073.6  total distance:  25716161.679002337
# done with cluster127
# hierarchy:  5  cluster:  128  distance within the cluster:  15656.9  total distance:  25731818.579002336
# done with cluster128
# hierarchy:  5  cluster:  129  distance within the cluster:  6000.0  total distance:  25737818.579002336
# done with cluster129
# hierarchy:  5  cluster:  130  distance within the cluster:  12858.5  total distance:  25750677.079002336
# done with cluster130
# hierarchy:  5  cluster:  131  distance within the cluster:  6828.43  total distance:  25757505.509002335
# done with cluster131
# hierarchy:  5  cluster:  132  distance within the cluster:  20485.3  total distance:  25777990.809002336
# done with cluster132
# hierarchy:  5  cluster:  133  distance within the cluster:  11666.9  total distance:  25789657.709002335
# done with cluster133
# hierarchy:  5  cluster:  134  distance within the cluster:  12828.4  total distance:  25802486.109002333
# done with cluster134
# hierarchy:  5  cluster:  135  distance within the cluster:  12828.4  total distance:  25815314.50900233
# done with cluster135
# hierarchy:  5  cluster:  136  distance within the cluster:  8848.49  total distance:  25824162.99900233
# done with cluster136
# hierarchy:  5  cluster:  137  distance within the cluster:  14016.4  total distance:  25838179.39900233
# done with cluster137
# hierarchy:  5  cluster:  138  distance within the cluster:  12828.4  total distance:  25851007.799002327
# done with cluster138
# hierarchy:  5  cluster:  139  distance within the cluster:  10376.1  total distance:  25861383.89900233
# done with cluster139
# hierarchy:  5  cluster:  140  distance within the cluster:  6010.03  total distance:  25867393.92900233
# done with cluster140
# hierarchy:  5  cluster:  141  distance within the cluster:  10366.1  total distance:  25877760.02900233
# done with cluster141
# hierarchy:  5  cluster:  142  distance within the cluster:  15056.9  total distance:  25892816.92900233
# done with cluster142
# hierarchy:  5  cluster:  143  distance within the cluster:  12337.3  total distance:  25905154.22900233
# done with cluster143
# hierarchy:  5  cluster:  144  distance within the cluster:  8472.14  total distance:  25913626.36900233
# done with cluster144
# hierarchy:  5  cluster:  145  distance within the cluster:  10000.0  total distance:  25923626.36900233
# done with cluster145
# hierarchy:  5  cluster:  146  distance within the cluster:  6193.06  total distance:  25929819.42900233
# done with cluster146
# hierarchy:  5  cluster:  147  distance within the cluster:  7614.64  total distance:  25937434.06900233
# done with cluster147
# hierarchy:  5  cluster:  148  distance within the cluster:  6828.43  total distance:  25944262.49900233
# done with cluster148
# hierarchy:  5  cluster:  149  distance within the cluster:  6000.0  total distance:  25950262.49900233
# done with cluster149
# hierarchy:  5  cluster:  150  distance within the cluster:  14000.0  total distance:  25964262.49900233
# done with cluster150
# hierarchy:  5  cluster:  151  distance within the cluster:  12296.2  total distance:  25976558.69900233
# done with cluster151
# hierarchy:  5  cluster:  152  distance within the cluster:  12191.2  total distance:  25988749.89900233
# done with cluster152
# hierarchy:  5  cluster:  153  distance within the cluster:  8265.85  total distance:  25997015.74900233
# done with cluster153
# hierarchy:  5  cluster:  154  distance within the cluster:  6940.42  total distance:  26003956.16900233
# ...
# done with cluster6316
# hierarchy:  5  cluster:  6317  distance within the cluster:  4930.39  total distance:  80072623.1244714
# done with cluster6317
# hierarchy:  5  cluster:  6318  distance within the cluster:  9664.98  total distance:  80082288.1044714
# done with cluster6318
# hierarchy:  5  cluster:  6319  distance within the cluster:  11306.9  total distance:  80093595.0044714
# done with cluster6319
# hierarchy:  5  cluster:  6320  distance within the cluster:  8021.27  total distance:  80101616.2744714
# done with cluster6320
# hierarchy:  5  cluster:  6321  distance within the cluster:  12227.3  total distance:  80113843.5744714
# done with cluster6321
# hierarchy:  5  cluster:  6322  distance within the cluster:  8834.78  total distance:  80122678.3544714
# done with cluster6322
# hierarchy:  5  cluster:  6323  distance within the cluster:  4787.49  total distance:  80127465.8444714
# done with cluster6323
# hierarchy:  5  cluster:  6324  distance within the cluster:  10000.0  total distance:  80137465.8444714
# done with cluster6324
# hierarchy:  5  cluster:  6325  distance within the cluster:  4930.39  total distance:  80142396.2344714
# done with cluster6325
# hierarchy:  5  cluster:  6326  distance within the cluster:  8000.0  total distance:  80150396.2344714
# done with cluster6326
# hierarchy:  5  cluster:  6327  distance within the cluster:  3860.78  total distance:  80154257.0144714
# done with cluster6327
# hierarchy:  5  cluster:  6328  distance within the cluster:  2940.42  total distance:  80157197.4344714
# done with cluster6328
# hierarchy:  5  cluster:  6329  distance within the cluster:  4930.39  total distance:  80162127.8244714
# done with cluster6329
# hierarchy:  5  cluster:  6330  distance within the cluster:  10000.0  total distance:  80172127.8244714
# done with cluster6330
# hierarchy:  5  cluster:  6331  distance within the cluster:  4930.39  total distance:  80177058.2144714
# done with cluster6331
# hierarchy:  5  cluster:  6332  distance within the cluster:  8000.0  total distance:  80185058.2144714
# done with cluster6332
# hierarchy:  5  cluster:  6333  distance within the cluster:  3860.78  total distance:  80188918.9944714
# done with cluster6333
# hierarchy:  5  cluster:  6334  distance within the cluster:  4930.39  total distance:  80193849.3844714
# done with cluster6334
# hierarchy:  5  cluster:  6335  distance within the cluster:  8000.0  total distance:  80201849.3844714
# done with cluster6335
# hierarchy:  5  cluster:  6336  distance within the cluster:  3860.78  total distance:  80205710.1644714
# done with cluster6336
# hierarchy:  5  cluster:  6337  distance within the cluster:  4930.39  total distance:  80210640.5544714
# done with cluster6337
# hierarchy:  5  cluster:  6338  distance within the cluster:  8000.0  total distance:  80218640.5544714
# done with cluster6338
# hierarchy:  5  cluster:  6339  distance within the cluster:  3860.78  total distance:  80222501.3344714
# done with cluster6339
# hierarchy:  5  cluster:  6340  distance within the cluster:  4930.39  total distance:  80227431.7244714
# done with cluster6340
# hierarchy:  5  cluster:  6341  distance within the cluster:  6000.0  total distance:  80233431.7244714
# done with cluster6341
# hierarchy:  5  cluster:  6342  distance within the cluster:  8000.0  total distance:  80241431.7244714
# done with cluster6342
# hierarchy:  5  cluster:  6343  distance within the cluster:  4930.39  total distance:  80246362.1144714
# done with cluster6343
# hierarchy:  5  cluster:  6344  distance within the cluster:  2940.42  total distance:  80249302.53447141
# done with cluster6344
# hierarchy:  5  cluster:  6345  distance within the cluster:  4930.39  total distance:  80254232.92447141
# done with cluster6345
# hierarchy:  5  cluster:  6346  distance within the cluster:  9509.2  total distance:  80263742.12447141
# done with cluster6346
# hierarchy:  5  cluster:  6347  distance within the cluster:  6226.41  total distance:  80269968.53447141
# done with cluster6347
# hierarchy:  5  cluster:  6348  distance within the cluster:  6183.03  total distance:  80276151.56447141
# done with cluster6348
# hierarchy:  5  cluster:  6349  distance within the cluster:  16583.6  total distance:  80292735.1644714
# done with cluster6349
# hierarchy:  5  cluster:  6350  distance within the cluster:  11306.9  total distance:  80304042.06447141
# done with cluster6350
# hierarchy:  5  cluster:  6351  distance within the cluster:  4930.39  total distance:  80308972.45447141
# done with cluster6351
# hierarchy:  5  cluster:  6352  distance within the cluster:  2940.42  total distance:  80311912.87447141
# done with cluster6352
# hierarchy:  5  cluster:  6353  distance within the cluster:  2940.42  total distance:  80314853.29447141
# done with cluster6353
# hierarchy:  5  cluster:  6354  distance within the cluster:  4930.39  total distance:  80319783.68447141
# done with cluster6354
# hierarchy:  5  cluster:  6355  distance within the cluster:  6226.41  total distance:  80326010.09447141
# done with cluster6355
# hierarchy:  5  cluster:  6356  distance within the cluster:  6113.2  total distance:  80332123.29447141
# done with cluster6356
# hierarchy:  5  cluster:  6357  distance within the cluster:  6000.0  total distance:  80338123.29447141
# done with cluster6357
# hierarchy:  5  cluster:  6358  distance within the cluster:  6828.43  total distance:  80344951.72447142
# done with cluster6358
# hierarchy:  5  cluster:  6359  distance within the cluster:  8021.27  total distance:  80352972.99447142
# done with cluster6359
# hierarchy:  5  cluster:  6360  distance within the cluster:  6000.0  total distance:  80358972.99447142
# done with cluster6360
# hierarchy:  5  cluster:  6361  distance within the cluster:  6828.43  total distance:  80365801.42447142
# done with cluster6361
# hierarchy:  5  cluster:  6362  distance within the cluster:  8736.5  total distance:  80374537.92447142
# done with cluster6362
# hierarchy:  5  cluster:  6363  distance within the cluster:  6000.0  total distance:  80380537.92447142
# done with cluster6363
# hierarchy:  5  cluster:  6364  distance within the cluster:  6828.43  total distance:  80387366.35447143
# done with cluster6364
# hierarchy:  5  cluster:  6365  distance within the cluster:  8736.5  total distance:  80396102.85447143
# done with cluster6365
# hierarchy:  5  cluster:  6366  distance within the cluster:  6000.0  total distance:  80402102.85447143
# done with cluster6366
# hierarchy:  5  cluster:  6367  distance within the cluster:  6828.43  total distance:  80408931.28447144
# done with cluster6367
# hierarchy:  5  cluster:  6368  distance within the cluster:  8736.5  total distance:  80417667.78447144
# done with cluster6368
# hierarchy:  5  cluster:  6369  distance within the cluster:  6000.0  total distance:  80423667.78447144
# done with cluster6369
# hierarchy:  5  cluster:  6370  distance within the cluster:  6000.0  total distance:  80429667.78447144
# done with cluster6370
# hierarchy:  5  cluster:  6371  distance within the cluster:  6828.43  total distance:  80436496.21447144
# done with cluster6371
# hierarchy:  5  cluster:  6372  distance within the cluster:  11551.8  total distance:  80448048.01447144
# done with cluster6372
# hierarchy:  5  cluster:  6373  distance within the cluster:  4930.39  total distance:  80452978.40447144
# done with cluster6373
# hierarchy:  5  cluster:  6374  distance within the cluster:  2940.42  total distance:  80455918.82447144
# done with cluster6374
# hierarchy:  5  cluster:  6375  distance within the cluster:  4930.39  total distance:  80460849.21447144
# done with cluster6375
# hierarchy:  5  cluster:  6376  distance within the cluster:  2940.42  total distance:  80463789.63447145
# done with cluster6376
# hierarchy:  5  cluster:  6377  distance within the cluster:  2940.42  total distance:  80466730.05447145
# done with cluster6377
# hierarchy:  5  cluster:  6378  distance within the cluster:  2940.42  total distance:  80469670.47447145
# done with cluster6378
# hierarchy:  5  cluster:  6379  distance within the cluster:  4930.39  total distance:  80474600.86447145
# done with cluster6379
# hierarchy:  5  cluster:  6380  distance within the cluster:  4930.39  total distance:  80479531.25447145
# done with cluster6380
# hierarchy:  5  cluster:  6381  distance within the cluster:  9664.98  total distance:  80489196.23447146
# done with cluster6381
# hierarchy:  5  cluster:  6382  distance within the cluster:  8021.27  total distance:  80497217.50447145
# done with cluster6382
# hierarchy:  5  cluster:  6383  distance within the cluster:  8021.27  total distance:  80505238.77447145
# done with cluster6383
# hierarchy:  5  cluster:  6384  distance within the cluster:  8834.78  total distance:  80514073.55447145
# done with cluster6384
# hierarchy:  5  cluster:  6385  distance within the cluster:  2940.42  total distance:  80517013.97447145
# done with cluster6385
# hierarchy:  5  cluster:  6386  distance within the cluster:  2940.42  total distance:  80519954.39447145
# done with cluster6386
# hierarchy:  5  cluster:  6387  distance within the cluster:  2940.42  total distance:  80522894.81447145
# done with cluster6387
# hierarchy:  5  cluster:  6388  distance within the cluster:  7063.65  total distance:  80529958.46447146
# done with cluster6388
# hierarchy:  5  cluster:  6389  distance within the cluster:  6000.0  total distance:  80535958.46447146
# done with cluster6389
# hierarchy:  5  cluster:  6390  distance within the cluster:  6000.0  total distance:  80541958.46447146
# done with cluster6390
# hierarchy:  5  cluster:  6391  distance within the cluster:  2940.42  total distance:  80544898.88447146
# done with cluster6391
# hierarchy:  5  cluster:  6392  distance within the cluster:  3860.78  total distance:  80548759.66447146
# done with cluster6392
# hierarchy:  5  cluster:  6393  distance within the cluster:  10000.0  total distance:  80558759.66447146
# done with cluster6393
# hierarchy:  5  cluster:  6394  distance within the cluster:  12607.3  total distance:  80571366.96447146
# done with cluster6394
# hierarchy:  5  cluster:  6395  distance within the cluster:  3860.78  total distance:  80575227.74447146
# done with cluster6395
# hierarchy:  5  cluster:  6396  distance within the cluster:  10000.0  total distance:  80585227.74447146
# done with cluster6396
# hierarchy:  5  cluster:  6397  distance within the cluster:  2940.42  total distance:  80588168.16447146
# done with cluster6397
# hierarchy:  5  cluster:  6398  distance within the cluster:  2940.42  total distance:  80591108.58447146
# done with cluster6398
# hierarchy:  5  cluster:  6399  distance within the cluster:  3860.78  total distance:  80594969.36447147
# done with cluster6399
# hierarchy:  5  cluster:  6400  distance within the cluster:  10000.0  total distance:  80604969.36447147
# done with cluster6400
# hierarchy:  5  cluster:  6401  distance within the cluster:  10000.0  total distance:  80614969.36447147
# done with cluster6401
# hierarchy:  5  cluster:  6402  distance within the cluster:  10000.0  total distance:  80624969.36447147
# done with cluster6402
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# hierarchy:  5  cluster:  6407  distance within the cluster:  10000.0  total distance:  80634969.36447147
# done with cluster6407
# hierarchy:  5  cluster:  6408  distance within the cluster:  10000.0  total distance:  80644969.36447147
# done with cluster6408
# hierarchy:  5  cluster:  6409  distance within the cluster:  6000.0  total distance:  80650969.36447147
# done with cluster6409
# hierarchy:  5  cluster:  6410  distance within the cluster:  6000.0  total distance:  80656969.36447147
# done with cluster6410
# hierarchy:  5  cluster:  6411  distance within the cluster:  6000.0  total distance:  80662969.36447147
# done with cluster6411
# hierarchy:  5  cluster:  6412  distance within the cluster:  6000.0  total distance:  80668969.36447147
# done with cluster6412
# hierarchy:  5  cluster:  6413  distance within the cluster:  10000.0  total distance:  80678969.36447147
# done with cluster6413
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# Ising skipped!!
# hierarchy:  5  cluster:  6418  distance within the cluster:  6000.0  total distance:  80684969.36447147
# done with cluster6418
# hierarchy:  5  cluster:  6419  distance within the cluster:  10000.0  total distance:  80694969.36447147
# done with cluster6419
# hierarchy:  5  cluster:  6420  distance within the cluster:  6000.0  total distance:  80700969.36447147
# done with cluster6420
# hierarchy:  5  cluster:  6421  distance within the cluster:  6000.0  total distance:  80706969.36447147
# done with cluster6421
# hierarchy:  5  cluster:  6422  distance within the cluster:  10000.0  total distance:  80716969.36447147
# done with cluster6422
# hierarchy:  5  cluster:  6423  distance within the cluster:  10000.0  total distance:  80726969.36447147
# done with cluster6423
# hierarchy:  5  cluster:  6424  distance within the cluster:  10000.0  total distance:  80736969.36447147
# done with cluster6424
# hierarchy:  5  cluster:  6425  distance within the cluster:  4930.39  total distance:  80741899.75447147
# done with cluster6425
# hierarchy:  5  cluster:  6426  distance within the cluster:  14248.6  total distance:  80756148.35447146
# done with cluster6426
# hierarchy:  5  cluster:  6427  distance within the cluster:  2940.42  total distance:  80759088.77447146
# done with cluster6427
# hierarchy:  5  cluster:  6428  distance within the cluster:  10478.5  total distance:  80769567.27447146
# done with cluster6428
# hierarchy:  5  cluster:  6429  distance within the cluster:  8834.78  total distance:  80778402.05447146
# done with cluster6429
# hierarchy:  5  cluster:  6430  distance within the cluster:  8930.39  total distance:  80787332.44447146
# done with cluster6430
# hierarchy:  5  cluster:  6431  distance within the cluster:  9143.47  total distance:  80796475.91447146
# done with cluster6431
# hierarchy:  5  cluster:  6432  distance within the cluster:  6000.0  total distance:  80802475.91447146
# done with cluster6432
# hierarchy:  5  cluster:  6433  distance within the cluster:  10940.4  total distance:  80813416.31447147
# done with cluster6433
# hierarchy:  5  cluster:  6434  distance within the cluster:  4930.39  total distance:  80818346.70447147
# done with cluster6434
# hierarchy:  5  cluster:  6435  distance within the cluster:  15131.0  total distance:  80833477.70447147
# done with cluster6435
# hierarchy:  5  cluster:  6436  distance within the cluster:  13908.1  total distance:  80847385.80447146
# done with cluster6436
# hierarchy:  5  cluster:  6437  distance within the cluster:  8296.23  total distance:  80855682.03447147
# done with cluster6437
# hierarchy:  5  cluster:  6438  distance within the cluster:  4930.39  total distance:  80860612.42447147
# done with cluster6438
# hierarchy:  5  cluster:  6439  distance within the cluster:  9143.47  total distance:  80869755.89447147
# done with cluster6439
# hierarchy:  5  cluster:  6440  distance within the cluster:  8000.0  total distance:  80877755.89447147
# done with cluster6440
# hierarchy:  5  cluster:  6441  distance within the cluster:  3860.78  total distance:  80881616.67447147
# done with cluster6441
# hierarchy:  5  cluster:  6442  distance within the cluster:  4930.39  total distance:  80886547.06447147
# done with cluster6442
# hierarchy:  5  cluster:  6443  distance within the cluster:  8000.0  total distance:  80894547.06447147
# done with cluster6443
# hierarchy:  5  cluster:  6444  distance within the cluster:  3860.78  total distance:  80898407.84447147
# done with cluster6444
# hierarchy:  5  cluster:  6445  distance within the cluster:  2940.42  total distance:  80901348.26447147
# done with cluster6445
# Max/Min number of Ising Macro MAC Operations =  11682  /  0
# total wall-clock latency:  7.008841626346111
# Max nMAC per hierarchy:  [11682, 11682, 9086, 11682, 12980, 2596]
# total traveling distance:  80901348.26447147
# [5977, 985, 189, 26, 3, 1]
# [{4: 2602, 5: 641, 6: 1269, 7: 595, 8: 564, 9: 162, 10: 112, 11: 26, 12: 6}, {4: 274, 5: 193, 6: 227, 7: 118, 8: 90, 9: 53, 10: 18, 11: 8, 12: 4}, {4: 23, 5: 32, 6: 46, 7: 27, 8: 30, 9: 18, 10: 13}, {4: 1, 5: 8, 6: 1, 7: 5, 8: 4, 9: 2, 10: 4, 11: 1}, {7: 1, 9: 1, 12: 1}, {3: 1}]

# %%
if True:
    route = np.array(route_btw_clusters)
    sol_route = np.array(sol_route)
    for n in range(int(len(route_btw_clusters)/2)-1):
        plt.plot(route[2*n+1:2*(n+1)+1,0], route[2*n+1:2*(n+1)+1,1], '-')
    plt.scatter(sol_route[:,0], sol_route[:,1], c=sys2_labels[n_hierarchies][:], s=20)

    colors = 'rbk'
    sol_route_ex = sol_route_ex[1:]
    for H in range(len(sol_route_ex)):
        for n in range(len(sol_route_ex[H])):
            plt.text(sol_route_ex[H][n][0],sol_route_ex[H][n][1], str(n+1), fontsize = 10*(len(sol_route_ex)-H), color = colors[H])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/dynamo/a/yoo241/Project/Large-Scale-Ising/Large-Scale-Ising-TopDown.ipynb Cell 21 line 1
#      <a href='vscode-notebook-cell:/home/dynamo/a/yoo241/Project/Large-Scale-Ising/Large-Scale-Ising-TopDown.ipynb#X26sZmlsZQ%3D%3D?line=9'>10</a> for H in range(len(sol_route_ex)):
#      <a href='vscode-notebook-cell:/home/dynamo/a/yoo241/Project/Large-Scale-Ising/Large-Scale-Ising-TopDown.ipynb#X26sZmlsZQ%3D%3D?line=10'>11</a>     for n in range(len(sol_route_ex[H])):
# ---> <a href='vscode-notebook-cell:/home/dynamo/a/yoo241/Project/Large-Scale-Ising/Large-Scale-Ising-TopDown.ipynb#X26sZmlsZQ%3D%3D?line=11'>12</a>         plt.text(sol_route_ex[H][n][0],sol_route_ex[H][n][1], str(n+1), fontsize = 10*(len(sol_route_ex)-H), color = colors[H])
#      <a href='vscode-notebook-cell:/home/dynamo/a/yoo241/Project/Large-Scale-Ising/Large-Scale-Ising-TopDown.ipynb#X26sZmlsZQ%3D%3D?line=12'>13</a> plt.show()
#
# IndexError: string index out of range

# %%
from math import sin, cos, sqrt, atan2, radians
def compute_geo(p1,p2):
    R = 6373.0
    
    lat1 = radians(float(p1[0]))
    lon1 = radians(float(p1[1]))
    lat2 = radians(float(p2[0]))
    lon2 = radians(float(p2[1]))
    
    dlon = lon2 - lon1
    dlat = lat2 -lat1

    a = sin(dlat/2)**2 + cos(lat1)*cos(lat2)*sin(dlon/2)**2
    c = 2*atan2(sqrt(a),sqrt(1-a))
    dist = R*c
    return dist

# %%
coord_geo == False
if coord_geo == True:
#     test = np.load("sys2clusters_" + str(x) + "/sol_table.npy", allow_pickle=True)
    for i in range(len(test)):
        print(i)
        for j in range(len(test[i])):
            geo_dist = 0
            li = test[i][j][1]
            for idx,elem in enumerate(li):
                thiscity = elem
                nextcity = li[(idx+1)%len(li)]
                geo_dist += compute_geo(thiscity, nextcity)
            test[i][j][2] = geo_dist 
            print(geo_dist)
        np.save("sys2clusters_" + str(x) + "/sol_table" ,test)

# %% [markdown]
# mport pdb; pdb.set_trace()

# %%
## Sangmin edited
GO = False
if GO:
    with open("tsp" + x + "_pyconcorde.txt", "w") as f:
        solver = TSPSolver.from_data(X_coord, Y_coord, norm="EUC_2D")  
        solution = solver.solve()
        f.write( str(" ") + str('output') + str(" ") )
        f.write( str("solution found? ") + str(solution.found_tour) + str(" ") )
        f.write( str("Optimal value? ") + str(solution.optimal_value) + str(" ") )
        f.write( str(" ").join( str(node_idx+1) for node_idx in solution.tour) )
        f.write( str(" ") + str(solution.tour[0]+1) + str(" ") )

# %%
GO = False
if GO:
    num_samples = 10000
    set_nodes_coord = np.random.random([num_samples, n_clusters, 2])
    with open("tsp" + str(n_clusters) + "_pr1002.txt", "w") as f:
        solver = TSPSolver.from_data(centers[:,0], centers[:,1], norm="EUC_2D")  
        solution = solver.solve()
        f.write( " ".join( str(x)+str(" ")+str(y) for x,y in centers) )
        f.write( str(" ") + str('output') + str(" ") )
        f.write( str(" ").join( str(node_idx+1) for node_idx in solution.tour) )
        f.write( str(" ") + str(solution.tour[0]+1) + str(" ") )
