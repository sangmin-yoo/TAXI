# %%
import os
import time
import sys
from sklearn.cluster import KMeans
from sklearn import metrics
from scipy.spatial.distance import cdist
from scipy.spatial import KDTree, cKDTree
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from concorde.tsp import TSPSolver
from math import sqrt, ceil, inf, floor

# %%
root_dir = os.getcwd()
tsp_dir = os.path.join(root_dir, "../tsplib")
concorde_dir = os.path.join(root_dir, "../pyconcorde/concorde")

# %%
sys.path.insert(0, root_dir)
sys.path.insert(0, tsp_dir)
#sys.path.insert(0, concorde_dir)

# %%
num_samples = 10000

# %%
def gen_tsp_data():
    ## Load a tsp library and Create a dictionary "tsp_database" of Name-X/Y coordinates.

    tsp_database = {}
    cities = os.listdir(tsp_dir)
    
    for city in cities:
        if city.endswith(".tsp"):
            with open(tsp_dir + '/' + city, 'r') as infile:
                lines = infile.readlines()
                for i in range(0, len(lines)):
                    line = lines[i]
                    if "DIMENSION" in line:
                        Dimension = line.strip().split(':')[1]
                        if not Dimension.isdigit():
                            continue
                    if "EDGE_WEIGHT_TYPE" in line:
                        EdgeWeightType = line.strip().split()[1]
                        if EdgeWeightType != "EUC_2D":
                            continue
                    if "NODE_COORD_SECTION" in line:
                        x_y = None
                        nodelist_x = []
                        nodelist_y = []
        
                        for j in range (1, int(Dimension)):
                            x_y = lines[i+1].strip().split()[1:]
    #                        print(x_y)
    #                        import pdb; pdb.set_trace()
                            x = x_y[0]
                            y = x_y[1]
                            nodelist_x.append(float(x))
                            nodelist_y.append(float(y))
                            i+=1
                        tsp_database.update({city[:-4]:[nodelist_x, nodelist_y]})
    return tsp_database

# %%
tsp_database = gen_tsp_data()
problem_list = tsp_database.keys()
problem_list
# Out:
# dict_keys(['d15112', 'pla7397', 'd18512', 'd2103', 'fl1400', 'pr107', 'fl3795', 'pcb3038', 'pr2392', 'pla85900', 'usa13509', 'brd14051', 'pla33810', 'pr152', 'pr226', 'pr1002', 'u2152', 'rl5934', 'bier127', 'rl5915', 'u2319', 'rat783', 'rl11849', 'rat575', 'kroA100', 'eil101'])

# %%
import pyproj as p
#x = "kroA100"
#x = "rat575"
#x = "eil101"
#x = "pr107"
#x = "pr152"
x = "pr1002"
x = "kroA100"
coord_geo = False
if coord_geo == True:
     crs_wgs = p.Proj(init='epsg:4326')
     crs_bng = p.Proj(init = 'epsg:27700')
    
     tsp_database[x][0],tsp_database[x][1]  = p.transform(crs_wgs, crs_bng, tsp_database[x][1], tsp_database[x][0])
# for x in tsp_database:
print("Problem : " + x)
#    print(tsp_database[x])
X_coord = np.array(tsp_database[x][0])
Y_coord = np.array(tsp_database[x][1])
X_Y = np.array(list(zip(X_coord,Y_coord))).reshape(len(X_coord),2)
plt.plot()
plt.title('Cities in ' + x)
plt.scatter(X_coord, Y_coord)
plt.show()
# Out:
# Problem : kroA100

# %% [markdown]
# lt.plot()<br>
# lt.title('Cities in ' + x)<br>
# lt.scatter(X_coord, Y_coord)<br>
# lt.show()

# %%
from numpy import inf

X_Y[X_Y == inf] = 0

# %%
def get_clustered_cities(num_clust, labels_array):
    return np.where(labels_array == num_clust)

# %%
def plot_sys2_cities(sys2_cities):
    for k in K:
        plt.scatter(sys2_cities[k][:,0], sys2_cities[k][:,1])
        plt.show()

# %%
MAC_ising = True
n_problems = 8
#cluster_size_min = floor(n_problems*0.7)
cluster_size_min = 3
#cluster_size_max = floor(1.5*n_problems)
cluster_size_max = 12
print("The minimum size of clusters: ", cluster_size_min)
print("The maximum size of clusters: ", cluster_size_max)
n_clusters = []
n_clusters.append(ceil(len(X_coord)/n_problems))
while n_clusters[-1] > n_problems:
    n_clusters.append(ceil(n_clusters[-1]/n_problems))
n_hierarchies = len(n_clusters)
print(n_clusters)
# Out:
# The minimum size of clusters:  3
# The maximum size of clusters:  12
# [13, 2]

# %%
import time   
from k_means_constrained import KMeansConstrained

X_Y=[X_Y]
KM_labels = []

Constrained_KMeans = False

if Constrained_KMeans:
    for i in range(n_hierarchies):
        #print(i, n_clusters[i])
        tic = time.perf_counter()
        KMC = KMeansConstrained(
            n_clusters = n_clusters[i],
            size_min = cluster_size_min,
            size_max = cluster_size_max,
            random_state = 0)
        y_KMC = KMC.fit_predict(X_Y[i])
        centers = KMC.cluster_centers_
        toc = time.perf_counter()
        print(f"time = {toc-tic:0.4f} seconds")
        plt.scatter(X_Y[i][:,0], X_Y[i][:,1], c=y_KMC, s=n_clusters[i], cmap='viridis')
        KM_labels.append(y_KMC)
        X_Y.append(centers)
        plt.scatter(centers[:,0], centers[:,1], c='black', s=200, alpha=0.5)
        plt.rcParams.update({'font.size':15})
        plt.show()
else :
    for i in range(n_hierarchies):
        tic = time.perf_counter()
        kmeanModel = KMeans(n_clusters[i], init='k-means++').fit(X_Y[i])
        toc = time.perf_counter()
        print(f"time = {toc-tic:0.4f} seconds")
        kmeanModel.fit(X_Y[i])
        y_kmeans = kmeanModel.predict(X_Y[i])
        plt.scatter(X_Y[i][:,0], X_Y[i][:,1], c=y_kmeans, s=50, cmap='viridis')
        centers = kmeanModel.cluster_centers_
        #print(kmeanModel.cluster_centers_)
        #print(kmeanModel.labels_)
        KM_labels.append(kmeanModel.labels_)
        X_Y.append(centers)
        plt.scatter(centers[:,0], centers[:,1], c='black', s=200, alpha=0.5)
        plt.rcParams.update({'font.size':15})
        plt.show()

    for i in range(len(X_Y)):
        print(i)
        print(X_Y[i].shape)
"""
for i in range(len(X_Y)):
    print(i)
    print(X_Y[i].shape)
"""
# Out:
# time = 0.0294 seconds
# /home/dynamo/a/yoo241/miniconda3/envs/ising/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/dynamo/a/yoo241/miniconda3/envs/ising/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# time = 0.0068 seconds
# /home/dynamo/a/yoo241/miniconda3/envs/ising/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/dynamo/a/yoo241/miniconda3/envs/ising/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 0
# (99, 2)
# 1
# (13, 2)
# 2
# (2, 2)
# '\nfor i in range(len(X_Y)):\n    print(i)\n    print(X_Y[i].shape)\n'

# %%
## sys2_cities has [hierarchies where the sub-cluster belongs, Center X/Y coordinates of the sub-cluster, Cities X/Y coordinates in the sub-cluster]
## sys2_centers has [hierarchies where the sub-cluster belongs, Center X/Y coordinates of the sub-cluster]
## sys2_clusters has [hierarchies where the sub-cluster belongs, Cities X/Y coordinates in the sub-cluster]
sys2_centers = []
sys2_clusters = []

H = range(0,n_hierarchies)
for h in H:
    K = range(0,n_clusters[h])
    sys2_centers.append([])
    sys2_clusters.append([])
    colors = mpl.cm.tab20(range(20))
    for k in K:
        sys2_centers[h].append(X_Y[h+1][k])
        sys2_clusters[h].append(X_Y[h][get_clustered_cities(k, KM_labels[h])])
    largest_cluster_size = n_problems
    smallest_cluster_size = n_problems
    for k in K:
        if len(sys2_clusters[h][k]) > largest_cluster_size:
            largest_cluster_size = len(sys2_clusters[h][k])
        if len(sys2_clusters[h][k]) < smallest_cluster_size:
            smallest_cluster_size = len(sys2_clusters[h][k])
        if (len(sys2_clusters[h][k]) == 1):
            print("dirty cluster")
    print("The largest & smallest cluster size in Hierarchy ",h+1, ": ", largest_cluster_size, " & ", smallest_cluster_size)
## Add the topmost cluster
sys2_centers.append([])
sys2_clusters.append([])
sys2_centers[-1].append([0, 0])
sys2_clusters[-1].append(X_Y[-1])
# Out:
# The largest & smallest cluster size in Hierarchy  1 :  14  &  4
# The largest & smallest cluster size in Hierarchy  2 :  8  &  6

# %%
def Fix_first_last_cities(sys2_centers, sys2_clusters, sol_route, Lowest_Hier):
    ## Find a pair of the closest cities that are in different clusters which will be sequentially visited.
    ## After finding, place each city in the pair in the end of the preceding cluster and the start of the following cluster.
    ## To avoid the city in the following cluster to be selected once again for the next search, the next search starts from Index 1.
    ## Refer to Page 25
    tree = cKDTree(sys2_centers)
    clust_id_list = []
    total_traveling_distance = 0
    
    for k in range(len(sol_route)-1):
        ## Finding a pair of cities from distinct sub-clusters having the shortest distance betweeen sub-clusters.
        #print("k+1: ", k+1, " sol_route: ", sol_route[k+1])
        clust_idx_curr = tree.query(sol_route[k])[1]
        clust_idx_next = tree.query(sol_route[k+1])[1]
        if k ==0:
            clust_id_list.append(clust_idx_curr)
        clust_id_list.append(clust_idx_next)
        
        curr_clust = sys2_clusters[clust_idx_curr]
        next_clust = sys2_clusters[clust_idx_next]
        tree_clust = cKDTree(next_clust)
        if k ==0:
            search_init = 0
        else:
            search_init = 1
        sht_dist = inf
        for inc in range(search_init, len(curr_clust)):
            val_sd, idx_sd = tree_clust.query(curr_clust[inc])
            if val_sd < sht_dist:
                sht_dist = val_sd
                sht_idx_curr = inc
                sht_idx_next = idx_sd
                
        ## Fix the first and the last cities according to the information found above.
        curr_clust[[-1, sht_idx_curr]] = curr_clust[[sht_idx_curr,-1]]
        sys2_clusters[clust_idx_curr] = curr_clust
        next_clust[[0, sht_idx_next]] = next_clust[[sht_idx_next,0]]
        sys2_clusters[clust_idx_next] = next_clust
        if Lowest_Hier:
            total_traveling_distance += sht_dist
            #print("Inter-cluster distance (clusters ", k, "-", k+1, "): ", sht_dist, " total distance: ", total_traveling_distance)
            
    return sys2_clusters, clust_id_list, total_traveling_distance

# %%
def skip_ising(Lowest_Hier, total_traveling_distance, sol_route, route_btw_clusters, timet, nMAC_array, nRandFlip_array, curr_clust_size, infile, outfile):
    print("Ising skipped!!")
    timet[-1].append(0)
    nMAC_array[-1].append(0)
    nRandFlip_array[-1].append(0)
    DIST = 0
    with open(infile,"r") as inF:
        lines = inF.readlines()
        outF = open(outfile,"w")
        #outF.write(str(curr_clust_size))
        #outF.write("\n")
        
        for i in range(1, curr_clust_size+1):
            line = lines[i]
            outF.write(line)
                        
            curr = line.strip().split()
            for j in range(len(curr)):
                curr[j] = float(curr[j])
            sol_route.append(curr)
            
            if Lowest_Hier:
                if (i == 0) or (i == curr_clust_size-1):
                    route_btw_clusters.append(curr)
        #if Lowest_Hier:
        for i in range(1, curr_clust_size):
            X1 = float(lines[i].strip().split()[0])
            Y1 = float(lines[i].strip().split()[1])
            X2 = float(lines[i+1].strip().split()[0])
            Y2 = float(lines[i+1].strip().split()[1])
            DIST += sqrt((X1-X2)**2+(Y1-Y2)**2)
        outF.write("\n")
        outF.write("dist ")
        outF.write(str(DIST))
        outF.write("\n")
        outF.write("n_MAC 0")
        outF.write("\n")
        outF.write("n_RandFlip 0")
        outF.write("\n")
        
        outF.close()
        inF.close()

        if Lowest_Hier:
            total_traveling_distance += DIST
    
    return total_traveling_distance, sol_route, route_btw_clusters, timet, nMAC_array, nRandFlip_array

# %%
def gen_sys2_sol(MAC_ising, benchmark, sys2_centers, sys2_clusters, SchPar):
    MAC_ising = False
    if MAC_ising:
        cpp_cmd = "./ising_mac"
    else :
        cpp_cmd = "./ising_RNG"
    os.system("rm -rf sys2clusters_" + str(benchmark))
    SYS2_CENTERS = sys2_centers
    SYS2_CLUSTERS = sys2_clusters
    
    timet =[]
    nMAC_array =[]
    nRandFlip_array = []
    sys2_labels = []
    colors = mpl.cm.tab20(range(20))
    
    for h in range(0, n_hierarchies+1):
        print("Execute Ising Solver for Hierarchy ", n_hierarchies-h)
        sys2_centers = SYS2_CENTERS[n_hierarchies-h]
        sys2_clusters = SYS2_CLUSTERS[n_hierarchies-h]

        if h != 0:
            sys2_clusters, clust_id_list, total_traveling_distance = Fix_first_last_cities(sys2_centers, sys2_clusters, sol_route, h == n_hierarchies)
        else:
            clust_id_list = range(0, len(sys2_centers))
            
        sol_route = []
        route_btw_clusters = []
        timet.append([])
        nMAC_array.append([])
        nRandFlip_array.append([])
        #kth = 0
        sys2_labels.append([])
        #for k in range(0, len(sys2_centers)):
        #for k in clust_id_list:
        for k in range(len(clust_id_list)):
            curr_center = sys2_centers[clust_id_list[k]]
            curr_clust = sys2_clusters[clust_id_list[k]]
            curr_clust_size = len(curr_clust)
            for l in range(curr_clust_size):
                sys2_labels[h].append(colors[k%20])
            curr_clust_file = [curr_clust_size]
            curr_clust_file.append(curr_clust)
            os.system("mkdir -p sys2clusters_" + str(benchmark))
            curr_filename = str(benchmark) + "_h" + str(n_hierarchies-h)  + "_c" + str(k) +".in"
            curr_logfile = str(benchmark) + "_h" + str(n_hierarchies-h)   + "_c" + str(k) +".out"
            inF = open("sys2clusters_" + str(benchmark) + "/" + curr_filename,"w")
            inF.write(str(curr_clust_size))
            inF.write("\n")
            for i in curr_clust:
                inF.write(str(i[0]) + " " + str(i[1]))
                inF.write("\n")
            inF.close()
            
            for i in range(0,1):
                if h == 0:
                    if curr_clust_size == 2:
                        total_traveling_distance, sol_route, route_btw_clusters, timet, nMAC_array, nRandFlip_array = skip_ising(h == n_hierarchies, 0, sol_route, route_btw_clusters, timet, nMAC_array, nRandFlip_array, curr_clust_size, "sys2clusters_" + str(benchmark) + "/" + curr_filename, "sys2clusters_" + str(benchmark) + "/" + curr_logfile)
                        break                        
                else:
                    if k == 0 or k == len(clust_id_list)-1:
                        if curr_clust_size < 3:
                            total_traveling_distance, sol_route, route_btw_clusters, timet, nMAC_array, nRandFlip_array = skip_ising(h == n_hierarchies, total_traveling_distance, sol_route, route_btw_clusters, timet, nMAC_array, nRandFlip_array, curr_clust_size, "sys2clusters_" + str(benchmark) + "/" + curr_filename, "sys2clusters_" + str(benchmark) + "/" + curr_logfile)
                            break
                    else:
                        if curr_clust_size < 4:
                            total_traveling_distance, sol_route, route_btw_clusters, timet, nMAC_array, nRandFlip_array = skip_ising(h == n_hierarchies, total_traveling_distance, sol_route, route_btw_clusters, timet, nMAC_array, nRandFlip_array, curr_clust_size, "sys2clusters_" + str(benchmark) + "/" + curr_filename, "sys2clusters_" + str(benchmark) + "/" + curr_logfile)
                            break
                tic = time.perf_counter()
                ### when h>0, Problem_size to optimize = N-1 when k is 0 or -1, otherwise N-2
                if h == 0 :
                        os.system(cpp_cmd+" k0" + " sys2clusters_" + str(benchmark) + "/" + curr_filename + " >> " + "sys2clusters_" + str(benchmark) + "/" + curr_logfile)
                elif k == len(clust_id_list)-1:
                    os.system(cpp_cmd+" k-1" + " sys2clusters_" + str(benchmark) + "/" + curr_filename + " >> " + "sys2clusters_" + str(benchmark) + "/" + curr_logfile)
                else :
                    os.system(cpp_cmd+" k" + str(k+1) + " sys2clusters_" + str(benchmark) + "/" + curr_filename + " >> " + "sys2clusters_" + str(benchmark) + "/" + curr_logfile)
                toc = time.perf_counter()
                timet[-1].append(toc-tic)
                
                dist_array =[]
                with open("sys2clusters_" + str(benchmark) + "/" + curr_logfile,"r") as outFile:
                    lines = outFile.readlines()
                    for i in range(0,len(lines)):
                        line = lines[i]
                        if "dist" in line:
                            dist_array.append(line.strip().split()[1])
                            continue
                        if "n_MAC" in line:
                            nMAC_array[-1].append(int(line.strip().split()[1]))
                            continue
                        if "n_RandFlip" in line:
                            nRandFlip_array[-1].append(int(line.strip().split()[1]))
                            continue
                    dist = min(dist_array)
                    ####################################
                    ####################################
                    if h == n_hierarchies:
                        total_traveling_distance += float(dist)
                        print("hierarchy: ", h, " cluster: ", k, " distance to the next cluster: ", float(dist), " total distance: ", total_traveling_distance)
                    ####################################
                    ####################################
                    for i in range(0, curr_clust_size):
                        line = lines[i]
                        """
                        if "seq_clust" in line:
                            continue
                        if "dist" in line:
                            continue
                        if "size():" in line:
                            continue
                        if "final" in line:
                            continue
                        if "remapped" in line:
                            continue
                        """
                        curr = line.strip().split()
                        for j in range(len(curr)):
                            curr[j] = float(curr[j])
                        sol_route.append(curr)
                    
                        if h == n_hierarchies:
                            if (i == 0) or (i == curr_clust_size-1):
                                route_btw_clusters.append(curr)
                    
                    outFile.close()
                print("done with cluster" + str(k))
        print(f"Ising Max time = {max(timet[-1]):0.4f} seconds", " / ", str(min(timet[-1])))
    
    print("total_traveling_distance: ", total_traveling_distance)
    return sol_route, route_btw_clusters, sys2_labels, total_traveling_distance

# %%
print(n_clusters)
#sol_route, route_btw_clusters, sys2_labels = gen_sys2_sol(MAC_ising, x, sys2_centers, sys2_clusters)
init_Irands = [50]
init_cools = [0.001]
Factors = [0.9]
Thresholds = [0]
Patiences = [10000]
#cools = [0.01, 0.005, 0.002, 0.001]
#Factors = [0.8, 0.9, 0.95, 0.99, 0.995, 0.999]
#Thresholds = [1e6, 1e3, 0, -1e3, -1e6]
#Patiences = [5, 10, 20, 50]
ttds = []

for Irand in init_Irands:
    for cool in init_cools:
        for Factor in Factors:
            for Threshold in Thresholds:
                for Patience in Patiences:
                    scheduler_params = [Irand, cool, Factor, Threshold, Patience]
                    sol_route, route_btw_clusters, sys2_labels, ttd = gen_sys2_sol(MAC_ising, x, sys2_centers, sys2_clusters, scheduler_params)
                    ttds.append(ttd)
i = 0
for Irand in init_Irands:
    for cool in init_cools:
        for Factor in Factors:
            for Threshold in Thresholds:
                for Patience in Patiences:
                    print("Irand: ", Irand, "Cool: ", cool, "Factor: ", Factor, " Threshold: ", Threshold, " Patience: ", Patience, " ttd: ", ttds[i])
                    i += 1
# Out:
# [13, 2]
# Execute Ising Solver for Hierarchy  2
# Ising skipped!!
# Ising Max time = 0.0000 seconds  /  0
# Execute Ising Solver for Hierarchy  1
# done with cluster0
# done with cluster1
# Ising Max time = 0.1327 seconds  /  0.06946039712056518
# Execute Ising Solver for Hierarchy  0
# hierarchy:  2  cluster:  0  distance to the next cluster:  1794.25  total distance:  5558.448478694157
# done with cluster0
# hierarchy:  2  cluster:  1  distance to the next cluster:  2380.29  total distance:  7938.738478694157
# done with cluster1
# hierarchy:  2  cluster:  2  distance to the next cluster:  1440.18  total distance:  9378.918478694157
# done with cluster2
# hierarchy:  2  cluster:  3  distance to the next cluster:  1575.06  total distance:  10953.978478694156
# done with cluster3
# hierarchy:  2  cluster:  4  distance to the next cluster:  983.978  total distance:  11937.956478694156
# done with cluster4
# hierarchy:  2  cluster:  5  distance to the next cluster:  1475.47  total distance:  13413.426478694155
# done with cluster5
# hierarchy:  2  cluster:  6  distance to the next cluster:  950.696  total distance:  14364.122478694155
# done with cluster6
# hierarchy:  2  cluster:  7  distance to the next cluster:  659.253  total distance:  15023.375478694155
# done with cluster7
# hierarchy:  2  cluster:  8  distance to the next cluster:  3252.94  total distance:  18276.315478694156
# done with cluster8
# hierarchy:  2  cluster:  9  distance to the next cluster:  1521.94  total distance:  19798.255478694155
# done with cluster9
# hierarchy:  2  cluster:  10  distance to the next cluster:  1183.43  total distance:  20981.685478694155
# done with cluster10
# hierarchy:  2  cluster:  11  distance to the next cluster:  655.969  total distance:  21637.654478694156
# done with cluster11
# hierarchy:  2  cluster:  12  distance to the next cluster:  2232.64  total distance:  23870.294478694155
# done with cluster12
# Ising Max time = 1.1259 seconds  /  0.007498040096834302
# total_traveling_distance:  23870.294478694155
# Irand:  50 Cool:  0.001 Factor:  0.9  Threshold:  0  Patience:  10000  ttd:  23870.294478694155

# %%
route = np.array(route_btw_clusters)
sol_route = np.array(sol_route)
for n in range(int(len(route_btw_clusters)/2)-1):
    plt.plot(route[2*n+1:2*(n+1)+1,0], route[2*n+1:2*(n+1)+1,1], '-')
plt.scatter(sol_route[:,0], sol_route[:,1], c=sys2_labels[n_hierarchies][:], s=20)
plt.show()

# %%
from math import sin, cos, sqrt, atan2, radians
def compute_geo(p1,p2):
    R = 6373.0
    
    lat1 = radians(float(p1[0]))
    lon1 = radians(float(p1[1]))
    lat2 = radians(float(p2[0]))
    lon2 = radians(float(p2[1]))
    
    dlon = lon2 - lon1
    dlat = lat2 -lat1

    a = sin(dlat/2)**2 + cos(lat1)*cos(lat2)*sin(dlon/2)**2
    c = 2*atan2(sqrt(a),sqrt(1-a))
    dist = R*c
    return dist

# %%
coord_geo == False
if coord_geo == True:
#     test = np.load("sys2clusters_" + str(x) + "/sol_table.npy", allow_pickle=True)
    for i in range(len(test)):
        print(i)
        for j in range(len(test[i])):
            geo_dist = 0
            li = test[i][j][1]
            for idx,elem in enumerate(li):
                thiscity = elem
                nextcity = li[(idx+1)%len(li)]
                geo_dist += compute_geo(thiscity, nextcity)
            test[i][j][2] = geo_dist 
            print(geo_dist)
        np.save("sys2clusters_" + str(x) + "/sol_table" ,test)

# %% [markdown]
# mport pdb; pdb.set_trace()

# %%
## Sangmin edited

print(X_coord.shape)
print(Y_coord.shape)
print(x)
with open("tsp" + x + "_pyconcorde.txt", "w") as f:
    solver = TSPSolver.from_data(X_coord, Y_coord, norm="EUC_2D")  
    solution = solver.solve()
    f.write( str(" ") + str('output') + str(" ") )
    f.write( str("solution found? ") + str(solution.found_tour) + str(" ") )
    f.write( str("Optimal value? ") + str(solution.optimal_value) + str(" ") )
    f.write( str(" ").join( str(node_idx+1) for node_idx in solution.tour) )
    f.write( str(" ") + str(solution.tour[0]+1) + str(" ") )
# Out:
# (99,)
# (99,)
# kroA100
# Problem Name: bf688eee3a60481f84c1a0a5a5f27a46
# Problem Type: TSP
# Number of Nodes: 99
# Rounded Euclidean Norm (CC_EUCLIDEAN)
# CCtsp_solve_dat ...
# Finding a good tour for compression ...
# linkern ...
# Starting Cycle: 23799
#    0 Steps   Best: 21292   0.00 seconds
#    3 Steps   Best: 21278   0.00 seconds
#   49 Total Steps.
# Best cycle length: 21278
# Lin-Kernighan Running Time: 0.03
# LK Initial Run: 21278.0
# LK Run 0: 21278.0
# LK Run from best tour: 21278.0
# Time to find compression tour: 0.06 (seconds)
# Set initial upperbound to 21278 (from tour)
# Fractional Matching: 21236.0
# Initial Running Time: 0.00 (seconds)
# Basis Running Time: 0.00 (seconds)
# Total fractional matching time: 0.00 (seconds)
# Total Time for first_lp: 0.00 (seconds)
# Setting upperbound to the initial bound: 21278.00
# Loading lp...done in 0.00 seconds
# LP has:  99 rows  120 columns  240 nonzeros
# Dual opt returned after 0.00 seconds
# Initial LP value: 21236.000000
# Setting tolerances: next cuts 0.4200 next round 0.0420
# CCtsp_init_edgegenerator (50)
#  2793 edges
# LP has:  99 rows  120 columns  240 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  99 rows  120 columns  240 nonzeros
# Found  0 connect cuts in 0.00 seconds
# Found  0 segment cuts in 0.00 seconds
# Found  2 Fast Blossoms in 0.00 seconds
#   Add  2 cuts (Total 1), LP: 21278.000000 (0.00 seconds)
# Integral Solution of Value 21278.00
# CCtsp_generate_edges (20297)
# Time for Add edges optimize: 0.00 seconds (0.00 total in 1 calls)
# Time for Add edges optimize: 0.00 seconds (0.00 total in 2 calls)
# CCtsp_generate_edges (20297)
# Time for Add edges optimize: 0.00 seconds (0.00 total in 3 calls)
# CCtsp_generate_edges (20297)
# Time for Add edges optimize: 0.00 seconds (0.00 total in 4 calls)
# CCtsp_generate_edges (20297)
# Time for Add edges: 0.00 seconds (0.00 total in 1 calls)
# (SPARSE) 165 edges added, penalty 0.000000, val 19431.000000
# Time for Sparse edge check: 0.00 seconds (0.00 total in 1 calls)
# Write Pool: 1 cuts
# Time for Cutting inside loop: 0.00 seconds (0.00 total in 1 calls)
# LP has:  100 rows  285 columns  587 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  100 rows  285 columns  579 nonzeros
# Found 12 connect cuts in 0.00 seconds
#   Add 12 cuts (Total 11), LP: 20690.000000 (0.00 seconds)
# Found  7 segment cuts in 0.00 seconds
#   Add  7 cuts (Total 15), LP: 20782.000000 (0.00 seconds)
# Found  6 Fast Blossoms in 0.00 seconds
#   Add  6 cuts (Total 20), LP: 20859.000000 (0.00 seconds)
# Found  4 Groetschel-Holland Blossoms in 0.00 seconds
#   Add  4 cuts (Total 23), LP: 20948.500000 (0.00 seconds)
# Block Combs
#   Type 0: 2 cuts  2.0000 max violation  0.00 seconds
#   Type 1: 2 cuts  2.0000 max violation  0.00 seconds
#   Type 2: 0 cuts  0.0000 max violation  0.00 seconds
#   Type 3: 0 cuts  0.0000 max violation  0.00 seconds
#   Type 4: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 1: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 2: 2 cuts  1.0000 max violation  0.00 seconds
#   Olaf 3: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 4: 0 cuts  0.0000 max violation  0.00 seconds
#   Total Time in block_combs: 0.00
# Found  6 block_combs in 0.00 seconds
#   Add  6 cuts (Total 25), LP: 20950.000000 (0.00 seconds)
# integral solution not connected
# Found  4 exact subtours in 0.00 seconds
#   Add  4 cuts (Total 28), LP: 21054.000000 (0.00 seconds)
# integral solution not connected
# Found  7 tighten_lp cuts (viol 1.0000) in 0.00 seconds
#   Add  7 cuts (Total 30), LP: 21074.500000 (0.00 seconds)
# Found  4 CLOSE tighten_lp cuts (viol 0.5000) in 0.00 seconds
#   Add  4 cuts (Total 32), LP: 21101.000000 (0.00 seconds)
# Found  5 double deckers (viol 4.0000) in 0.00 seconds
#   Add  5 cuts (Total 33), LP: 21111.000000 (0.00 seconds)
# Found  4 CLOSE double deckers (viol 1.0000) in 0.00 seconds
#   Add  4 cuts (Total 35), LP: 21140.600000 (0.00 seconds)
# Found  5 Handling Inequalities (viol 3.2000) in 0.00 seconds
#   Add  5 cuts (Total 36), LP: 21199.000000 (0.00 seconds)
# Found  0 teethed combs (viol -0.0000) in 0.00 seconds
# CCtsp_generate_edges (20297)
# Time for Add edges optimize: 0.00 seconds (0.00 total in 5 calls)
# CCtsp_generate_edges (20297)
# Time for Add edges: 0.00 seconds (0.00 total in 2 calls)
# (SPARSE) 23 edges added, penalty 0.000000, val 21029.500000
# Time for Sparse edge check: 0.00 seconds (0.00 total in 2 calls)
# Write Pool: 19 cuts
# Time for Cutting inside loop: 0.01 seconds (0.01 total in 2 calls)
# LP has:  135 rows  308 columns  2048 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  135 rows  308 columns  1194 nonzeros
# Found  2 connect cuts in 0.00 seconds
#   Add  2 cuts (Total 37), LP: 21035.500000 (0.00 seconds)
# Found  1 segment cuts in 0.00 seconds
#   Add  1 cuts (Total 37), LP: 21042.000000 (0.00 seconds)
# Found  4 Fast Blossoms in 0.00 seconds
#   Add  4 cuts (Total 40), LP: 21077.216667 (0.00 seconds)
# Found  4 Groetschel-Holland Blossoms in 0.00 seconds
#   Add  3 cuts (Total 40), LP: 21081.550000 (0.00 seconds)
# Block Combs
#   Type 0: 11 cuts  1.3333 max violation  0.00 seconds
#   Type 1: 6 cuts  1.3333 max violation  0.00 seconds
#   Type 2: 2 cuts  0.6667 max violation  0.00 seconds
#   Type 5: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 1: 6 cuts  1.3333 max violation  0.00 seconds
#   Olaf 2: 6 cuts  1.3333 max violation  0.00 seconds
#   Olaf 3: 7 cuts  0.7667 max violation  0.00 seconds
#   Olaf 4: 7 cuts  0.7667 max violation  0.00 seconds
#   Total Time in block_combs: 0.00
# Found 45 block_combs in 0.00 seconds
#   Add 45 cuts (Total 46), LP: 21112.766667 (0.00 seconds)
# Found  5 exact subtours in 0.00 seconds
#   Add  5 cuts (Total 48), LP: 21159.000000 (0.00 seconds)
# Found 13 tighten_lp cuts (viol 1.3333) in 0.00 seconds
#   Add 13 cuts (Total 52), LP: 21182.500000 (0.00 seconds)
# Found  4 CLOSE tighten_lp cuts (viol 0.2500) in 0.00 seconds
#   Add  4 cuts (Total 52), LP: 21186.333333 (0.00 seconds)
# Found 14 double deckers (viol 1.3333) in 0.00 seconds
#   Add 14 cuts (Total 54), LP: 21196.250000 (0.00 seconds)
# Found  9 CLOSE double deckers (viol 1.0000) in 0.00 seconds
#   Add  9 cuts (Total 55), LP: 21213.000000 (0.00 seconds)
# integral solution not connected
# Found  0 Handling Inequalities (viol -0.0000) in 0.00 seconds
# Found  3 teethed combs (viol 2.0000) in 0.00 seconds
#   Add  3 cuts (Total 56), LP: 21215.369436 (0.00 seconds)
# CCtsp_generate_edges (20297)
# Time for Add edges optimize: 0.00 seconds (0.00 total in 6 calls)
# CCtsp_generate_edges (20297)
# Time for Add edges: 0.00 seconds (0.00 total in 3 calls)
# (SPARSE) 11 edges added, penalty 0.000000, val 21194.750000
# Time for Sparse edge check: 0.00 seconds (0.00 total in 3 calls)
# Write Pool: 47 cuts
# Time for Cutting inside loop: 0.02 seconds (0.03 total in 3 calls)
# LP has:  155 rows  319 columns  3971 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  155 rows  319 columns  1821 nonzeros
# Found  1 pool cuts (viol 1.0000) in 0.00 seconds
#   Add  1 cuts (Total 57), LP: 21194.750000 (0.00 seconds)
# Found  0 connect cuts in 0.00 seconds
# Found  6 segment cuts in 0.00 seconds
#   Add  6 cuts (Total 59), LP: 21202.166667 (0.00 seconds)
# Found  2 Fast Blossoms in 0.00 seconds
#   Add  2 cuts (Total 60), LP: 21208.333333 (0.00 seconds)
# Found  0 Groetschel-Holland Blossoms in 0.00 seconds
# Block Combs
#   Type 0: 12 cuts  1.3333 max violation  0.00 seconds
#   Type 1: 6 cuts  1.3333 max violation  0.00 seconds
#   Type 2: 4 cuts  0.6667 max violation  0.00 seconds
#   Type 5: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 1: 4 cuts  1.3333 max violation  0.00 seconds
#   Olaf 2: 3 cuts  1.3333 max violation  0.00 seconds
#   Olaf 3: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 4: 0 cuts  0.0000 max violation  0.00 seconds
#   Total Time in block_combs: 0.00
# Found 29 block_combs in 0.00 seconds
#   Add 29 cuts (Total 62), LP: 21220.787879 (0.00 seconds)
# Found  6 exact subtours in 0.00 seconds
#   Add  6 cuts (Total 64), LP: 21229.187500 (0.00 seconds)
# Found 21 tighten_lp cuts (viol 0.5000) in 0.00 seconds
#   Add 21 cuts (Total 68), LP: 21235.000000 (0.00 seconds)
# Found  4 CLOSE tighten_lp cuts (viol 0.5000) in 0.00 seconds
#   Add  4 cuts (Total 70), LP: 21252.888889 (0.00 seconds)
# Found  6 double deckers (viol 0.8889) in 0.00 seconds
#   Add  6 cuts (Total 69), LP: 21257.310345 (0.00 seconds)
# Found  9 CLOSE double deckers (viol 0.2414) in 0.00 seconds
#   Add  9 cuts (Total 66), LP: 21261.500000 (0.00 seconds)
# Found  1 Handling Inequalities (viol 0.2500) in 0.00 seconds
#   Add  1 cuts (Total 66), LP: 21261.687500 (0.00 seconds)
# Found  3 teethed combs (viol 0.2500) in 0.00 seconds
#   Add  3 cuts (Total 66), LP: 21263.721951 (0.00 seconds)
# CCtsp_generate_edges (20297)
# Time for Add edges optimize: 0.00 seconds (0.00 total in 7 calls)
# CCtsp_generate_edges (20297)
# Time for Add edges optimize: 0.00 seconds (0.00 total in 8 calls)
# CCtsp_generate_edges (20297)
# Time for Add edges: 0.00 seconds (0.00 total in 4 calls)
# (SPARSE) 4 edges added, penalty 0.000000, val 21263.509259
# Time for Sparse edge check: 0.00 seconds (0.01 total in 4 calls)
# Write Pool: 63 cuts
# Time for Cutting inside loop: 0.02 seconds (0.05 total in 4 calls)
# LP has:  165 rows  323 columns  4424 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  165 rows  323 columns  2020 nonzeros
# Found  4 pool cuts (viol 0.0741) in 0.00 seconds
#   Add  4 cuts (Total 68), LP: 21263.721951 (0.00 seconds)
# Found  0 connect cuts in 0.00 seconds
# Found  4 segment cuts in 0.00 seconds
#   Add  4 cuts (Total 68), LP: 21274.666667 (0.00 seconds)
# Found  0 Fast Blossoms in 0.00 seconds
# Found  0 Groetschel-Holland Blossoms in 0.00 seconds
# Block Combs
#   Type 0: 3 cuts  0.6667 max violation  0.00 seconds
#   Type 1: 0 cuts  0.0000 max violation  0.00 seconds
#   Type 2: 0 cuts  0.0000 max violation  0.00 seconds
#   Type 5: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 1: 1 cuts  0.6667 max violation  0.00 seconds
#   Olaf 2: 1 cuts  0.6667 max violation  0.00 seconds
#   Olaf 3: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 4: 0 cuts  0.0000 max violation  0.00 seconds
#   Total Time in block_combs: 0.00
# Found  5 block_combs in 0.00 seconds
#   Add  5 cuts (Total 69), LP: 21278.000000 (0.00 seconds)
# Integral Solution of Value 21278.00
# CCtsp_generate_edges (20297)
# Time for Add edges: 0.00 seconds (0.00 total in 5 calls)
# (SPARSE) 0 edges added, penalty 0.000000, val 21278.000000
# Time for Sparse edge check: 0.00 seconds (0.01 total in 5 calls)
# Write Pool: 65 cuts
# Time for Cutting inside loop: 0.01 seconds (0.05 total in 5 calls)
# LP has:  168 rows  323 columns  2262 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  168 rows  323 columns  2065 nonzeros
# Integral Solution of Value 21278.00
# CCtsp_generate_edges (20297)
# Time for Add edges: 0.00 seconds (0.01 total in 6 calls)
# (SPARSE) 0 edges added, penalty 0.000000, val 21278.000000
# Time for Sparse edge check: 0.00 seconds (0.01 total in 6 calls)
# recomputing rownorms ...
# Write Pool: 65 cuts
# Time for Cutting inside loop: 0.00 seconds (0.05 total in 6 calls)
# CCtsp_init_edgegenerator (-1)
# xprice_build
# xprice_reset (0)
# CCtsp_generate_edges (20297)
# Time for Add edges: 0.00 seconds (0.01 total in 7 calls)
# 0 edges added, penalty 0.000000
# New lower bound: 21278.000000
# Time for Full edge check: 0.00 seconds (0.00 total in 1 calls)
# Time for Cutting Loop: 0.06 seconds (0.06 total in 1 calls)
# Number of outside rounds: 1
# CCtsp_x_greedy_tour ...
# 98 edges in x-tour
# tour length: 21278.00 (0.00 seconds)
# Built CCkdtree: 0.00 (seconds)
#  481 edges
# Quad Nearest added 481 edges (0.00 seconds)
# Edgegen total edges: 481 (0.00 seconds)
# x-heuristic lk  gives: 21278.00
# Exact Price Time: 0.00 seconds
# Exact lower bound: 21278.000000
# DIFF: 0.000000
# Established Bound: 21278
# Optimal tour: 21278
# Total Time to solve TSP: 0.13

# %%
GO = False
if GO:
    num_samples = 10000
    set_nodes_coord = np.random.random([num_samples, n_clusters, 2])
    with open("tsp" + str(n_clusters) + "_pr1002.txt", "w") as f:
        solver = TSPSolver.from_data(centers[:,0], centers[:,1], norm="EUC_2D")  
        solution = solver.solve()
        f.write( " ".join( str(x)+str(" ")+str(y) for x,y in centers) )
        f.write( str(" ") + str('output') + str(" ") )
        f.write( str(" ").join( str(node_idx+1) for node_idx in solution.tour) )
        f.write( str(" ") + str(solution.tour[0]+1) + str(" ") )
