# %%
import os
import time
import sys
from sklearn.cluster import KMeans
from sklearn import metrics
from scipy.spatial.distance import cdist
from scipy.spatial import KDTree, cKDTree
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from concorde.tsp import TSPSolver
from math import sqrt, ceil, inf, floor

# %%
root_dir = os.getcwd()
tsp_dir = os.path.join(root_dir, "../tsplib")
concorde_dir = os.path.join(root_dir, "../pyconcorde/concorde")

# %%
sys.path.insert(0, root_dir)
sys.path.insert(0, tsp_dir)
#sys.path.insert(0, concorde_dir)

# %%
num_samples = 10000

# %%
def gen_tsp_data():
    ## Load a tsp library and Create a dictionary "tsp_database" of Name-X/Y coordinates.

    tsp_database = {}
    cities = os.listdir(tsp_dir)
    
    for city in cities:
        if city.endswith(".tsp"):
            with open(tsp_dir + '/' + city, 'r') as infile:
                lines = infile.readlines()
                for i in range(0, len(lines)):
                    line = lines[i]
                    if "DIMENSION" in line:
                        Dimension = line.strip().split(':')[1]
                        if not Dimension.isdigit():
                            continue
                    if "EDGE_WEIGHT_TYPE" in line:
                        EdgeWeightType = line.strip().split()[1]
                        if EdgeWeightType != "EUC_2D":
                            continue
                    if "NODE_COORD_SECTION" in line:
                        x_y = None
                        nodelist_x = []
                        nodelist_y = []
        
                        for j in range (1, int(Dimension)):
                            x_y = lines[i+1].strip().split()[1:]
    #                        print(x_y)
    #                        import pdb; pdb.set_trace()
                            x = x_y[0]
                            y = x_y[1]
                            nodelist_x.append(float(x))
                            nodelist_y.append(float(y))
                            i+=1
                        tsp_database.update({city[:-4]:[nodelist_x, nodelist_y]})
    return tsp_database

# %%
tsp_database = gen_tsp_data()
problem_list = tsp_database.keys()
problem_list
# Out:
# dict_keys(['pr107', 'pr152', 'pr226', 'pr1002', 'rat575', 'kroA100', 'eil101'])

# %%
import pyproj as p
#x = "kroA100"
#x = "rat575"
#x = "eil101"
#x = "pr107"
#x = "pr152"
x = "pr1002"
coord_geo = False
if coord_geo == True:
     crs_wgs = p.Proj(init='epsg:4326')
     crs_bng = p.Proj(init = 'epsg:27700')
    
     tsp_database[x][0],tsp_database[x][1]  = p.transform(crs_wgs, crs_bng, tsp_database[x][1], tsp_database[x][0])
# for x in tsp_database:
print("Problem : " + x)
#    print(tsp_database[x])
X_coord = np.array(tsp_database[x][0])
Y_coord = np.array(tsp_database[x][1])
X_Y = np.array(list(zip(X_coord,Y_coord))).reshape(len(X_coord),2)
plt.plot()
plt.title('Cities in ' + x)
plt.scatter(X_coord, Y_coord)
plt.show()
# Out:
# Problem : pr1002

# %% [markdown]
# lt.plot()<br>
# lt.title('Cities in ' + x)<br>
# lt.scatter(X_coord, Y_coord)<br>
# lt.show()

# %%
from numpy import inf

X_Y[X_Y == inf] = 0

# %%
def get_clustered_cities(num_clust, labels_array):
    return np.where(labels_array == num_clust)

# %%
def plot_sys2_cities(sys2_cities):
    for k in K:
        plt.scatter(sys2_cities[k][:,0], sys2_cities[k][:,1])
        plt.show()

# %%
MAC_ising = True
n_problems = 8
#cluster_size_min = floor(n_problems*0.7)
cluster_size_min = 4
print("The minimum size of clusters: ", cluster_size_min)
print("The maximum size of clusters: ", n_problems)
n_clusters = []
n_clusters.append(ceil(len(X_coord)/n_problems))
while n_clusters[-1] > n_problems:
    n_clusters.append(ceil(n_clusters[-1]/n_problems))
n_hierarchies = len(n_clusters)
print(n_clusters)
# Out:
# The minimum size of clusters:  4
# The maximum size of clusters:  8
# [126, 16, 2]

# %%
import time   
from k_means_constrained import KMeansConstrained

X_Y=[X_Y]
KM_labels = []

Constrained_KMeans = True

if Constrained_KMeans:
    for i in range(n_hierarchies):
        #print(i, n_clusters[i])
        tic = time.perf_counter()
        KMC = KMeansConstrained(
            n_clusters = n_clusters[i],
            size_min = cluster_size_min,
            size_max = n_problems,
            random_state = 0)
        y_KMC = KMC.fit_predict(X_Y[i])
        centers = KMC.cluster_centers_
        toc = time.perf_counter()
        print(f"time = {toc-tic:0.4f} seconds")
        plt.scatter(X_Y[i][:,0], X_Y[i][:,1], c=y_KMC, s=n_clusters[i], cmap='viridis')
        KM_labels.append(y_KMC)
        X_Y.append(centers)
        plt.scatter(centers[:,0], centers[:,1], c='black', s=200, alpha=0.5)
        plt.rcParams.update({'font.size':15})
        plt.show()
else :
    for i in range(n_hierarchies):
        tic = time.perf_counter()
        kmeanModel = KMeans(n_clusters[i], init='k-means++').fit(X_Y[i])
        toc = time.perf_counter()
        print(f"time = {toc-tic:0.4f} seconds")
        kmeanModel.fit(X_Y[i])
        y_kmeans = kmeanModel.predict(X_Y[i])
        plt.scatter(X_Y[i][:,0], X_Y[i][:,1], c=y_kmeans, s=50, cmap='viridis')
        centers = kmeanModel.cluster_centers_
        #print(kmeanModel.cluster_centers_)
        #print(kmeanModel.labels_)
        KM_labels.append(kmeanModel.labels_)
        X_Y.append(centers)
        plt.scatter(centers[:,0], centers[:,1], c='black', s=200, alpha=0.5)
        plt.rcParams.update({'font.size':15})
        plt.show()

    for i in range(len(X_Y)):
        print(i)
        print(X_Y[i].shape)
"""
for i in range(len(X_Y)):
    print(i)
    print(X_Y[i].shape)
"""
# Out:
# time = 11.8451 seconds
# time = 0.2272 seconds
# time = 0.0154 seconds
# '\nfor i in range(len(X_Y)):\n    print(i)\n    print(X_Y[i].shape)\n'

# %%
## sys2_cities has [hierarchies where the sub-cluster belongs, Center X/Y coordinates of the sub-cluster, Cities X/Y coordinates in the sub-cluster]
## sys2_centers has [hierarchies where the sub-cluster belongs, Center X/Y coordinates of the sub-cluster]
## sys2_clusters has [hierarchies where the sub-cluster belongs, Cities X/Y coordinates in the sub-cluster]
sys2_centers = []
sys2_clusters = []

H = range(0,n_hierarchies)
for h in H:
    K = range(0,n_clusters[h])
    sys2_centers.append([])
    sys2_clusters.append([])
    colors = mpl.cm.tab20(range(20))
    for k in K:
        sys2_centers[h].append(X_Y[h+1][k])
        sys2_clusters[h].append(X_Y[h][get_clustered_cities(k, KM_labels[h])])
    largest_cluster_size = n_problems
    smallest_cluster_size = n_problems
    for k in K:
        if len(sys2_clusters[h][k]) > largest_cluster_size:
            largest_cluster_size = len(sys2_clusters[h][k])
        if len(sys2_clusters[h][k]) < smallest_cluster_size:
            smallest_cluster_size = len(sys2_clusters[h][k])
        if (len(sys2_clusters[h][k]) == 1):
            print("dirty cluster")
    print("The largest & smallest cluster size in Hierarchy ",h+1, ": ", largest_cluster_size, " & ", smallest_cluster_size)
## Add the topmost cluster
sys2_centers.append([])
sys2_clusters.append([])
sys2_centers[-1].append([0, 0])
sys2_clusters[-1].append(X_Y[-1])
# Out:
# The largest & smallest cluster size in Hierarchy  1 :  8  &  6
# The largest & smallest cluster size in Hierarchy  2 :  8  &  7
# The largest & smallest cluster size in Hierarchy  3 :  8  &  8

# %%
def Fix_first_last_cities(sys2_centers, sys2_clusters, sol_route, Lowest_Hier):
    tree = cKDTree(sys2_centers)
    clust_id_list = []
    total_traveling_distance = 0
    
    for k in range(len(sol_route)-1):
        clust_idx_curr = tree.query(sol_route[k])[1]
        clust_idx_next = tree.query(sol_route[k+1])[1]
        if k ==0:
            clust_id_list.append(clust_idx_curr)
        clust_id_list.append(clust_idx_next)
        
        curr_clust = sys2_clusters[clust_idx_curr]
        next_clust = sys2_clusters[clust_idx_next]
        tree_clust = cKDTree(next_clust)
        if k ==0:
            search_init = 0
        else:
            search_init = 1
        sht_dist = inf
        for inc in range(search_init, len(curr_clust)):
            val_sd, idx_sd = tree_clust.query(curr_clust[inc])
            if val_sd < sht_dist:
                sht_dist = val_sd
                sht_idx_curr = inc
                sht_idx_next = idx_sd
        curr_clust[[-1, sht_idx_curr]] = curr_clust[[sht_idx_curr,-1]]
        sys2_clusters[clust_idx_curr] = curr_clust
        next_clust[[0, sht_idx_next]] = next_clust[[sht_idx_next,0]]
        sys2_clusters[clust_idx_next] = next_clust
        if Lowest_Hier:
            total_traveling_distance += sht_dist
    return sys2_clusters, total_traveling_distance

# %%
def gen_sys2_sol(MAC_ising, benchmark, sys2_centers, sys2_clusters):
    MAC_ising = False
    if MAC_ising:
        cpp_cmd = "./ising_mac"
    else :
        cpp_cmd = "./ising_RNG"
    
    sol_route = []
    total_traveling_distance = 0
    timet =[]
    os.system("rm -rf sys2clusters_" + str(benchmark))
    SYS2_CENTERS = sys2_centers
    SYS2_CLUSTERS = sys2_clusters
    
    sys2_labels = []
    colors = mpl.cm.tab20(range(20))

    for h in range(0, n_hierarchies+1):
        print("Execute Ising Solver for Hierarchy ", n_hierarchies-h)
        sys2_centers = SYS2_CENTERS[n_hierarchies-h]
        sys2_clusters = SYS2_CLUSTERS[n_hierarchies-h]

        timet.append([])
        ## Find a pair of the closest cities that are in different clusters which will be sequentially visited.
        ## After finding, place each city in the pair in the end of the preceding cluster and the start of the following cluster.
        ## To avoid the city in the following cluster to be selected once again for the next search, the next search starts from Index 1.
        ## Refer to Page 25
        
        if h != 0:
            tree = cKDTree(sys2_centers)
            clust_id_list = []
            for k in range(len(sol_route)-1):
                clust_idx_curr = tree.query(sol_route[k])[1]
                clust_idx_next = tree.query(sol_route[k+1])[1]
                if k ==0:
                    clust_id_list.append(clust_idx_curr)
                clust_id_list.append(clust_idx_next)
                
                curr_clust = sys2_clusters[clust_idx_curr]
                next_clust = sys2_clusters[clust_idx_next]
                tree_clust = cKDTree(next_clust)
                if k ==0:
                    search_init = 0
                else:
                    search_init = 1
                sht_dist = inf
                for inc in range(search_init, len(curr_clust)):
                    val_sd, idx_sd = tree_clust.query(curr_clust[inc])
                    if val_sd < sht_dist:
                        sht_dist = val_sd
                        sht_idx_curr = inc
                        sht_idx_next = idx_sd
                curr_clust[[-1, sht_idx_curr]] = curr_clust[[sht_idx_curr,-1]]
                sys2_clusters[clust_idx_curr] = curr_clust
                next_clust[[0, sht_idx_next]] = next_clust[[sht_idx_next,0]]
                sys2_clusters[clust_idx_next] = next_clust
                if h == n_hierarchies:
                    total_traveling_distance += sht_dist
                    print("hierarchy: ", h, " cluster: ", k, " distance to the next cluster: ", sht_dist, " total distance: ", total_traveling_distance)
            sol_route = []
            route_btw_clusters = []
        else:
            clust_id_list = range(0, len(sys2_centers))
            
        kth = 0
        sys2_labels.append([])
        #for k in range(0, len(sys2_centers)):
        for k in clust_id_list:
            curr_center = sys2_centers[k]
            curr_clust = sys2_clusters[k]
            curr_clust_size = len(curr_clust)
            for l in range(curr_clust_size):
                sys2_labels[h].append(colors[kth%20])
                
            curr_clust_file = [curr_clust_size]
            curr_clust_file.append(curr_clust)
            os.system("mkdir -p sys2clusters_" + str(benchmark))
            curr_filename = str(benchmark) + "_h" + str(n_hierarchies-h)  + "_c" + str(kth) +".in"
            curr_logfile = str(benchmark) + "_h" + str(n_hierarchies-h)   + "_c" + str(kth) +".out"
            inF = open("sys2clusters_" + str(benchmark) + "/" + curr_filename,"w")
            inF.write(str(curr_clust_size))
            inF.write("\n")
            for i in curr_clust:
                inF.write(str(i[0]) + " " + str(i[1]))
                inF.write("\n")      
            inF.close()
            
    #        outF = open("sys2clusters_" + str(benchmark) + "/" + curr_logfile,"w")
            
            for i in range(0,1):
    #            outF.write("pass " + str(i+1) + "\n")
                tic = time.perf_counter()
                ### when h>0, Problem_size to optimize = N-1 when k is 0 or -1, otherwise N-2
                if h == 0 :
                    os.system(cpp_cmd+" k0" + " sys2clusters_" + str(benchmark) + "/" + curr_filename + " >> " + "sys2clusters_" + str(benchmark) + "/" + curr_logfile)
                elif kth == len(sys2_centers)-1:
                    os.system(cpp_cmd+" k-1" + " sys2clusters_" + str(benchmark) + "/" + curr_filename + " >> " + "sys2clusters_" + str(benchmark) + "/" + curr_logfile)
                else :
                    os.system(cpp_cmd+" k" + str(kth+1) + " sys2clusters_" + str(benchmark) + "/" + curr_filename + " >> " + "sys2clusters_" + str(benchmark) + "/" + curr_logfile)
                toc = time.perf_counter()
                timet[-1].append(toc-tic)
            
    #            print(f"time = {toc-tic:0.4f} seconds")
            dist_array =[]
            sol =[]
            with open("sys2clusters_" + str(benchmark) + "/" + curr_logfile,"r") as outFile:
                lines = outFile.readlines()
                
                for i in range(0,len(lines)):
                    line = lines[i]
                    if "dist" in line:
                        dist_array.append(line.strip().split()[1])
                        continue
                dist = min(dist_array)
                ####################################
                ####################################
                ####################################
                if h == n_hierarchies:
                    print("hierarchy: ", h, " cluster: ", kth, " distance to the next cluster: ", float(dist), " total distance: ", total_traveling_distance)
                    total_traveling_distance += float(dist)
                ####################################
                ####################################
                ####################################
                for i in range(0, curr_clust_size):
                    line = lines[i]
                    """
                    if "seq_clust" in line:
                        continue
                    if "dist" in line:
                        continue
                    if "size():" in line:
                        continue
                    if "final" in line:
                        continue
                    if "remapped" in line:
                        continue
                    """
                    curr = line.strip().split()
                    for j in range(len(curr)):
                        curr[j] = float(curr[j])
                    sol_route.append(curr)
                
                    if h == n_hierarchies:
                        if (i == 0) or (i == curr_clust_size-1):
                            route_btw_clusters.append(curr)
                
                outFile.close()
            print("done with cluster" + str(k)+ " ("+str(kth)+"th)")
            kth += 1
        print("Ising Max time = " + str(max(timet[-1])))
        print("Ising Min time = " + str(min(timet[-1])))
        #print("Ising Total time = " + str(sum(timet[-1])))
    
    print("total_traveling_distance: ", total_traveling_distance)
    return sol_route, route_btw_clusters, sys2_labels

# %%
print(n_clusters)
sol_route, route_btw_clusters, sys2_labels = gen_sys2_sol(MAC_ising, x, sys2_centers, sys2_clusters)
# Out:
# [126, 16, 2]
# Execute Ising Solver for Hierarchy  3
# done with cluster0 (0th)
# Ising Max time = 0.022534684045240283
# Ising Min time = 0.022534684045240283
# Execute Ising Solver for Hierarchy  2
# done with cluster0 (0th)
# done with cluster1 (1th)
# Ising Max time = 0.2871608380228281
# Ising Min time = 0.23624082806054503
# Execute Ising Solver for Hierarchy  1
# done with cluster0 (0th)
# done with cluster12 (1th)
# done with cluster6 (2th)
# done with cluster9 (3th)
# done with cluster5 (4th)
# done with cluster11 (5th)
# done with cluster2 (6th)
# done with cluster15 (7th)
# done with cluster8 (8th)
# done with cluster7 (9th)
# done with cluster3 (10th)
# done with cluster14 (11th)
# done with cluster1 (12th)
# done with cluster10 (13th)
# done with cluster13 (14th)
# done with cluster4 (15th)
# Ising Max time = 0.2927276509581134
# Ising Min time = 0.11799550789874047
# Execute Ising Solver for Hierarchy  0
# hierarchy:  3  cluster:  0  distance to the next cluster:  158.11388300841898  total distance:  158.11388300841898
# hierarchy:  3  cluster:  1  distance to the next cluster:  738.24115301167  total distance:  896.355036020089
# hierarchy:  3  cluster:  2  distance to the next cluster:  158.11388300841898  total distance:  1054.468919028508
# hierarchy:  3  cluster:  3  distance to the next cluster:  500.0  total distance:  1554.468919028508
# hierarchy:  3  cluster:  4  distance to the next cluster:  304.138126514911  total distance:  1858.607045543419
# hierarchy:  3  cluster:  5  distance to the next cluster:  206.15528128088303  total distance:  2064.762326824302
# hierarchy:  3  cluster:  6  distance to the next cluster:  291.547594742265  total distance:  2356.309921566567
# hierarchy:  3  cluster:  7  distance to the next cluster:  335.4101966249685  total distance:  2691.7201181915357
# hierarchy:  3  cluster:  8  distance to the next cluster:  250.0  total distance:  2941.7201181915357
# hierarchy:  3  cluster:  9  distance to the next cluster:  680.0735254367721  total distance:  3621.793643628308
# hierarchy:  3  cluster:  10  distance to the next cluster:  1610.1242188104618  total distance:  5231.91786243877
# hierarchy:  3  cluster:  11  distance to the next cluster:  210.7225664232476  total distance:  5442.640428862017
# hierarchy:  3  cluster:  12  distance to the next cluster:  841.4582580259106  total distance:  6284.098686887927
# hierarchy:  3  cluster:  120  distance to the next cluster:  1850.71  total distance:  311089.76430338144
# done with cluster11 (120th)
# hierarchy:  3  cluster:  121  distance to the next cluster:  1753.08  total distance:  312940.47430338146
# done with cluster124 (121th)
# hierarchy:  3  cluster:  122  distance to the next cluster:  1898.8  total distance:  314693.5543033815
# done with cluster96 (122th)
# hierarchy:  3  cluster:  123  distance to the next cluster:  2210.86  total distance:  316592.35430338146
# done with cluster41 (123th)
# hierarchy:  3  cluster:  124  distance to the next cluster:  2244.66  total distance:  318803.21430338145
# done with cluster5 (124th)
# hierarchy:  3  cluster:  125  distance to the next cluster:  2426.0  total distance:  321047.8743033814
# done with cluster32 (125th)
# Ising Max time = 0.3357531490037218
# Ising Min time = 0.07271455298177898
# total_traveling_distance:  323473.8743033814

# %%
route = np.array(route_btw_clusters)
sol_route = np.array(sol_route)
for n in range(int(len(route_btw_clusters)/2)-1):
    plt.plot(route[2*n+1:2*(n+1)+1,0], route[2*n+1:2*(n+1)+1,1], '-')
plt.scatter(sol_route[:,0], sol_route[:,1], c=sys2_labels[n_hierarchies][:], s=20)
plt.show()

# %%
from math import sin, cos, sqrt, atan2, radians
def compute_geo(p1,p2):
    R = 6373.0
    
    lat1 = radians(float(p1[0]))
    lon1 = radians(float(p1[1]))
    lat2 = radians(float(p2[0]))
    lon2 = radians(float(p2[1]))
    
    dlon = lon2 - lon1
    dlat = lat2 -lat1

    a = sin(dlat/2)**2 + cos(lat1)*cos(lat2)*sin(dlon/2)**2
    c = 2*atan2(sqrt(a),sqrt(1-a))
    dist = R*c
    return dist

# %%
coord_geo == False
if coord_geo == True:
#     test = np.load("sys2clusters_" + str(x) + "/sol_table.npy", allow_pickle=True)
    for i in range(len(test)):
        print(i)
        for j in range(len(test[i])):
            geo_dist = 0
            li = test[i][j][1]
            for idx,elem in enumerate(li):
                thiscity = elem
                nextcity = li[(idx+1)%len(li)]
                geo_dist += compute_geo(thiscity, nextcity)
            test[i][j][2] = geo_dist 
            print(geo_dist)
        np.save("sys2clusters_" + str(x) + "/sol_table" ,test)

# %% [markdown]
# mport pdb; pdb.set_trace()

# %%
## Sangmin edited

print(X_coord.shape)
print(Y_coord.shape)
print(x)
with open("tsp" + x + "_pyconcorde.txt", "w") as f:
    solver = TSPSolver.from_data(X_coord, Y_coord, norm="EUC_2D")  
    solution = solver.solve()
    f.write( str(" ") + str('output') + str(" ") )
    f.write( str("solution found? ") + str(solution.found_tour) + str(" ") )
    f.write( str("Optimal value? ") + str(solution.optimal_value) + str(" ") )
    f.write( str(" ").join( str(node_idx+1) for node_idx in solution.tour) )
    f.write( str(" ") + str(solution.tour[0]+1) + str(" ") )
# Out:
# (1001,)
# (1001,)
# pr1002
# Problem Name: b2d10840a4b043b18efdabd75ea4285f
# Problem Type: TSP
# Number of Nodes: 1001
# Rounded Euclidean Norm (CC_EUCLIDEAN)
# CCtsp_solve_dat ...
# Finding a good tour for compression ...
# linkern ...
# Starting Cycle: 304860
#    0 Steps   Best: 263521   0.01 seconds
#    2 Steps   Best: 263455   0.01 seconds
#    3 Steps   Best: 263423   0.01 seconds
Groetschel-Holland Blossoms in 0.00 seconds
#   Add 19 cuts (Total 85), LP: 255407.550000 (0.00 seconds)
# Block Combs
#   Type 0: 13 cuts  2.0000 max violation  0.00 seconds
#   Type 1: 6 cuts  2.5000 max violation  0.00 seconds
#   Type 2: 6 cuts  3.0000 max violation  0.00 seconds
#   Type 3: 2 cuts  2.0000 max violation  0.00 seconds
#   Type 4: 0 cuts  0.0000 max violation  0.00 seconds
#   Type 5: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 1: 8 cuts  2.5000 max violation  0.00 seconds
#   Olaf 2: 9 cuts  2.0000 max violation  0.00 seconds
#   Olaf 3: 5 cuts  1.3000 max violation  0.00 seconds
#   Olaf 4: 5 cuts  1.3000 max violation  0.00 seconds
#   Total Time in block_combs: 0.01
# Found 54 block_combs in 0.01 seconds
#   Add 54 cuts (Total 92), LP: 255452.166667 (0.00 seconds)
# Found 22 exact subtours in 0.00 seconds
#   Add 22 cuts (Total 110), LP: 256320.283333 (0.00 seconds)
# Found 44 tighten_lp cuts (viol 2.0000) in 0.00 seconds
#   Add 44 cuts (Total 127), LP: 256527.750000 (0.00 seconds)
# Found 23 CLOSE tighten_lp cuts (viol 0.5000) in 0.00 seconds
#   Add 23 cuts (Total 137), LP: 256914.333333 (0.00 seconds)
# Found 21 double deckers (viol 2.3333) in 0.01 seconds
#   Add 21 cuts (Total 143), LP: 256939.916667 (0.00 seconds)
# Found  7 CLOSE double deckers (viol 0.7500) in 0.00 seconds
#   Add  7 cuts (Total 144), LP: 256947.166667 (0.00 seconds)
# Found 15 Handling Inequalities (viol 1.0833) in 0.01 seconds
#   Add 15 cuts (Total 151), LP: 256977.697619 (0.00 seconds)
# Found  6 teethed combs (viol 1.0000) in 0.00 seconds
#   Add  6 cuts (Total 156), LP: 257009.733333 (0.00 seconds)
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.01 seconds (0.01 total in 1 calls)
# Time for Add edges optimize: 0.01 seconds (0.01 total in 2 calls)
# Time for Add edges optimize: 0.00 seconds (0.02 total in 3 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.00 seconds (0.02 total in 4 calls)
# Time for Add edges optimize: 0.00 seconds (0.02 total in 5 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.00 seconds (0.02 total in 6 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.00 seconds (0.02 total in 7 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges: 0.02 seconds (0.02 total in 1 calls)
# (SPARSE) 424 edges added, penalty 0.000000, val 248088.937500
# Time for Sparse edge check: 0.02 seconds (0.02 total in 1 calls)
# Write Pool: 69 cuts
# Time for Cutting inside loop: 0.09 seconds (0.09 total in 1 calls)
# LP has:  1157 rows  2096 columns  9308 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  1157 rows  2096 columns  5770 nonzeros
# Found 57 connect cuts in 0.00 seconds
#   Add 57 cuts (Total 192), LP: 252928.333333 (0.01 seconds)
# Found 25 segment cuts in 0.00 seconds
#   Add 25 cuts (Total 209), LP: 253686.116667 (0.01 seconds)
# Found 26 Fast Blossoms in 0.00 seconds
#   Add 26 cuts (Total 230), LP: 254079.876389 (0.01 seconds)
# Found 22 Groetschel-Holland Blossoms in 0.00 seconds
#   Add 22 cuts (Total 242), LP: 254219.379630 (0.01 seconds)
# Block Combs
#   Type 0: 41 cuts  1.4167 max violation  0.00 seconds
#   Type 1: 40 cuts  1.4167 max violation  0.00 seconds
#   Type 2: 34 cuts  2.2500 max violation  0.00 seconds
#   Type 3: 23 cuts  2.2500 max violation  0.00 seconds
#   Type 4: 23 cuts  3.2500 max violation  0.00 seconds
#   Type 5: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 1: 27 cuts  1.0000 max violation  0.00 seconds
#   Olaf 2: 31 cuts  2.0000 max violation  0.01 seconds
#   Olaf 3: 10 cuts  3.0000 max violation  0.00 seconds
#   Olaf 4: 18 cuts  3.0000 max violation  0.00 seconds
#   Total Time in block_combs: 0.04
# Found 247 block_combs in 0.04 seconds
#   Add 247 cuts (Total 272), LP: 254372.501302 (0.02 seconds)
# Found 15 exact subtours in 0.00 seconds
#   Add 15 cuts (Total 281), LP: 256054.722222 (0.01 seconds)
# Found 79 tighten_lp cuts (viol 1.1111) in 0.01 seconds
#   Add 79 cuts (Total 304), LP: 256235.895833 (0.01 seconds)
# Found 41 CLOSE tighten_lp cuts (viol 0.5000) in 0.00 seconds
#   Add 41 cuts (Total 315), LP: 256410.375000 (0.01 seconds)
# Found 63 double deckers (viol 8.0000) in 0.02 seconds
#   Add 63 cuts (Total 324), LP: 256461.871970 (0.01 seconds)
# Found 15 CLOSE double deckers (viol 1.0556) in 0.01 seconds
#   Add 15 cuts (Total 306), LP: 256519.211364 (0.00 seconds)
# Found 15 Handling Inequalities (viol 3.3750) in 0.01 seconds
#   Add 15 cuts (Total 313), LP: 256546.863570 (0.00 seconds)
# Found 25 teethed combs (viol 1.7500) in 0.00 seconds
#   Add 25 cuts (Total 323), LP: 256602.692980 (0.00 seconds)
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.02 seconds (0.04 total in 8 calls)
# Time for Add edges optimize: 0.00 seconds (0.04 total in 9 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.00 seconds (0.04 total in 10 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges: 0.02 seconds (0.05 total in 2 calls)
# (SPARSE) 119 edges added, penalty 0.000000, val 256013.725694
# Time for Sparse edge check: 0.02 seconds (0.05 total in 2 calls)
# Write Pool: 201 cuts
# Time for Cutting inside loop: 0.22 seconds (0.31 total in 2 calls)
# LP has:  1324 rows  2215 columns  17759 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  1324 rows  2215 columns  7883 nonzeros
# Found  2 pool cuts (viol 1.0000) in 0.00 seconds
#   Add  2 cuts (Total 325), LP: 256033.225694 (0.01 seconds)
# Found 14 connect cuts in 0.00 seconds
#   Add 14 cuts (Total 327), LP: 256141.475694 (0.00 seconds)
# Found 36 segment cuts in 0.00 seconds
#   Add 36 cuts (Total 337), LP: 256377.812500 (0.01 seconds)
# Found 22 Fast Blossoms in 0.00 seconds
#   Add 22 cuts (Total 347), LP: 256563.375000 (0.01 seconds)
# Found 25 Groetschel-Holland Blossoms in 0.00 seconds
#   Add 23 cuts (Total 354), LP: 256708.766667 (0.00 seconds)
# Block Combs
#   Type 0: 30 cuts  2.0000 max violation  0.00 seconds
#   Type 1: 17 cuts  2.0000 max violation  0.00 seconds
#   Type 2: 12 cuts  2.0000 max violation  0.00 seconds
#   Type 4: 10 cuts  2.0000 max violation  0.00 seconds
#   Type 5: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 1: 20 cuts  2.0000 max violation  0.00 seconds
#   Olaf 2: 18 cuts  2.0000 max violation  0.00 seconds
#   Olaf 3: 8 cuts  1.4333 max violation  0.00 seconds
#   Olaf 4: 6 cuts  0.8333 max violation  0.00 seconds
#   Total Time in block_combs: 0.02
# Found 121 block_combs in 0.02 seconds
#   Add 121 cuts (Total 368), LP: 256832.207939 (0.01 seconds)
# Found  2 exact subtours in 0.00 seconds
#   Add  2 cuts (Total 366), LP: 256881.025728 (0.00 seconds)
# Found 87 tighten_lp cuts (viol 1.0270) in 0.01 seconds
#   Add 87 cuts (Total 394), LP: 257056.600000 (0.01 seconds)
# Found 46 CLOSE tighten_lp cuts (viol 0.2500) in 0.00 seconds
#   Add 46 cuts (Total 408), LP: 257141.750000 (0.01 seconds)
# Found 38 double deckers (viol 3.0000) in 0.07 seconds
#   Add 38 cuts (Total 397), LP: 257185.842857 (0.01 seconds)
# Found 23 CLOSE double deckers (viol 1.0000) in 0.02 seconds
#   Add 23 cuts (Total 404), LP: 257269.222222 (0.01 seconds)
# Found 21 Handling Inequalities (viol 1.3333) in 0.02 seconds
#   Add 21 cuts (Total 399), LP: 257271.077778 (0.00 seconds)
# Found 15 teethed combs (viol 1.1000) in 0.01 seconds
#   Add 15 cuts (Total 399), LP: 257356.931176 (0.01 seconds)
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.01 seconds (0.06 total in 11 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.00 seconds (0.06 total in 12 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges: 0.02 seconds (0.06 total in 3 calls)
# (SPARSE) 106 edges added, penalty -0.000000, val 257021.250000
# Time for Sparse edge check: 0.02 seconds (0.06 total in 3 calls)
# Write Pool: 326 cuts
# Time for Cutting inside loop: 0.27 seconds (0.58 total in 3 calls)
# LP has:  1400 rows  2321 columns  16746 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  1400 rows  2321 columns  8942 nonzeros
# Found  2 pool cuts (viol 1.0000) in 0.00 seconds
#   Add  2 cuts (Total 401), LP: 257021.250000 (0.01 seconds)
# Found  3 connect cuts in 0.00 seconds
#   Add  3 cuts (Total 390), LP: 257118.666667 (0.00 seconds)
# Found  8 segment cuts in 0.00 seconds
#   Add  8 cuts (Total 393), LP: 257143.710938 (0.01 seconds)
# Found 12 Fast Blossoms in 0.00 seconds
#   Add 12 cuts (Total 401), LP: 257230.774306 (0.01 seconds)
# Found 10 Groetschel-Holland Blossoms in 0.00 seconds
#   Add 10 cuts (Total 402), LP: 257290.185190 (0.01 seconds)
# Block Combs
#   Type 0: 43 cuts  1.9130 max violation  0.01 seconds
#   Type 1: 25 cuts  0.9565 max violation  0.00 seconds
#   Type 2: 19 cuts  0.8021 max violation  0.00 seconds
#   Type 4: 15 cuts  0.5217 max violation  0.00 seconds
#   Type 5: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 1: 17 cuts  1.9130 max violation  0.00 seconds
#   Olaf 2: 14 cuts  1.0435 max violation  0.00 seconds
#   Olaf 3: 1 cuts  0.8696 max violation  0.00 seconds
#   Olaf 4: 1 cuts  0.8696 max violation  0.00 seconds
#   Total Time in block_combs: 0.03
# Found 135 block_combs in 0.03 seconds
#   Add 135 cuts (Total 421), LP: 257339.164651 (0.02 seconds)
# Found  2 exact subtours in 0.00 seconds
#   Add  2 cuts (Total 417), LP: 257357.664651 (0.00 seconds)
# Found 86 tighten_lp cuts (viol 0.9655) in 0.01 seconds
#   Add 86 cuts (Total 433), LP: 257446.445238 (0.01 seconds)
# Found 48 CLOSE tighten_lp cuts (viol 0.5000) in 0.01 seconds
#   Add 48 cuts (Total 450), LP: 257513.514867 (0.02 seconds)
# Found 79 double deckers (viol 2.0000) in 0.02 seconds
#   Add 79 cuts (Total 458), LP: 257591.732719 (0.02 seconds)
# Found 36 CLOSE double deckers (viol 1.0000) in 0.02 seconds
#   Add 36 cuts (Total 456), LP: 257620.597057 (0.01 seconds)
# Found  5 Handling Inequalities (viol 0.6986) in 0.02 seconds
#   Add  5 cuts (Total 455), LP: 257623.719380 (0.00 seconds)
# Found 29 teethed combs (viol 0.6667) in 0.01 seconds
#   Add 29 cuts (Total 460), LP: 257662.447452 (0.01 seconds)
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.03 seconds (0.09 total in 13 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.00 seconds (0.09 total in 14 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges: 0.03 seconds (0.10 total in 4 calls)
# (SPARSE) 40 edges added, penalty -0.000000, val 257591.141278
# Time for Sparse edge check: 0.03 seconds (0.10 total in 4 calls)
# Write Pool: 449 cuts
# Time for Cutting inside loop: 0.28 seconds (0.86 total in 4 calls)
# LP has:  1461 rows  2361 columns  18017 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  1461 rows  2361 columns  10195 nonzeros
# Found  7 pool cuts (viol 0.5500) in 0.00 seconds
#   Add  7 cuts (Total 455), LP: 257596.678442 (0.02 seconds)
# Found  0 connect cuts in 0.00 seconds
# Found 43 segment cuts in 0.00 seconds
#   Add 43 cuts (Total 456), LP: 257641.318438 (0.01 seconds)
# Found  4 Fast Blossoms in 0.00 seconds
#   Add  4 cuts (Total 458), LP: 257666.720908 (0.01 seconds)
# Found 10 Groetschel-Holland Blossoms in 0.00 seconds
#   Add 10 cuts (Total 454), LP: 257701.665598 (0.01 seconds)
# Block Combs
#   Type 0: 41 cuts  1.3333 max violation  0.01 seconds
#   Type 1: 25 cuts  0.9583 max violation  0.00 seconds
#   Type 2: 18 cuts  0.6667 max violation  0.00 seconds
#   Type 4: 10 cuts  0.6667 max violation  0.00 seconds
#   Type 5: 0 cuts  0.0000 max violation  0.01 seconds
#   Olaf 1: 9 cuts  0.5256 max violation  0.01 seconds
#   Olaf 2: 8 cuts  1.0000 max violation  0.01 seconds
#   Olaf 3: 4 cuts  1.4744 max violation  0.00 seconds
#   Olaf 4: 4 cuts  1.4744 max violation  0.00 seconds
#   Total Time in block_combs: 0.04
# Found 119 block_combs in 0.04 seconds
#   Add 119 cuts (Total 462), LP: 257785.319377 (0.04 seconds)
# Found 40 exact subtours in 0.00 seconds
#   Add 40 cuts (Total 462), LP: 257822.819509 (0.02 seconds)
# Found 54 tighten_lp cuts (viol 1.0000) in 0.02 seconds
#   Add 54 cuts (Total 468), LP: 257844.905159 (0.02 seconds)
# Found 33 CLOSE tighten_lp cuts (viol 0.5000) in 0.01 seconds
#   Add 33 cuts (Total 476), LP: 257874.549683 (0.02 seconds)
# Found 42 double deckers (viol 1.4545) in 0.03 seconds
#   Add 42 cuts (Total 476), LP: 257887.017766 (0.01 seconds)
# Found 16 CLOSE double deckers (viol 0.6000) in 0.04 seconds
#   Add 16 cuts (Total 473), LP: 257900.862831 (0.02 seconds)
# Found 20 Handling Inequalities (viol 0.0781) in 0.03 seconds
#   Add 20 cuts (Total 464), LP: 257900.884315 (0.00 seconds)
# Found 22 teethed combs (viol 1.0156) in 0.01 seconds
#   Add 22 cuts (Total 467), LP: 257929.032540 (0.04 seconds)
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.03 seconds (0.12 total in 15 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.00 seconds (0.12 total in 16 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges: 0.04 seconds (0.13 total in 5 calls)
# (SPARSE) 29 edges added, penalty -0.000000, val 257831.644907
# Time for Sparse edge check: 0.04 seconds (0.13 total in 5 calls)
# Write Pool: 518 cuts
# Time for Cutting inside loop: 0.44 seconds (1.30 total in 5 calls)
# LP has:  1468 rows  2390 columns  19512 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  1468 rows  2390 columns  10943 nonzeros
# Found  3 pool cuts (viol 0.1736) in 0.00 seconds
#   Add  3 cuts (Total 466), LP: 257832.677083 (0.02 seconds)
# Found  0 connect cuts in 0.00 seconds
# Found  6 segment cuts in 0.00 seconds
#   Add  6 cuts (Total 451), LP: 257851.833333 (0.01 seconds)
# Found  2 Fast Blossoms in 0.00 seconds
#   Add  2 cuts (Total 441), LP: 257852.604167 (0.01 seconds)
# Found  3 Groetschel-Holland Blossoms in 0.00 seconds
#   Add  3 cuts (Total 439), LP: 257853.585367 (0.00 seconds)
# Block Combs
#   Type 0: 11 cuts  1.0000 max violation  0.00 seconds
#   Type 1: 13 cuts  1.0000 max violation  0.00 seconds
#   Type 2: 16 cuts  1.0000 max violation  0.00 seconds
#   Type 4: 6 cuts  1.0000 max violation  0.00 seconds
#   Type 5: 1 cuts  0.7297 max violation  0.00 seconds
#   Olaf 1: 8 cuts  1.0000 max violation  0.00 seconds
#   Olaf 2: 6 cuts  1.0000 max violation  0.01 seconds
#   Olaf 3: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 4: 0 cuts  0.0000 max violation  0.00 seconds
#   Total Time in block_combs: 0.04
# Found 61 block_combs in 0.04 seconds
#   Add 61 cuts (Total 438), LP: 257906.782143 (0.03 seconds)
# Found 16 exact subtours in 0.00 seconds
#   Add 16 cuts (Total 437), LP: 257914.686639 (0.01 seconds)
# Found 55 tighten_lp cuts (viol 0.5620) in 0.01 seconds
#   Add 55 cuts (Total 445), LP: 257947.095573 (0.04 seconds)
# Found 60 CLOSE tighten_lp cuts (viol 0.1607) in 0.01 seconds
#   Add 60 cuts (Total 448), LP: 257951.875000 (0.01 seconds)
# Found 12 double deckers (viol 3.0000) in 0.05 seconds
#   Add 12 cuts (Total 439), LP: 257958.747153 (0.03 seconds)
# Found 63 CLOSE double deckers (viol 0.3426) in 0.02 seconds
#   Add 63 cuts (Total 440), LP: 257963.500000 (0.01 seconds)
# Found  2 Handling Inequalities (viol 0.1373) in 0.05 seconds
#   Add  2 cuts (Total 439), LP: 257964.221698 (0.01 seconds)
# Found  6 teethed combs (viol 0.3019) in 0.01 seconds
#   Add  6 cuts (Total 440), LP: 257965.333095 (0.01 seconds)
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.03 seconds (0.15 total in 17 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges: 0.03 seconds (0.16 total in 6 calls)
# (SPARSE) 10 edges added, penalty 0.000000, val 257955.511959
# Time for Sparse edge check: 0.03 seconds (0.16 total in 6 calls)
# Write Pool: 569 cuts
# Time for Cutting inside loop: 0.41 seconds (1.71 total in 6 calls)
# LP has:  1441 rows  2400 columns  18833 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  1441 rows  2400 columns  10827 nonzeros
# Found  3 pool cuts (viol 0.0585) in 0.00 seconds
#   Add  2 cuts (Total 440), LP: 257955.542253 (0.02 seconds)
# Found  0 connect cuts in 0.00 seconds
# Found  8 segment cuts in 0.00 seconds
#   Add  8 cuts (Total 438), LP: 257963.455456 (0.02 seconds)
# Found  0 Fast Blossoms in 0.00 seconds
# Found  2 Groetschel-Holland Blossoms in 0.00 seconds
#   Add  2 cuts (Total 436), LP: 257964.908042 (0.01 seconds)
# Block Combs
#   Type 0: 15 cuts  0.5356 max violation  0.00 seconds
#   Type 1: 9 cuts  0.6661 max violation  0.01 seconds
#   Type 2: 6 cuts  0.4155 max violation  0.00 seconds
#   Type 4: 6 cuts  0.4339 max violation  0.00 seconds
#   Type 5: 0 cuts  0.0000 max violation  0.01 seconds
#   Olaf 1: 5 cuts  0.2298 max violation  0.01 seconds
#   Olaf 2: 8 cuts  0.4587 max violation  0.01 seconds
#   Olaf 3: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 4: 0 cuts  0.0000 max violation  0.00 seconds
#   Total Time in block_combs: 0.04
# Found 49 block_combs in 0.04 seconds
#   Add 49 cuts (Total 431), LP: 257971.823314 (0.02 seconds)
# Found 17 exact subtours in 0.00 seconds
#   Add 15 cuts (Total 434), LP: 257973.666353 (0.01 seconds)
# Found 48 tighten_lp cuts (viol 0.3456) in 0.01 seconds
#   Add 48 cuts (Total 437), LP: 257979.798397 (0.03 seconds)
# Found 29 CLOSE tighten_lp cuts (viol 0.0688) in 0.02 seconds
#   Add 29 cuts (Total 442), LP: 257980.974432 (0.01 seconds)
# Found  2 double deckers (viol 0.7500) in 0.04 seconds
#   Add  2 cuts (Total 440), LP: 257981.618182 (0.00 seconds)
# Found  1 CLOSE double deckers (viol 0.2000) in 0.04 seconds
#   Add  1 cuts (Total 441), LP: 257981.618182 (0.00 seconds)
# Found  0 Handling Inequalities (viol -0.0000) in 0.03 seconds
# Found  2 teethed combs (viol 0.4000) in 0.01 seconds
#   Add  2 cuts (Total 438), LP: 257981.646753 (0.00 seconds)
# Found 28 consecutiveones cuts in 0.02 seconds
#   Add 28 cuts (Total 447), LP: 258047.290200 (0.03 seconds)
# localcuts classes(8d)... 273 nodes 433 edges
# localcuts done in 0.00 seconds
# Found  2 LocalCuts in 0.00 seconds
#   Add  2 cuts (Total 443), LP: 258048.064394 (0.00 seconds)
# localcuts classes(9d)... 264 nodes 417 edges
# localcuts done in 0.00 seconds
# Found  1 LocalCuts in 0.00 seconds
#   Add  1 cuts (Total 443), LP: 258048.164394 (0.00 seconds)
# localcuts classes(10d)... 280 nodes 444 edges
# localcuts done in 0.01 seconds
# Found  3 LocalCuts in 0.01 seconds
#   Add  3 cuts (Total 439), LP: 258050.587963 (0.00 seconds)
# localcuts classes(11d)... 195 nodes 311 edges
# localcuts done in 0.00 seconds
# Found  3 LocalCuts in 0.00 seconds
#   Add  3 cuts (Total 434), LP: 258052.763889 (0.01 seconds)
# localcuts classes(12d)... 183 nodes 289 edges
# localcuts done in 0.00 seconds
# Found  5 LocalCuts in 0.00 seconds
#   Add  5 cuts (Total 427), LP: 258055.500000 (0.02 seconds)
# localcuts classes(13d)... 161 nodes 251 edges
# localcuts done in 0.00 seconds
# Found  2 LocalCuts in 0.00 seconds
#   Add  2 cuts (Total 426), LP: 258058.722115 (0.01 seconds)
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.02 seconds (0.17 total in 18 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges: 0.02 seconds (0.18 total in 7 calls)
# (SPARSE) 13 edges added, penalty 0.000000, val 258054.028133
# Time for Sparse edge check: 0.02 seconds (0.18 total in 7 calls)
# Write Pool: 627 cuts
# Time for Cutting inside loop: 0.46 seconds (2.17 total in 7 calls)
# LP has:  1427 rows  2413 columns  15080 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  1427 rows  2413 columns  10430 nonzeros
# Found 24 pool cuts (viol 2.0000) in 0.00 seconds
#   Add 24 cuts (Total 433), LP: 258085.430800 (0.05 seconds)
# Found  0 connect cuts in 0.00 seconds
# Found 19 segment cuts in 0.00 seconds
#   Add 19 cuts (Total 436), LP: 258090.700549 (0.01 seconds)
# Found  0 Fast Blossoms in 0.00 seconds
# Found  2 Groetschel-Holland Blossoms in 0.00 seconds
#   Add  2 cuts (Total 424), LP: 258090.781746 (0.00 seconds)
# Block Combs
#   Type 0: 11 cuts  0.3333 max violation  0.00 seconds
#   Type 1: 4 cuts  0.2857 max violation  0.00 seconds
#   Type 2: 6 cuts  0.6429 max violation  0.00 seconds
#   Type 4: 3 cuts  0.1111 max violation  0.00 seconds
#   Type 5: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 1: 3 cuts  0.2857 max violation  0.00 seconds
#   Olaf 2: 5 cuts  0.2857 max violation  0.01 seconds
#   Olaf 3: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 4: 0 cuts  0.0000 max violation  0.00 seconds
#   Total Time in block_combs: 0.02
# Found 32 block_combs in 0.02 seconds
#   Add 32 cuts (Total 431), LP: 258094.331959 (0.02 seconds)
# Found 17 exact subtours in 0.00 seconds
#   Add 14 cuts (Total 439), LP: 258097.725182 (0.02 seconds)
# Found 38 tighten_lp cuts (viol 0.5000) in 0.01 seconds
#   Add 38 cuts (Total 450), LP: 258109.703152 (0.04 seconds)
# Found 56 CLOSE tighten_lp cuts (viol 0.3559) in 0.01 seconds
#   Add 56 cuts (Total 455), LP: 258126.378261 (0.02 seconds)
# Found 49 double deckers (viol 0.6667) in 0.03 seconds
#   Add 49 cuts (Total 456), LP: 258128.008816 (0.01 seconds)
# Found 34 CLOSE double deckers (viol 0.3333) in 0.03 seconds
#   Add 34 cuts (Total 463), LP: 258129.753097 (0.02 seconds)
# Found 13 Handling Inequalities (viol 0.0599) in 0.05 seconds
#   Add 13 cuts (Total 461), LP: 258129.981407 (0.01 seconds)
# Found 38 teethed combs (viol 0.2726) in 0.01 seconds
#   Add 38 cuts (Total 475), LP: 258133.371656 (0.03 seconds)
# Found 35 consecutiveones cuts in 0.03 seconds
#   Add 29 cuts (Total 484), LP: 258167.954776 (0.04 seconds)
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.10 seconds (0.27 total in 19 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.00 seconds (0.28 total in 20 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges: 0.11 seconds (0.30 total in 8 calls)
# (SPARSE) 18 edges added, penalty -0.000000, val 258165.257587
# Time for Sparse edge check: 0.11 seconds (0.30 total in 8 calls)
# Write Pool: 700 cuts
# Time for Cutting inside loop: 0.60 seconds (2.77 total in 8 calls)
# LP has:  1485 rows  2431 columns  20058 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  1485 rows  2431 columns  12219 nonzeros
# Found  9 pool cuts (viol 0.3436) in 0.00 seconds
#   Add  9 cuts (Total 490), LP: 258168.279486 (0.05 seconds)
# Found  0 connect cuts in 0.00 seconds
# Found 14 segment cuts in 0.00 seconds
#   Add 12 cuts (Total 493), LP: 258169.020588 (0.01 seconds)
# Found  0 Fast Blossoms in 0.00 seconds
# Found  1 Groetschel-Holland Blossoms in 0.00 seconds
#   Add  1 cuts (Total 484), LP: 258169.510204 (0.01 seconds)
# Block Combs
#   Type 0: 3 cuts  0.2857 max violation  0.00 seconds
#   Type 1: 3 cuts  0.2857 max violation  0.00 seconds
#   Type 2: 1 cuts  0.1088 max violation  0.00 seconds
#   Type 5: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 1: 1 cuts  0.2857 max violation  0.00 seconds
#   Olaf 2: 1 cuts  0.2449 max violation  0.00 seconds
#   Olaf 3: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 4: 0 cuts  0.0000 max violation  0.00 seconds
#   Total Time in block_combs: 0.02
# Found  9 block_combs in 0.02 seconds
#   Add  9 cuts (Total 479), LP: 258171.128675 (0.01 seconds)
# Found  6 exact subtours in 0.00 seconds
#   Add  6 cuts (Total 479), LP: 258173.018692 (0.01 seconds)
# Found 23 tighten_lp cuts (viol 0.6168) in 0.06 seconds
#   Add 23 cuts (Total 482), LP: 258175.908778 (0.04 seconds)
# Found 39 CLOSE tighten_lp cuts (viol 0.2607) in 0.02 seconds
#   Add 39 cuts (Total 492), LP: 258188.005465 (0.06 seconds)
# Found 87 double deckers (viol 0.4446) in 0.03 seconds
#   Add 87 cuts (Total 495), LP: 258189.903005 (0.03 seconds)
# Found 23 CLOSE double deckers (viol 0.1052) in 0.06 seconds
#   Add 23 cuts (Total 487), LP: 258190.454545 (0.01 seconds)
# Found  4 Handling Inequalities (viol 0.0455) in 0.02 seconds
#   Add  4 cuts (Total 479), LP: 258190.552857 (0.01 seconds)
# Found 10 teethed combs (viol 0.3636) in 0.02 seconds
#   Add 10 cuts (Total 481), LP: 258191.694173 (0.02 seconds)
# Found 21 consecutiveones cuts in 0.03 seconds
#   Add 21 cuts (Total 487), LP: 258200.400000 (0.03 seconds)
# localcuts classes(8d)... 159 nodes 255 edges
# localcuts done in 0.00 seconds
# Found  2 LocalCuts in 0.00 seconds
#   Add  2 cuts (Total 488), LP: 258200.642946 (0.01 seconds)
# localcuts classes(9d)... 270 nodes 436 edges
# localcuts done in 0.00 seconds
# Found  2 LocalCuts in 0.00 seconds
#   Add  2 cuts (Total 487), LP: 258201.877967 (0.01 seconds)
# localcuts classes(10d)... 271 nodes 439 edges
# localcuts done in 0.00 seconds
# Found  2 LocalCuts in 0.00 seconds
#   Add  2 cuts (Total 478), LP: 258202.065737 (0.01 seconds)
# localcuts classes(11d)... 295 nodes 483 edges
# localcuts done in 0.00 seconds
# Found  1 LocalCuts in 0.00 seconds
#   Add  1 cuts (Total 463), LP: 258202.291286 (0.03 seconds)
# localcuts classes(12d)... 323 nodes 545 edges
# localcuts done in 0.00 seconds
# Found  2 LocalCuts in 0.00 seconds
#   Add  2 cuts (Total 456), LP: 258202.345481 (0.00 seconds)
# localcuts classes(13d)... 329 nodes 555 edges
# localcuts done in 0.00 seconds
# Found  1 LocalCuts in 0.00 seconds
#   Add  1 cuts (Total 452), LP: 258202.354430 (0.00 seconds)
# localcuts classes(14d)... 310 nodes 523 edges
# localcuts done in 0.00 seconds
# Found  1 LocalCuts in 0.00 seconds
#   Add  1 cuts (Total 451), LP: 258202.364930 (0.00 seconds)
# localcuts classes(15d)... 301 nodes 506 edges
# localcuts done in 0.00 seconds
# Found  0 LocalCuts in 0.00 seconds
# localcuts classes(16d)... 301 nodes 506 edges
# localcuts done in 0.01 seconds
# Found  1 LocalCuts in 0.01 seconds
#   Add  1 cuts (Total 446), LP: 258204.767759 (0.01 seconds)
# localcuts spheres(6d/8d)... 262 nodes 423 edges
# localcuts done in 0.02 seconds
# Found  5 LocalCuts in 0.02 seconds
#   Add  5 cuts (Total 434), LP: 258206.115727 (0.00 seconds)
# localcuts spheres(7d/9d)... 261 nodes 421 edges
# localcuts done in 0.02 seconds
# Found  9 LocalCuts in 0.02 seconds
#   Add  9 cuts (Total 436), LP: 258219.662921 (0.03 seconds)
# localcuts spheres(8d/10d)... 161 nodes 263 edges
# localcuts done in 0.02 seconds
# Found  3 LocalCuts in 0.02 seconds
#   Add  3 cuts (Total 434), LP: 258220.564647 (0.03 seconds)
# localcuts spheres(9d/11d)... 310 nodes 509 edges
# localcuts done in 0.03 seconds
# Found  4 LocalCuts in 0.03 seconds
#   Add  4 cuts (Total 434), LP: 258221.010929 (0.01 seconds)
# localcuts spheres(10d/12d)... 259 nodes 421 edges
# localcuts done in 0.03 seconds
# Found  3 LocalCuts in 0.03 seconds
#   Add  3 cuts (Total 426), LP: 258221.147506 (0.01 seconds)
# localcuts spheres(11d/13d)... 255 nodes 415 edges
# localcuts done in 0.05 seconds
# Found  5 LocalCuts in 0.05 seconds
#   Add  5 cuts (Total 428), LP: 258226.132119 (0.02 seconds)
# localcuts spheres(12d/14d)... 349 nodes 585 edges
# localcuts done in 0.11 seconds
# Found 36 LocalCuts in 0.11 seconds
#   Add 36 cuts (Total 434), LP: 258230.169355 (0.02 seconds)
# localcuts spheres(13d/15d)... 107 nodes 178 edges
# localcuts done in 0.04 seconds
# Found 18 LocalCuts in 0.04 seconds
#   Add 18 cuts (Total 436), LP: 258231.114659 (0.01 seconds)
# localcuts spheres(14d/16d)... 136 nodes 225 edges
# localcuts done in 0.04 seconds
# Found 26 LocalCuts in 0.04 seconds
#   Add 26 cuts (Total 439), LP: 258232.309535 (0.02 seconds)
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.06 seconds (0.34 total in 21 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges: 0.06 seconds (0.36 total in 9 calls)
# (SPARSE) 14 edges added, penalty 0.000000, val 258224.074267
# Time for Sparse edge check: 0.06 seconds (0.36 total in 9 calls)
# Write Pool: 793 cuts
# Time for Cutting inside loop: 1.23 seconds (4.00 total in 9 calls)
# LP has:  1440 rows  2445 columns  22048 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  1440 rows  2445 columns  11541 nonzeros
# Found  5 pool cuts (viol 0.2959) in 0.00 seconds
#   Add  5 cuts (Total 443), LP: 258225.712380 (0.06 seconds)
# Found  0 connect cuts in 0.00 seconds
# Found 38 segment cuts in 0.00 seconds
#   Add 33 cuts (Total 445), LP: 258228.070892 (0.03 seconds)
# Found  0 Fast Blossoms in 0.00 seconds
# Found  3 Groetschel-Holland Blossoms in 0.00 seconds
#   Add  2 cuts (Total 444), LP: 258228.746660 (0.01 seconds)
# Block Combs
#   Type 0: 21 cuts  0.0648 max violation  0.01 seconds
#   Type 1: 16 cuts  0.0648 max violation  0.01 seconds
#   Type 2: 13 cuts  0.0648 max violation  0.01 seconds
#   Type 5: 0 cuts  0.0000 max violation  0.01 seconds
#   Olaf 1: 10 cuts  0.0355 max violation  0.01 seconds
#   Olaf 2: 11 cuts  0.0232 max violation  0.01 seconds
#   Olaf 3: 0 cuts  0.0000 max violation  0.00 seconds
#   Olaf 4: 0 cuts  0.0001 max violation  0.00 seconds
#   Total Time in block_combs: 0.05
# Found 71 block_combs in 0.05 seconds
#   Add 71 cuts (Total 452), LP: 258229.139036 (0.01 seconds)
# Found  5 exact subtours in 0.00 seconds
#   Add  5 cuts (Total 455), LP: 258229.338525 (0.01 seconds)
# Found 20 tighten_lp cuts (viol 0.1641) in 0.02 seconds
#   Add 20 cuts (Total 455), LP: 258231.000000 (0.01 seconds)
# Integral Solution of Value 258231.00
# CCtsp_generate_edges (23003)
# Time for Add edges optimize: 0.00 seconds (0.34 total in 22 calls)
# CCtsp_generate_edges (23003)
# Time for Add edges: 0.01 seconds (0.36 total in 10 calls)
# (SPARSE) 1 edges added, penalty -0.000000, val 258231.000000
# Time for Sparse edge check: 0.01 seconds (0.36 total in 10 calls)
# Write Pool: 806 cuts
# Time for Cutting inside loop: 0.22 seconds (4.22 total in 10 calls)
# CCtsp_init_edgegenerator (-1)
# xprice_build
# xprice_reset (0)
# CCtsp_generate_edges (23003)
# Time for Add edges: 0.00 seconds (0.37 total in 11 calls)
# 0 edges added, penalty -0.000000
# New lower bound: 258231.000000
# Time for Full edge check: 0.00 seconds (0.00 total in 1 calls)
# Setting tolerances: next cuts 4.3400 next round 0.4340
# LP has:  1456 rows  2446 columns  13458 nonzeros
# Loading lp...done in 0.00 seconds
# LP has:  1456 rows  2446 columns  11621 nonzeros
# Integral Solution of Value 258231.00
# CCtsp_generate_edges (23003)
# Time for Add edges: 0.00 seconds (0.37 total in 12 calls)
# (SPARSE) 0 edges added, penalty -0.000000, val 258231.000000
# Time for Sparse edge check: 0.00 seconds (0.37 total in 11 calls)
# recomputing rownorms ...
# Write Pool: 806 cuts
# Time for Cutting inside loop: 0.03 seconds (4.25 total in 11 calls)
# CCtsp_init_edgegenerator (-1)
# xprice_build
# xprice_reset (0)
# CCtsp_generate_edges (23003)
# Time for Add edges: 0.00 seconds (0.37 total in 13 calls)
# 0 edges added, penalty -0.000000
# Time for Full edge check: 0.00 seconds (0.00 total in 2 calls)
# Time for Cutting Loop: 4.27 seconds (4.27 total in 1 calls)
# Number of outside rounds: 2
# CCtsp_x_greedy_tour ...
# 1000 edges in x-tour
# tour length: 258231.00 (0.00 seconds)
# Built CCkdtree: 0.00 (seconds)
# . 4306 edges
# Quad Nearest added 4306 edges (0.00 seconds)
# Edgegen total edges: 4306 (0.00 seconds)
# x-heuristic lk  gives: 258231.00
# Upperbound from x-heuristic: 258231.00
# Exact Price Time: 0.04 seconds
# Exact lower bound: 258231.000000
# DIFF: 0.000000
# Established Bound: 258231
# Optimal tour: 258231
# Total Time to solve TSP: 5.23

# %%
GO = False
if GO:
    num_samples = 10000
    set_nodes_coord = np.random.random([num_samples, n_clusters, 2])
    with open("tsp" + str(n_clusters) + "_pr1002.txt", "w") as f:
        solver = TSPSolver.from_data(centers[:,0], centers[:,1], norm="EUC_2D")  
        solution = solver.solve()
        f.write( " ".join( str(x)+str(" ")+str(y) for x,y in centers) )
        f.write( str(" ") + str('output') + str(" ") )
        f.write( str(" ").join( str(node_idx+1) for node_idx in solution.tour) )
        f.write( str(" ") + str(solution.tour[0]+1) + str(" ") )
